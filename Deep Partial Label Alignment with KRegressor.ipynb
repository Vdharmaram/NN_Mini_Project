# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('./data', train=True,  download=True, transform=transform)
    test_set  = dataset('./data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %% [markdown]
# ## K-Regressor

# %%
class KRegressor(nn.Module):
    def __init__(self, input_shape: int, hidden_size: int):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=hidden_size,
                nhead=1
            ),
            num_layers=1
        )
        self.output_layer = nn.Sequential(
            nn.Linear(hidden_size, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        z = self.transformer(x)[0, :]
        k = self.output_layer(z)
        return k

# %% [markdown]
# ## Dimensionality reducer

# %%
class DimensionReducer(nn.Module):
    def __init__(
        self,
        in_features: int,
        hidden_size: int,
        beta: float = 5.0,
        esp:  float = 1e-8
    ):
        super().__init__()
        
        self.beta = beta
        self.esp = esp
        self.k_regressor = KRegressor(in_features, hidden_size)
    
    def forward(self, xs: torch.Tensor) -> torch.Tensor:
        kd = min(xs.shape[0], xs.shape[1])
        ks = self.k_regressor(xs)
        
        xs = xs - torch.mean(xs, dim=0)
        # xs = xs + self.esp
        us, ss, vhs = torch.linalg.svd(xs, full_matrices=False)
        
        i = torch.arange(kd, device=xs.device)
        ws = torch.sigmoid(-self.beta*(i - ks*kd))
        
        ss1 = torch.diag(ss * ws)
        xs = torch.mm(torch.mm(us, ss1), vhs)
        
        return (xs, ks)

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor   = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
        self.dimension_reducer = DimensionReducer(self.feature_extractor.output_shape, hidden_size=128)
    
    def forward(self, x):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x, k = self.dimension_reducer(x)
        x = self.class_regressor(x)
        return (x, k)

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & dataset creation

# %%
lr_c = 1e-3
batch_size = 128
model_save_path = 'best_model.pt'

num_epochs = 50
checkpoint = 20

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, k=None, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred, _ = model_c(x)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha):
    N = xs.shape[0]
    
    ys_pred, ks = classifier(xs)
    
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    k_loss = ks**2
    loss = cls_loss + alpha*ks
    
    optimizer_c.zero_grad()
    loss.backward()
    optimizer_c.step()
    
    return (loss.item(), cls_loss.item(), k_loss.item(), ks.item())

# %% [markdown]
# # Main

# %%
def main():
    global classifier, dimension_reducer
    global cls_loss_fn
    global optimizer_c
    global loss_labels_train, loss_labels_val
    
    classifier = MyModel(
        input_shape=(1, 28, 28),
        output_shape=10,
        cnn_out_features=[16, 32, 64],
        fnn_out_features=[128, 64],
    ).to(device)
    
    dimension_reducer = DimensionReducer(
        classifier.class_regressor.in_features,
        hidden_size=128
    ).to(device)
    
    print(torchinfo.summary(classifier, input_size=(batch_size, 1, 28, 28)))
    
    cls_loss_fn = nn.CrossEntropyLoss()
    optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)
    
    all_loss = np.zeros((num_epochs, 4))
    loss_labels_train = ['loss', 'cls_loss', 'k_loss', 'k']

    all_loss_val = np.zeros((num_epochs, 4))
    all_loss_test = np.zeros((1, 4))
    loss_labels_val = ['cls_loss_s', 'accuracy_s', 'cls_loss_t', 'accuracy_t']
    
    best_val_loss = float('inf')
    best_k = 1
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1} --------')

        classifier.train()

        len_dataloader = min(len(train_s), len(train_t))
        iter_s = iter(train_s)
        iter_t = iter(train_t)

        avg_loss = np.zeros(all_loss.shape[1])

        for batch_idx in range(len_dataloader):
            # p = float(batch_idx + epoch * len_dataloader) / num_epochs / len_dataloader
            # alpha = 2 / (1 + np.exp(-10 * p)) - 1
            alpha = 1e-2

            data_s = next(iter_s)
            data_t = next(iter_t)

            xs, ys_true = data_s
            xt, yt_true = data_t
            if xs.shape[0] != xt.shape[0]:
                continue

            xs = xs.to(device)
            xt = xt.to(device)
            ys_true = ys_true.to(device)
            yt_true = yt_true.to(device)

            losses = train_step(xs, xt, ys_true, alpha)
            avg_loss += losses

            if checkpoint is not None and batch_idx % checkpoint == 0:
                print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                        batch_idx * batch_size,
                        len_dataloader * batch_size,
                        batch_idx / len_dataloader * 100
                    ),
                    end='\t'
                )
                for loss, label in zip(losses, loss_labels_train):
                    print(f'{label}: {loss:.6f}', end='\t')
                print('')

        avg_loss = avg_loss / len_dataloader
        all_loss[epoch] = losses

        val_losses_s = evaluate(classifier, val_s, cls_loss_fn, mode='Validation (source)')
        val_losses_t = evaluate(classifier, val_t, cls_loss_fn, mode='Validation (target)')

        all_loss_val[epoch] = val_losses_s + val_losses_t

        val_loss = val_losses_t[0]

        if val_loss < best_val_loss:
            torch.save(classifier.state_dict(), model_save_path)
            best_k = avg_loss[-1]
            best_val_loss = val_loss
            print(f'Best model updated and saved at "{model_save_path}"')
    
    classifier.load_state_dict(torch.load(model_save_path))
    test_loss_s = evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
    test_loss_t = evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
    
    all_loss_test = test_loss_s + test_loss_t
    
    return (all_loss, all_loss_val, all_loss_test)

# %%
all_loss_train = []
all_loss_val   = []
all_loss_test  = []
for i in range(5):
    loss_train, loss_val, loss_test = main()
    all_loss_train.append(loss_train)
    all_loss_val.append(loss_val)
    all_loss_test.append(loss_test)

all_loss_train = np.array(all_loss_train)
all_loss_val   = np.array(all_loss_val)
all_loss_test  = np.array(all_loss_test)
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# MyModel                                                 [128, 10]                 --
# ├─FeatureExtractor: 1-1                                 [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                                  --                        --
# │    │    └─Sequential: 3-1                             [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2                             [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3                             [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                                 [128, 576]                --
# │    └─KRegressor: 2-2                                  [1]                       --
# │    │    └─Linear: 3-4                                 [128, 128]                73,856
# │    │    └─TransformerEncoder: 3-5                     [128, 128]                593,024
# │    │    └─Sequential: 3-6                             [1]                       129
# ├─ClassRegressor: 1-3                                   [128, 10]                 --
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─Sequential: 3-7                             [128, 128]                73,856
# │    │    └─Sequential: 3-8                             [128, 64]                 8,256
# │    └─Linear: 2-4                                      [128, 10]                 650
# =========================================================================================================
# Total params: 773,067
# Trainable params: 773,067
# Non-trainable params: 0
# Total mult-adds (M): 335.97
# =========================================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 25.31
# Params size (MB): 2.83
# Estimated Total Size (MB): 28.54
# =========================================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.310486	cls_loss: 2.305570	k_loss: 0.241595	k: 0.491523
# Train -> [ 2560/ 5504 (47%)]	loss: 1.705860	cls_loss: 1.703628	k_loss: 0.049802	k: 0.223163
# Train -> [ 5120/ 5504 (93%)]	loss: 0.514950	cls_loss: 0.508051	k_loss: 0.476031	k: 0.689950
# Validation (source) -> cls_loss: 0.441470	accuracy: 87.7467%
# Validation (target) -> cls_loss: 1.123067	accuracy: 63.3370%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.456652	cls_loss: 0.449684	k_loss: 0.485629	k: 0.696871
# Train -> [ 2560/ 5504 (47%)]	loss: 0.186055	cls_loss: 0.183739	k_loss: 0.053599	k: 0.231515
# Train -> [ 5120/ 5504 (93%)]	loss: 0.245527	cls_loss: 0.237914	k_loss: 0.579699	k: 0.761380
# Validation (source) -> cls_loss: 0.191620	accuracy: 94.1467%
# Validation (target) -> cls_loss: 1.008403	accuracy: 71.0209%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.180148	cls_loss: 0.172842	k_loss: 0.533823	k: 0.730632
# Train -> [ 2560/ 5504 (47%)]	loss: 0.131387	cls_loss: 0.124709	k_loss: 0.445915	k: 0.667769
# Train -> [ 5120/ 5504 (93%)]	loss: 0.097989	cls_loss: 0.092611	k_loss: 0.289210	k: 0.537782
# Validation (source) -> cls_loss: 0.130281	accuracy: 96.1067%
# Validation (target) -> cls_loss: 1.164315	accuracy: 68.9901%
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 0
--------
# Train -> [    0/ 5504 (0%)]	loss: 0.021062	cls_loss: 0.016489	k_loss: 0.209148	k: 0.457327
# Train -> [ 2560/ 5504 (47%)]	loss: 0.049444	cls_loss: 0.045061	k_loss: 0.192189	k: 0.438393
# Train -> [ 5120/ 5504 (93%)]	loss: 0.008261	cls_loss: 0.003643	k_loss: 0.213239	k: 0.461778
# Validation (source) -> cls_loss: 0.044307	accuracy: 98.8133%
# Validation (target) -> cls_loss: 0.807248	accuracy: 77.3875%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.056537	cls_loss: 0.051775	k_loss: 0.226722	k: 0.476153
# Train -> [ 2560/ 5504 (47%)]	loss: 0.061962	cls_loss: 0.057942	k_loss: 0.161635	k: 0.402039
# Train -> [ 5120/ 5504 (93%)]	loss: 0.061845	cls_loss: 0.058117	k_loss: 0.138987	k: 0.372809
# Validation (source) -> cls_loss: 0.052438	accuracy: 98.6533%
# Validation (target) -> cls_loss: 1.064571	accuracy: 75.1921%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.017085	cls_loss: 0.013193	k_loss: 0.151454	k: 0.389170
# Train -> [ 2560/ 5504 (47%)]	loss: 0.071578	cls_loss: 0.069082	k_loss: 0.062301	k: 0.249602
# Train -> [ 5120/ 5504 (93%)]	loss: 0.015297	cls_loss: 0.011527	k_loss: 0.142143	k: 0.377019
# Validation (source) -> cls_loss: 0.047129	accuracy: 98.7067%
# Validation (target) -> cls_loss: 0.726161	accuracy: 78.9243%
# Test (source) -> cls_loss: 0.041942	accuracy: 98.7300%
# Test (target) -> cls_loss: 0.686617	accuracy: 81.1161%
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# MyModel                                                 [128, 10]                 --
# ├─FeatureExtractor: 1-1                                 [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                                  --                        --
# │    │    └─Sequential: 3-1                             [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2                             [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3                             [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                                 [128, 576]                --
# │    └─KRegressor: 2-2                                  [1]                       --
# │    │    └─Linear: 3-4                                 [128, 128]                73,856
# │    │    └─TransformerEncoder: 3-5                     [128, 128]                593,024
# │    │    └─Sequential: 3-6                             [1]                       129
# ├─ClassRegressor: 1-3                                   [128, 10]                 --
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─Sequential: 3-7                             [128, 128]                73,856
# │    │    └─Sequential: 3-8                             [128, 64]                 8,256
# │    └─Linear: 2-4                                      [128, 10]                 650
# =========================================================================================================
# Total params: 773,067
# Trainable params: 773,067
# Non-trainable params: 0
# Total mult-adds (M): 335.97
# =========================================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 25.31
# Params size (MB): 2.83
# Estimated Total Size (MB): 28.54
# =========================================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.313128	cls_loss: 2.307208	k_loss: 0.350526	k: 0.592053
# Train -> [ 2560/ 5504 (47%)]	loss: 1.171266	cls_loss: 1.165280	k_loss: 0.358368	k: 0.598639
# Train -> [ 5120/ 5504 (93%)]	loss: 0.417706	cls_loss: 0.410738	k_loss: 0.485532	k: 0.696801
# Validation (source) -> cls_loss: 0.428817	accuracy: 86.1867%
# Validation (target) -> cls_loss: 1.041809	accuracy: 67.0692%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 0
--------
# Train -> [    0/ 5504 (0%)]	loss: 0.009888	cls_loss: 0.005721	k_loss: 0.173657	k: 0.416722
# Train -> [ 2560/ 5504 (47%)]	loss: 0.038692	cls_loss: 0.032530	k_loss: 0.379699	k: 0.616197
# Train -> [ 5120/ 5504 (93%)]	loss: 0.018732	cls_loss: 0.010922	k_loss: 0.610058	k: 0.781062
# Validation (source) -> cls_loss: 0.047844	accuracy: 98.6267%
# Validation (target) -> cls_loss: 0.656536	accuracy: 83.5895%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.042395	cls_loss: 0.034576	k_loss: 0.611349	k: 0.781888
# Train -> [ 2560/ 5504 (47%)]	loss: 0.013015	cls_loss: 0.004298	k_loss: 0.759838	k: 0.871687
# Train -> [ 5120/ 5504 (93%)]	loss: 0.023021	cls_loss: 0.014065	k_loss: 0.802182	k: 0.895646
# Validation (source) -> cls_loss: 0.064975	accuracy: 98.2267%
# Validation (target) -> cls_loss: 0.867308	accuracy: 76.4544%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.015364	cls_loss: 0.006359	k_loss: 0.810815	k: 0.900453
# Train -> [ 2560/ 5504 (47%)]	loss: 0.059943	cls_loss: 0.051042	k_loss: 0.792327	k: 0.890128
# Train -> [ 5120/ 5504 (93%)]	loss: 0.020741	cls_loss: 0.012080	k_loss: 0.750040	k: 0.866049
# Validation (source) -> cls_loss: 0.047429	accuracy: 98.6533%
# Validation (target) -> cls_loss: 0.712179	accuracy: 80.0768%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.021086	cls_loss: 0.012207	k_loss: 0.788355	k: 0.887894
# Train -> [ 2560/ 5504 (47%)]	loss: 0.013721	cls_loss: 0.005375	k_loss: 0.696522	k: 0.834579
# Train -> [ 5120/ 5504 (93%)]	loss: 0.009811	cls_loss: 0.001909	k_loss: 0.624420	k: 0.790203
# Validation (source) -> cls_loss: 0.047312	accuracy: 98.6933%
# Validation (target) -> cls_loss: 0.857555	accuracy: 77.2228%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.008403	cls_loss: 0.000566	k_loss: 0.614041	k: 0.783608
# Train -> [ 2560/ 5504 (47%)]	loss: 0.007604	cls_loss: 0.000372	k_loss: 0.523080	k: 0.723243
# Train -> [ 5120/ 5504 (93%)]	loss: 0.007318	cls_loss: 0.000462	k_loss: 0.470167	k: 0.685687
# Validation (source) -> cls_loss: 0.046118	accuracy: 98.6867%
# Validation (target) -> cls_loss: 0.679251	accuracy: 81.4490%
# Test (source) -> cls_loss: 0.054617	accuracy: 98.3500%
# Test (target) -> cls_loss: 0.684219	accuracy: 79.0732%

# %%
np.save('all_loss_train.npy', all_loss_train)
np.save('all_loss_val.npy', all_loss_val)
np.save('all_loss_test.npy', all_loss_test)

plot_losses(
    list(np.mean(all_loss_train, axis=0).T),
    loss_labels_train,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training'
)
plot_losses(
    list(np.mean(all_loss_val, axis=0).T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation'
)
print(np.mean(all_loss_test, axis=0))
# Out:
# [0.04185224 0.9869     0.63250406 0.81943199]
