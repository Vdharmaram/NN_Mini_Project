# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('./data', train=True,  download=True, transform=transform)
    test_set  = dataset('./data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
    
    def forward(self, x):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x = self.class_regressor(x)
        return x

# %% [markdown]
# ## Domain discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_features: int, hidden_size: int):
        super().__init__()
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=hidden_size, nhead=1), num_layers=1
        )
        self.op_layer = nn.Sequential(nn.Linear(hidden_size, 1), nn.Sigmoid())
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        x = self.transformer(x)[0, :]
        x = self.op_layer(x)
        return x

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & model creation

# %%
lr_c = 1e-3
lr_d = 1e-10
batch_size = 128
model_save_path = 'best_model.pt'

classifier = MyModel(
    input_shape=(1, 28, 28),
    output_shape=10,
    cnn_out_features=[16, 32, 64],
    fnn_out_features=[128, 64],
).to(device)
discriminator = Discriminator(classifier.class_regressor.in_features, 128).to(device)

cls_loss_fn = nn.CrossEntropyLoss()
adv_loss_fn = nn.BCELoss()

optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)
optimizer_d = torch.optim.Adam(discriminator.parameters(), lr=lr_d)

# %%
torchinfo.summary(classifier, input_size=(batch_size, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─ClassRegressor: 1-2                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 106,058
# Trainable params: 106,058
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred = model_c(x)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha):
    N = xs.shape[0]
    
    xs = classifier.feature_extractor(xs)
    xs = torch.flatten(xs, start_dim=1)
    xt = classifier.feature_extractor(xt)
    xt = torch.flatten(xt, start_dim=1)
    
    ####
    # discriminator training
    ####
    label_s = torch.zeros(1, device=device)
    label_t = torch.ones(1, device=device)
    
    pt_s = discriminator(xs.detach())
    pt_t = discriminator(xt.detach())
    
    adv_loss_s = adv_loss_fn(pt_s, label_s)
    adv_loss_t = adv_loss_fn(pt_t, label_t)
    
    loss_d = (adv_loss_s + adv_loss_t)/2
    optimizer_d.zero_grad()
    loss_d.backward()
    optimizer_d.step()
    
    ####
    # classifier training
    ####
    ys_pred = classifier.class_regressor(xs)
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    
    pt_s_c = discriminator(xs)
    pt_t_c = discriminator(xt)
    
    # classifier tries to trick discriminator
    adv_loss_s_c = adv_loss_fn(pt_s_c, label_t)
    adv_loss_t_c = adv_loss_fn(pt_t_c, label_s)
    
    loss_c = cls_loss + alpha*(adv_loss_s_c + adv_loss_t_c)/2
    optimizer_c.zero_grad()
    cls_loss.backward()
    optimizer_c.step()
    
    return (loss_c.item(), cls_loss.item(), adv_loss_s_c.item(), adv_loss_t_c.item())

# %% [markdown]
# # Main

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)

# %%
num_epochs = 50
checkpoint = 20

all_loss = np.zeros((num_epochs, 4))
loss_labels = ['loss', 'cls_loss', 'adv_loss_s', 'adv_loss_t']

all_loss_val_s = np.zeros((num_epochs, 2))
all_loss_val_t = np.zeros((num_epochs, 2))
loss_labels_val = ['cls_loss', 'accuracy']

best_val_loss = float('inf')

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1} --------')
    
    classifier.train()
    discriminator.train()
    
    len_dataloader = min(len(train_s), len(train_t))
    iter_s = iter(train_s)
    iter_t = iter(train_t)
    
    avg_loss = np.zeros(all_loss.shape[1])
    
    for batch_idx in range(len_dataloader):
        # alpha = (epoch*len_dataloader + batch_idx) / (num_epochs*len_dataloader)
        alpha = 1
        data_s = next(iter_s)
        data_t = next(iter_t)
        
        xs, ys_true = data_s
        xt, yt_true = data_t
        if xs.shape[0] != xt.shape[0]:
            continue
        
        xs = xs.to(device)
        xt = xt.to(device)
        ys_true = ys_true.to(device)
        yt_true = yt_true.to(device)
        
        losses = train_step(xs, xt, ys_true, alpha)
        avg_loss += losses
        
        if checkpoint is not None and batch_idx % checkpoint == 0:
            print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                    batch_idx * batch_size,
                    len_dataloader * batch_size,
                    batch_idx / len_dataloader * 100
                ),
                end='\t'
            )
            for loss, label in zip(losses, loss_labels):
                print(f'{label}: {loss:.6f}', end='\t')
            print('')
    
    avg_loss = avg_loss / len_dataloader
    all_loss[epoch] = losses
    
    val_losses_s = evaluate(classifier, val_s, cls_loss_fn, mode='Validation (source)')
    val_losses_t = evaluate(classifier, val_t, cls_loss_fn, mode='Validation (target)')
    
    all_loss_val_s[epoch] = val_losses_s
    all_loss_val_t[epoch] = val_losses_t
    
    val_loss = val_losses_t[0]
    
    if val_loss < best_val_loss:
        torch.save(classifier.state_dict(), model_save_path)
        best_val_loss = val_loss
        print(f'Best model updated and saved at "{model_save_path}"')
# Out:
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.894611	cls_loss: 2.307346	adv_loss_s: 0.408620	adv_loss_t: 0.765910
# Train -> [ 2560/ 5504 (47%)]	loss: 2.469141	cls_loss: 1.820413	adv_loss_s: 0.396979	adv_loss_t: 0.900476
# Train -> [ 5120/ 5504 (93%)]	loss: 1.512891	cls_loss: 0.743924	adv_loss_s: 0.374222	adv_loss_t: 1.163713
# Validation (source) -> cls_loss: 0.747591	accuracy: 76.5933%
# Validation (target) -> cls_loss: 1.501315	accuracy: 47.8595%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.537254	cls_loss: 0.760000	adv_loss_s: 0.454014	adv_loss_t: 1.100492
# Train -> [ 2560/ 5504 (47%)]	loss: 1.092012	cls_loss: 0.409344	adv_loss_s: 0.283746	adv_loss_t: 1.081591
# Train -> [ 5120/ 5504 (93%)]	loss: 1.336616	cls_loss: 0.522438	adv_loss_s: 0.526174	adv_loss_t: 1.102182
# Validation (source) -> cls_loss: 0.353231	accuracy: 89.5200%
# Validation (target) -> cls_loss: 0.893356	accuracy: 70.4720%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.852556	cls_loss: 0.303808	adv_loss_s: 0.344560	adv_loss_t: 0.752937
# Train -> [ 2560/ 5504 (47%)]	loss: 0.893178	cls_loss: 0.190023	adv_loss_s: 0.310473	adv_loss_t: 1.095838
# Train -> [ 5120/ 5504 (93%)]	loss: 0.975416	cls_loss: 0.259813	adv_loss_s: 0.411498	adv_loss_t: 1.019708
# Validation (source) -> cls_loss: 0.214860	accuracy: 93.5467%
# Validation (target) -> cls_loss: 0.909214	accuracy: 69.2645%
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.930769	cls_loss: 0.142149	adv_loss_s: 0.572078	adv_loss_t: 1.005164
# Train -> [ 2560/ 5504 (47%)]	loss: 0.735088	cls_loss: 0.218499	adv_loss_s: 0.474131	adv_loss_t: 0.559046
# Train -> [ 5120/ 5504 (93%)]	loss: 1.039384	cls_loss: 0.248612	adv_loss_s: 0.297150	adv_loss_t: 1.284395
# Validation (source) -> cls_loss: 0.168779	accuracy: 94.9133%
# Validation (target) -> cls_loss: 0.882189	accuracy: 71.8441%
# Best model updated and saved at "best_model.pt"
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.808993	cls_loss: 0.185599	adv_loss_s: 0.474338	adv_loss_t: 0.772452
# Train -> [ 2560/ 5504 (47%)]	loss: 0.858949	cls_loss: 0.151774	adv_loss_s: 0.426098	adv_loss_t: 0.988252
# Train -> [ 5120/ 5504 (93%)]	loss: 0.781205	cls_loss: 0.135195	adv_loss_s: 0.402149	adv_loss_t: 0.889871
# Validation (source) -> cls_loss: 0.141795	accuracy: 95.6667%
# Validation (target) -> cls_loss: 0.926864	accuracy: 73.0516%
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.884476	cls_loss: 0.103563	adv_loss_s: 0.514739	adv_loss_t: 1.047086
# Train -> [ 2560/ 5504 (47%)]	loss: 0.922752	cls_loss: 0.083219	adv_loss_s: 0.527960	adv_loss_t: 1.151107
# Train -> [ 5120/ 5504 (93%)]	loss: 0.844805	cls_loss: 0.143110	adv_loss_s: 0.388817	adv_loss_t: 1.014572
# Validation (source) -> cls_loss: 0.132229	accuracy: 96.1667%
# Validation (target) -> cls_loss: 0.989080	accuracy: 68.2766%
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.720050	cls_loss: 0.114782	adv_loss_s: 0.356811	adv_loss_t: 0.853725
# Train -> [ 2560/ 5504 (47%)]	loss: 0.881967	cls_loss: 0.131801	adv_loss_s: 0.419455	adv_loss_t: 1.080877
# Train -> [ 5120/ 5504 (93%)]	loss: 0.798707	cls_loss: 0.107683	adv_loss_s: 0.441454	adv_loss_t: 0.940594
# Validation (source) -> cls_loss: 0.112915	accuracy: 96.5933%
# Validation (target) -> cls_loss: 0.741851	accuracy: 76.9484%
# Best model updated and saved at "best_model.pt"
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.781576	cls_loss: 0.141086	adv_loss_s: 0.290652	adv_loss_t: 0.990329
# Train -> [ 2560/ 5504 (47%)]	loss: 0.836811	cls_loss: 0.122074	adv_loss_s: 0.392779	adv_loss_t: 1.036695
# Train -> [ 5120/ 5504 (93%)]	loss: 1.180121	cls_loss: 0.141272	adv_loss_s: 0.387753	adv_loss_t: 1.689945
# Validation (source) -> cls_loss: 0.098872	accuracy: 96.9067%
# Validation (target) -> cls_loss: 0.716464	accuracy: 77.0033%
# Best model updated and saved at "best_model.pt"
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.932104	cls_loss: 0.088883	adv_loss_s: 0.354937	adv_loss_t: 1.331505
# Train -> [ 2560/ 5504 (47%)]	loss: 0.567487	cls_loss: 0.024570	adv_loss_s: 0.388436	adv_loss_t: 0.697399
# Train -> [ 5120/ 5504 (93%)]	loss: 0.696078	cls_loss: 0.027493	adv_loss_s: 0.418538	adv_loss_t: 0.918632
# Validation (source) -> cls_loss: 0.099993	accuracy: 96.8200%
# Validation (target) -> cls_loss: 0.817307	accuracy: 73.6553%
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.727481	cls_loss: 0.040426	adv_loss_s: 0.386444	adv_loss_t: 0.987666
# Train -> [ 2560/ 5504 (47%)]	loss: 0.840908	cls_loss: 0.036264	adv_loss_s: 0.552079	adv_loss_t: 1.057209
# Train -> [ 5120/ 5504 (93%)]	loss: 0.699853	cls_loss: 0.075922	adv_loss_s: 0.449198	adv_loss_t: 0.798664
# Validation (source) -> cls_loss: 0.091458	accuracy: 97.2133%
# Validation (target) -> cls_loss: 0.984812	accuracy: 72.7223%
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.803493	cls_loss: 0.063056	adv_loss_s: 0.540432	adv_loss_t: 0.940441
# Train -> [ 2560/ 5504 (47%)]	loss: 0.935710	cls_loss: 0.112208	adv_loss_s: 0.753448	adv_loss_t: 0.893556
# Train -> [ 5120/ 5504 (93%)]	loss: 0.890789	cls_loss: 0.094583	adv_loss_s: 0.707837	adv_loss_t: 0.884575
# Validation (source) -> cls_loss: 0.132003	accuracy: 95.5600%
# Validation (target) -> cls_loss: 0.926291	accuracy: 74.0395%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.838595	cls_loss: 0.072822	adv_loss_s: 0.514001	adv_loss_t: 1.017543
# Train -> [ 2560/ 5504 (47%)]	loss: 0.878132	cls_loss: 0.056401	adv_loss_s: 0.751031	adv_loss_t: 0.892431
# Train -> [ 5120/ 5504 (93%)]	loss: 0.775364	cls_loss: 0.028491	adv_loss_s: 0.369316	adv_loss_t: 1.124429
# Validation (source) -> cls_loss: 0.077755	accuracy: 97.5867%
# Validation (target) -> cls_loss: 0.674734	accuracy: 77.6070%
# Best model updated and saved at "best_model.pt"
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.815864	cls_loss: 0.107316	adv_loss_s: 0.622734	adv_loss_t: 0.794363
# Train -> [ 2560/ 5504 (47%)]	loss: 0.631015	cls_loss: 0.009456	adv_loss_s: 0.537094	adv_loss_t: 0.706025
# Train -> [ 5120/ 5504 (93%)]	loss: 0.561594	cls_loss: 0.057546	adv_loss_s: 0.273188	adv_loss_t: 0.734909
# Validation (source) -> cls_loss: 0.072143	accuracy: 97.6733%
# Validation (target) -> cls_loss: 0.712939	accuracy: 77.7168%
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.074095	cls_loss: 0.027559	adv_loss_s: 0.731245	adv_loss_t: 1.361825
# Train -> [ 2560/ 5504 (47%)]	loss: 0.893999	cls_loss: 0.076334	adv_loss_s: 0.705563	adv_loss_t: 0.929768
# Train -> [ 5120/ 5504 (93%)]	loss: 0.733364	cls_loss: 0.081978	adv_loss_s: 0.379544	adv_loss_t: 0.923227
# Validation (source) -> cls_loss: 0.074366	accuracy: 97.6467%
# Validation (target) -> cls_loss: 0.688435	accuracy: 79.1987%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.608841	cls_loss: 0.008272	adv_loss_s: 0.455238	adv_loss_t: 0.745901
# Train -> [ 2560/ 5504 (47%)]	loss: 0.497503	cls_loss: 0.027359	adv_loss_s: 0.424770	adv_loss_t: 0.515516
# Train -> [ 5120/ 5504 (93%)]	loss: 0.670824	cls_loss: 0.032194	adv_loss_s: 0.255302	adv_loss_t: 1.021958
# Validation (source) -> cls_loss: 0.068936	accuracy: 97.9133%
# Validation (target) -> cls_loss: 0.783946	accuracy: 77.2228%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.686669	cls_loss: 0.111480	adv_loss_s: 0.464925	adv_loss_t: 0.685452
# Train -> [ 2560/ 5504 (47%)]	loss: 0.686514	cls_loss: 0.022392	adv_loss_s: 0.294847	adv_loss_t: 1.033398
# Train -> [ 5120/ 5504 (93%)]	loss: 0.695533	cls_loss: 0.043132	adv_loss_s: 0.391728	adv_loss_t: 0.913075
# Validation (source) -> cls_loss: 0.071081	accuracy: 97.7733%
# Validation (target) -> cls_loss: 0.797818	accuracy: 76.2898%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.799953	cls_loss: 0.095336	adv_loss_s: 0.508439	adv_loss_t: 0.900795
# Train -> [ 2560/ 5504 (47%)]	loss: 0.863473	cls_loss: 0.093039	adv_loss_s: 0.633790	adv_loss_t: 0.907077
# Train -> [ 5120/ 5504 (93%)]	loss: 0.765101	cls_loss: 0.027790	adv_loss_s: 0.537953	adv_loss_t: 0.936669
# Validation (source) -> cls_loss: 0.070331	accuracy: 97.8333%
# Validation (target) -> cls_loss: 0.969854	accuracy: 73.9846%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.806279	cls_loss: 0.141609	adv_loss_s: 0.341214	adv_loss_t: 0.988127
# Train -> [ 2560/ 5504 (47%)]	loss: 0.833010	cls_loss: 0.050456	adv_loss_s: 0.621863	adv_loss_t: 0.943246
# Train -> [ 5120/ 5504 (93%)]	loss: 0.796480	cls_loss: 0.069622	adv_loss_s: 0.472694	adv_loss_t: 0.981023
# Validation (source) -> cls_loss: 0.069430	accuracy: 97.8600%
# Validation (target) -> cls_loss: 1.057366	accuracy: 71.3502%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.908886	cls_loss: 0.057988	adv_loss_s: 0.445718	adv_loss_t: 1.256078
# Train -> [ 2560/ 5504 (47%)]	loss: 0.866019	cls_loss: 0.065297	adv_loss_s: 0.638407	adv_loss_t: 0.963036
# Train -> [ 5120/ 5504 (93%)]	loss: 0.774417	cls_loss: 0.076824	adv_loss_s: 0.468045	adv_loss_t: 0.927141
# Validation (source) -> cls_loss: 0.060614	accuracy: 98.1067%
# Validation (target) -> cls_loss: 1.076442	accuracy: 73.7102%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.705087	cls_loss: 0.094968	adv_loss_s: 0.293689	adv_loss_t: 0.926548
# Train -> [ 2560/ 5504 (47%)]	loss: 0.773858	cls_loss: 0.035864	adv_loss_s: 0.400219	adv_loss_t: 1.075769
# Train -> [ 5120/ 5504 (93%)]	loss: 0.659293	cls_loss: 0.009688	adv_loss_s: 0.466801	adv_loss_t: 0.832408
# Validation (source) -> cls_loss: 0.060954	accuracy: 98.1533%
# Validation (target) -> cls_loss: 0.999418	accuracy: 72.4479%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.607460	cls_loss: 0.022773	adv_loss_s: 0.310639	adv_loss_t: 0.858736
# Train -> [ 2560/ 5504 (47%)]	loss: 0.906026	cls_loss: 0.012858	adv_loss_s: 0.448164	adv_loss_t: 1.338172
# Train -> [ 5120/ 5504 (93%)]	loss: 0.761727	cls_loss: 0.024124	adv_loss_s: 0.482056	adv_loss_t: 0.993149
# Validation (source) -> cls_loss: 0.057434	accuracy: 98.2267%
# Validation (target) -> cls_loss: 0.844587	accuracy: 78.3754%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.786806	cls_loss: 0.020476	adv_loss_s: 0.476509	adv_loss_t: 1.056150
# Train -> [ 2560/ 5504 (47%)]	loss: 0.775947	cls_loss: 0.022667	adv_loss_s: 0.618324	adv_loss_t: 0.888236
# Train -> [ 5120/ 5504 (93%)]	loss: 0.667896	cls_loss: 0.037749	adv_loss_s: 0.621343	adv_loss_t: 0.638953
# Validation (source) -> cls_loss: 0.062331	accuracy: 98.2133%
# Validation (target) -> cls_loss: 1.375867	accuracy: 67.1240%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.526531	cls_loss: 0.053550	adv_loss_s: 0.375866	adv_loss_t: 0.570095
# Train -> [ 2560/ 5504 (47%)]	loss: 0.923614	cls_loss: 0.048512	adv_loss_s: 0.715330	adv_loss_t: 1.034874
# Train -> [ 5120/ 5504 (93%)]	loss: 0.833311	cls_loss: 0.082958	adv_loss_s: 0.651209	adv_loss_t: 0.849497
# Validation (source) -> cls_loss: 0.056376	accuracy: 98.1067%
# Validation (target) -> cls_loss: 0.959032	accuracy: 72.9418%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.554882	cls_loss: 0.012882	adv_loss_s: 0.495727	adv_loss_t: 0.588273
# Train -> [ 2560/ 5504 (47%)]	loss: 0.667305	cls_loss: 0.026169	adv_loss_s: 0.415469	adv_loss_t: 0.866804
# Train -> [ 5120/ 5504 (93%)]	loss: 0.689132	cls_loss: 0.075897	adv_loss_s: 0.443151	adv_loss_t: 0.783319
# Validation (source) -> cls_loss: 0.069892	accuracy: 97.8467%
# Validation (target) -> cls_loss: 1.201170	accuracy: 71.8441%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.948873	cls_loss: 0.060002	adv_loss_s: 0.447730	adv_loss_t: 1.330014
# Train -> [ 2560/ 5504 (47%)]	loss: 0.646052	cls_loss: 0.026344	adv_loss_s: 0.539140	adv_loss_t: 0.700274
# Train -> [ 5120/ 5504 (93%)]	loss: 0.678118	cls_loss: 0.060145	adv_loss_s: 0.416407	adv_loss_t: 0.819538
# Validation (source) -> cls_loss: 0.072473	accuracy: 97.7400%
# Validation (target) -> cls_loss: 1.140094	accuracy: 71.2404%
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.937318	cls_loss: 0.041459	adv_loss_s: 0.737384	adv_loss_t: 1.054333
# Train -> [ 2560/ 5504 (47%)]	loss: 0.872818	cls_loss: 0.063363	adv_loss_s: 0.354814	adv_loss_t: 1.264096
# Train -> [ 5120/ 5504 (93%)]	loss: 0.809464	cls_loss: 0.049938	adv_loss_s: 0.847220	adv_loss_t: 0.671832
# Validation (source) -> cls_loss: 0.054533	accuracy: 98.4133%
# Validation (target) -> cls_loss: 1.074889	accuracy: 70.6915%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.756736	cls_loss: 0.034568	adv_loss_s: 0.687138	adv_loss_t: 0.757199
# Train -> [ 2560/ 5504 (47%)]	loss: 0.880727	cls_loss: 0.093026	adv_loss_s: 0.934855	adv_loss_t: 0.640548
# Train -> [ 5120/ 5504 (93%)]	loss: 0.579874	cls_loss: 0.012753	adv_loss_s: 0.400019	adv_loss_t: 0.734223
# Validation (source) -> cls_loss: 0.070058	accuracy: 97.7467%
# Validation (target) -> cls_loss: 1.063006	accuracy: 72.9967%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.853164	cls_loss: 0.028914	adv_loss_s: 0.733226	adv_loss_t: 0.915274
# Train -> [ 2560/ 5504 (47%)]	loss: 0.798072	cls_loss: 0.049534	adv_loss_s: 0.478508	adv_loss_t: 1.018568
# Train -> [ 5120/ 5504 (93%)]	loss: 0.499895	cls_loss: 0.033467	adv_loss_s: 0.365451	adv_loss_t: 0.567405
# Validation (source) -> cls_loss: 0.047017	accuracy: 98.6333%
# Validation (target) -> cls_loss: 1.022914	accuracy: 72.7223%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.973781	cls_loss: 0.094615	adv_loss_s: 0.623671	adv_loss_t: 1.134660
# Train -> [ 2560/ 5504 (47%)]	loss: 1.018138	cls_loss: 0.077962	adv_loss_s: 0.522893	adv_loss_t: 1.357458
# Train -> [ 5120/ 5504 (93%)]	loss: 0.728107	cls_loss: 0.063617	adv_loss_s: 0.404427	adv_loss_t: 0.924554
# Validation (source) -> cls_loss: 0.074507	accuracy: 97.7267%
# Validation (target) -> cls_loss: 0.919779	accuracy: 75.2470%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.782511	cls_loss: 0.033359	adv_loss_s: 0.368197	adv_loss_t: 1.130107
# Train -> [ 2560/ 5504 (47%)]	loss: 0.896585	cls_loss: 0.068823	adv_loss_s: 0.540213	adv_loss_t: 1.115312
# Train -> [ 5120/ 5504 (93%)]	loss: 0.891775	cls_loss: 0.093015	adv_loss_s: 0.743275	adv_loss_t: 0.854245
# Validation (source) -> cls_loss: 0.055766	accuracy: 98.3067%
# Validation (target) -> cls_loss: 1.110109	accuracy: 73.2711%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.830177	cls_loss: 0.059384	adv_loss_s: 0.582795	adv_loss_t: 0.958791
# Train -> [ 2560/ 5504 (47%)]	loss: 0.682211	cls_loss: 0.032162	adv_loss_s: 0.498919	adv_loss_t: 0.801179
# Train -> [ 5120/ 5504 (93%)]	loss: 0.759949	cls_loss: 0.012549	adv_loss_s: 0.488770	adv_loss_t: 1.006029
# Validation (source) -> cls_loss: 0.070718	accuracy: 97.9600%
# Validation (target) -> cls_loss: 1.252011	accuracy: 71.7892%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.612737	cls_loss: 0.020726	adv_loss_s: 0.612443	adv_loss_t: 0.571580
# Train -> [ 2560/ 5504 (47%)]	loss: 0.782624	cls_loss: 0.006702	adv_loss_s: 0.453480	adv_loss_t: 1.098364
# Train -> [ 5120/ 5504 (93%)]	loss: 0.628627	cls_loss: 0.011630	adv_loss_s: 0.368769	adv_loss_t: 0.865225
# Validation (source) -> cls_loss: 0.051832	accuracy: 98.5000%
# Validation (target) -> cls_loss: 0.988846	accuracy: 75.9056%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.674563	cls_loss: 0.024843	adv_loss_s: 0.567680	adv_loss_t: 0.731760
# Train -> [ 2560/ 5504 (47%)]	loss: 0.688353	cls_loss: 0.068873	adv_loss_s: 0.535151	adv_loss_t: 0.703810
# Train -> [ 5120/ 5504 (93%)]	loss: 0.683240	cls_loss: 0.059768	adv_loss_s: 0.557518	adv_loss_t: 0.689425
# Validation (source) -> cls_loss: 0.051976	accuracy: 98.4200%
# Validation (target) -> cls_loss: 0.964328	accuracy: 76.4544%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.781876	cls_loss: 0.053460	adv_loss_s: 0.730143	adv_loss_t: 0.726689
# Train -> [ 2560/ 5504 (47%)]	loss: 0.703230	cls_loss: 0.018300	adv_loss_s: 0.507550	adv_loss_t: 0.862310
# Train -> [ 5120/ 5504 (93%)]	loss: 0.704177	cls_loss: 0.023305	adv_loss_s: 0.617408	adv_loss_t: 0.744336
# Validation (source) -> cls_loss: 0.045846	accuracy: 98.6933%
# Validation (target) -> cls_loss: 1.177321	accuracy: 72.5027%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.720881	cls_loss: 0.030700	adv_loss_s: 0.324101	adv_loss_t: 1.056260
# Train -> [ 2560/ 5504 (47%)]	loss: 0.865153	cls_loss: 0.033078	adv_loss_s: 0.527377	adv_loss_t: 1.136773
# Train -> [ 5120/ 5504 (93%)]	loss: 0.704803	cls_loss: 0.026661	adv_loss_s: 0.606682	adv_loss_t: 0.749602
# Validation (source) -> cls_loss: 0.051061	accuracy: 98.5133%
# Validation (target) -> cls_loss: 1.281671	accuracy: 68.2217%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.491235	cls_loss: 0.057942	adv_loss_s: 0.557215	adv_loss_t: 0.309370
# Train -> [ 2560/ 5504 (47%)]	loss: 0.767521	cls_loss: 0.003784	adv_loss_s: 0.497934	adv_loss_t: 1.029539
# Train -> [ 5120/ 5504 (93%)]	loss: 0.635020	cls_loss: 0.049187	adv_loss_s: 0.346777	adv_loss_t: 0.824889
# Validation (source) -> cls_loss: 0.057709	accuracy: 98.2867%
# Validation (target) -> cls_loss: 1.172952	accuracy: 71.5148%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.710343	cls_loss: 0.024941	adv_loss_s: 0.503593	adv_loss_t: 0.867211
# Train -> [ 2560/ 5504 (47%)]	loss: 0.602029	cls_loss: 0.060362	adv_loss_s: 0.546427	adv_loss_t: 0.536906
# Train -> [ 5120/ 5504 (93%)]	loss: 0.554113	cls_loss: 0.119787	adv_loss_s: 0.403496	adv_loss_t: 0.465156
# Validation (source) -> cls_loss: 0.049401	accuracy: 98.5867%
# Validation (target) -> cls_loss: 0.913792	accuracy: 74.4786%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.634294	cls_loss: 0.032222	adv_loss_s: 0.679344	adv_loss_t: 0.524800
# Train -> [ 2560/ 5504 (47%)]	loss: 0.868681	cls_loss: 0.065374	adv_loss_s: 0.587159	adv_loss_t: 1.019454
# Train -> [ 5120/ 5504 (93%)]	loss: 0.797240	cls_loss: 0.131089	adv_loss_s: 0.303607	adv_loss_t: 1.028696
# Validation (source) -> cls_loss: 0.056157	accuracy: 98.3533%
# Validation (target) -> cls_loss: 0.851885	accuracy: 76.2349%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.464254	cls_loss: 0.071813	adv_loss_s: 0.299596	adv_loss_t: 0.485286
# Train -> [ 2560/ 5504 (47%)]	loss: 0.992936	cls_loss: 0.044760	adv_loss_s: 0.916062	adv_loss_t: 0.980289
# Train -> [ 5120/ 5504 (93%)]	loss: 0.848233	cls_loss: 0.001751	adv_loss_s: 0.799034	adv_loss_t: 0.893931
# Validation (source) -> cls_loss: 0.056828	accuracy: 98.3333%
# Validation (target) -> cls_loss: 1.661187	accuracy: 63.5565%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.828268	cls_loss: 0.008975	adv_loss_s: 0.605771	adv_loss_t: 1.032815
# Train -> [ 2560/ 5504 (47%)]	loss: 0.686382	cls_loss: 0.010856	adv_loss_s: 0.394824	adv_loss_t: 0.956227
# Train -> [ 5120/ 5504 (93%)]	loss: 0.622518	cls_loss: 0.004670	adv_loss_s: 0.330441	adv_loss_t: 0.905255
# Validation (source) -> cls_loss: 0.052937	accuracy: 98.4733%
# Validation (target) -> cls_loss: 1.765248	accuracy: 65.0384%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.728245	cls_loss: 0.012147	adv_loss_s: 0.680441	adv_loss_t: 0.751754
# Train -> [ 2560/ 5504 (47%)]	loss: 0.570255	cls_loss: 0.023171	adv_loss_s: 0.514917	adv_loss_t: 0.579251
# Train -> [ 5120/ 5504 (93%)]	loss: 0.779495	cls_loss: 0.009466	adv_loss_s: 0.450276	adv_loss_t: 1.089783
# Validation (source) -> cls_loss: 0.046541	accuracy: 98.6867%
# Validation (target) -> cls_loss: 1.582610	accuracy: 67.8375%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.735077	cls_loss: 0.014519	adv_loss_s: 0.428344	adv_loss_t: 1.012773
# Train -> [ 2560/ 5504 (47%)]	loss: 0.800691	cls_loss: 0.023206	adv_loss_s: 0.902496	adv_loss_t: 0.652473
# Train -> [ 5120/ 5504 (93%)]	loss: 0.637192	cls_loss: 0.004863	adv_loss_s: 0.334871	adv_loss_t: 0.929788
# Validation (source) -> cls_loss: 0.046313	accuracy: 98.7133%
# Validation (target) -> cls_loss: 1.193075	accuracy: 71.1306%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.779331	cls_loss: 0.024231	adv_loss_s: 0.518445	adv_loss_t: 0.991756
# Train -> [ 2560/ 5504 (47%)]	loss: 0.534536	cls_loss: 0.044485	adv_loss_s: 0.390160	adv_loss_t: 0.589941
# Train -> [ 5120/ 5504 (93%)]	loss: 0.812900	cls_loss: 0.012108	adv_loss_s: 0.609457	adv_loss_t: 0.992128
# Validation (source) -> cls_loss: 0.044244	accuracy: 98.6933%
# Validation (target) -> cls_loss: 1.020222	accuracy: 75.1921%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.709586	cls_loss: 0.111096	adv_loss_s: 0.392775	adv_loss_t: 0.804205
# Train -> [ 2560/ 5504 (47%)]	loss: 0.735731	cls_loss: 0.017425	adv_loss_s: 0.527988	adv_loss_t: 0.908624
# Train -> [ 5120/ 5504 (93%)]	loss: 0.456073	cls_loss: 0.016680	adv_loss_s: 0.252838	adv_loss_t: 0.625947
# Validation (source) -> cls_loss: 0.055945	accuracy: 98.3333%
# Validation (target) -> cls_loss: 0.900685	accuracy: 78.0461%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.801710	cls_loss: 0.015317	adv_loss_s: 0.625219	adv_loss_t: 0.947566
# Train -> [ 2560/ 5504 (47%)]	loss: 1.090020	cls_loss: 0.007195	adv_loss_s: 1.041615	adv_loss_t: 1.124036
# Train -> [ 5120/ 5504 (93%)]	loss: 0.797614	cls_loss: 0.032973	adv_loss_s: 0.434219	adv_loss_t: 1.095062
# Validation (source) -> cls_loss: 0.055841	accuracy: 98.2733%
# Validation (target) -> cls_loss: 1.487111	accuracy: 69.5939%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.548272	cls_loss: 0.018140	adv_loss_s: 0.569611	adv_loss_t: 0.490653
# Train -> [ 2560/ 5504 (47%)]	loss: 0.782484	cls_loss: 0.002473	adv_loss_s: 0.918674	adv_loss_t: 0.641348
# Train -> [ 5120/ 5504 (93%)]	loss: 0.523275	cls_loss: 0.023026	adv_loss_s: 0.444595	adv_loss_t: 0.555903
# Validation (source) -> cls_loss: 0.042754	accuracy: 98.7867%
# Validation (target) -> cls_loss: 1.250951	accuracy: 72.3930%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.599529	cls_loss: 0.028702	adv_loss_s: 0.491133	adv_loss_t: 0.650521
# Train -> [ 2560/ 5504 (47%)]	loss: 0.762920	cls_loss: 0.010416	adv_loss_s: 0.555696	adv_loss_t: 0.949312
# Train -> [ 5120/ 5504 (93%)]	loss: 0.876761	cls_loss: 0.006840	adv_loss_s: 0.649849	adv_loss_t: 1.089992
# Validation (source) -> cls_loss: 0.052816	accuracy: 98.6267%
# Validation (target) -> cls_loss: 1.689933	accuracy: 66.5203%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.915975	cls_loss: 0.004209	adv_loss_s: 0.706574	adv_loss_t: 1.116957
# Train -> [ 2560/ 5504 (47%)]	loss: 1.030578	cls_loss: 0.000797	adv_loss_s: 0.631550	adv_loss_t: 1.428013
# Train -> [ 5120/ 5504 (93%)]	loss: 0.900908	cls_loss: 0.013531	adv_loss_s: 0.524982	adv_loss_t: 1.249772
# Validation (source) -> cls_loss: 0.045789	accuracy: 98.7733%
# Validation (target) -> cls_loss: 1.237780	accuracy: 70.9111%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.489311	cls_loss: 0.006039	adv_loss_s: 0.669718	adv_loss_t: 0.296825
# Train -> [ 2560/ 5504 (47%)]	loss: 0.599545	cls_loss: 0.002387	adv_loss_s: 0.502608	adv_loss_t: 0.691707
# Train -> [ 5120/ 5504 (93%)]	loss: 0.819773	cls_loss: 0.030086	adv_loss_s: 0.564004	adv_loss_t: 1.015370
# Validation (source) -> cls_loss: 0.049103	accuracy: 98.6133%
# Validation (target) -> cls_loss: 1.355882	accuracy: 68.8255%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.587928	cls_loss: 0.012216	adv_loss_s: 0.487083	adv_loss_t: 0.664341
# Train -> [ 2560/ 5504 (47%)]	loss: 0.636841	cls_loss: 0.044409	adv_loss_s: 0.662335	adv_loss_t: 0.522530
# Train -> [ 5120/ 5504 (93%)]	loss: 0.551065	cls_loss: 0.013322	adv_loss_s: 0.331863	adv_loss_t: 0.743622
# Validation (source) -> cls_loss: 0.050195	accuracy: 98.7200%
# Validation (target) -> cls_loss: 1.779304	accuracy: 66.1910%

# %%
plot_losses(
    list(all_loss.T),
    loss_labels,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training (source)'
)
plot_losses(
    list(all_loss_val_s.T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation (source)'
)
plot_losses(
    list(all_loss_val_t.T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation (target)'
)

# %%
classifier.load_state_dict(torch.load(model_save_path))
evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
# Out:
# Test (source) -> cls_loss: 0.066760	accuracy: 97.8500%
# Test (target) -> cls_loss: 0.716733	accuracy: 76.9806%
# (0.7167329508811235, 0.7698056801195815)
