# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('../data', train=True,  download=True, transform=transform)
    test_set  = dataset('../data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor   = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
    
    def forward(self, x):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x = self.class_regressor(x)
        return x

# %% [markdown]
# ## Domain discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_features: int, hidden_size: int):
        super().__init__()
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=hidden_size, nhead=1), num_layers=1
        )
        self.op_layer = nn.Sequential(nn.Linear(hidden_size, 1), nn.Sigmoid())
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        x = self.transformer(x)
        x = self.op_layer(x)
        return x

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & dataset creation

# %%
lr_c = 1e-3
lr_d = 1e-10
batch_size = 128
model_save_path = 'best_model.pt'

num_epochs = 50
checkpoint = 20

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred = model_c(x)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha):
    N = xs.shape[0]
    
    xs = classifier.feature_extractor(xs)
    xs = torch.flatten(xs, start_dim=1)
    xt = classifier.feature_extractor(xt)
    xt = torch.flatten(xt, start_dim=1)
    
    ####
    # discriminator training
    ####
    label_s = torch.zeros(N, 1, device=device)
    label_t = torch.ones(N, 1, device=device)
    
    pt_s = discriminator(xs.detach())
    pt_t = discriminator(xt.detach())
    
    adv_loss_s = adv_loss_fn(pt_s, label_s)
    adv_loss_t = adv_loss_fn(pt_t, label_t)
    
    loss_d = (adv_loss_s + adv_loss_t)/2
    optimizer_d.zero_grad()
    loss_d.backward()
    optimizer_d.step()
    
    ####
    # classifier training
    ####
    ys_pred = classifier.class_regressor(xs)
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    
    pt_s_c = discriminator(xs)
    pt_t_c = discriminator(xt)
    
    # classifier tries to trick discriminator
    adv_loss_s_c = adv_loss_fn(pt_s_c, label_t)
    adv_loss_t_c = adv_loss_fn(pt_t_c, label_s)
    
    loss_c = cls_loss + alpha*(adv_loss_s_c + adv_loss_t_c)/2
    optimizer_c.zero_grad()
    cls_loss.backward()
    optimizer_c.step()
    
    return (loss_c.item(),
            cls_loss.item(),
            adv_loss_s_c.item(),
            adv_loss_t_c.item())

# %% [markdown]
# # Main

# %%
def main():
    global classifier, discriminator
    global cls_loss_fn, adv_loss_fn
    global optimizer_c, optimizer_d
    global loss_labels_train, loss_labels_val
    
    classifier = MyModel(
        input_shape=(1, 28, 28),
        output_shape=10,
        cnn_out_features=[16, 32, 64],
        fnn_out_features=[128, 64],
    ).to(device)
    discriminator = Discriminator(classifier.class_regressor.in_features, 128).to(device)
    
    print(torchinfo.summary(classifier, input_size=(batch_size, 1, 28, 28)))

    cls_loss_fn = nn.CrossEntropyLoss()
    adv_loss_fn = nn.BCELoss()
    
    optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)
    optimizer_d = torch.optim.Adam(discriminator.parameters(), lr=lr_d)
    
    all_loss = np.zeros((num_epochs, 4))
    loss_labels_train = ['loss', 'cls_loss', 'adv_loss_s', 'adv_loss_t']

    all_loss_val = np.zeros((num_epochs, 4))
    all_loss_test = np.zeros((1, 4))
    loss_labels_val = ['cls_loss_s', 'accuracy_s', 'cls_loss_t', 'accuracy_t']

    best_val_loss = float('inf')
    best_k = 1

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1} --------')

        classifier.train()
        discriminator.train()

        len_dataloader = min(len(train_s), len(train_t))
        iter_s = iter(train_s)
        iter_t = iter(train_t)

        avg_loss = np.zeros(all_loss.shape[1])

        for batch_idx in range(len_dataloader):
            # alpha = (epoch*len_dataloader + batch_idx) / (num_epochs*len_dataloader)
            alpha = 1
            data_s = next(iter_s)
            data_t = next(iter_t)

            xs, ys_true = data_s
            xt, yt_true = data_t
            if xs.shape[0] != xt.shape[0]:
                continue

            xs = xs.to(device)
            xt = xt.to(device)
            ys_true = ys_true.to(device)
            yt_true = yt_true.to(device)

            losses = train_step(xs, xt, ys_true, alpha)
            avg_loss += losses

            if checkpoint is not None and batch_idx % checkpoint == 0:
                print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                        batch_idx * batch_size,
                        len_dataloader * batch_size,
                        batch_idx / len_dataloader * 100
                    ),
                    end='\t'
                )
                for loss, label in zip(losses, loss_labels_train):
                    print(f'{label}: {loss:.6f}', end='\t')
                print('')

        avg_loss = avg_loss / len_dataloader
        all_loss[epoch] = losses

        val_losses_s = evaluate(classifier, val_s, cls_loss_fn, mode='Validation (source)')
        val_losses_t = evaluate(classifier, val_t, cls_loss_fn, mode='Validation (target)')

        all_loss_val[epoch] = val_losses_s + val_losses_t

        val_loss = val_losses_t[0]

        if val_loss < best_val_loss:
            torch.save(classifier.state_dict(), model_save_path)
            best_k = avg_loss[-1]
            best_val_loss = val_loss
            print(f'Best model updated and saved at "{model_save_path}"')
    
    classifier.load_state_dict(torch.load(model_save_path))
    test_loss_s = evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
    test_loss_t = evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
    
    all_loss_test = test_loss_s + test_loss_t
    
    return (all_loss, all_loss_val, all_loss_test)

# %%
all_loss_train = []
all_loss_val   = []
all_loss_test  = []
for i in range(5):
    loss_train, loss_val, loss_test = main()
    all_loss_train.append(loss_train)
    all_loss_val.append(loss_val)
    all_loss_test.append(loss_test)

all_loss_train = np.array(all_loss_train)
all_loss_val   = np.array(all_loss_val)
all_loss_test  = np.array(all_loss_test)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─ClassRegressor: 1-2                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 106,058
# Trainable params: 106,058
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.014998	cls_loss: 2.303488	adv_loss_s: 0.803967	adv_loss_t: 0.619054
# Train -> [ 2560/ 5504 (47%)]	loss: 2.493705	cls_loss: 1.756697	adv_loss_s: 0.851441	adv_loss_t: 0.622576
# Train -> [ 5120/ 5504 (93%)]	loss: 1.392682	cls_loss: 0.647562	adv_loss_s: 0.891913	adv_loss_t: 0.598329
# Validation (source) -> cls_loss: 0.577950	accuracy: 81.3000%
# Validation (target) -> cls_loss: 1.261328	accuracy: 63.6114%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.418757	cls_loss: 0.643527	adv_loss_s: 0.940841	adv_loss_t: 0.609618
# Train -> [ 2560/ 5504 (47%)]	loss: 1.105744	cls_loss: 0.347583	adv_loss_s: 0.930957	adv_loss_t: 0.585364
# Train -> [ 5120/ 5504 (93%)]	loss: 0.995368	cls_loss: 0.250856	adv_loss_s: 0.929367	adv_loss_t: 0.559655
# Validation (source) -> cls_loss: 0.277663	accuracy: 91.3667%
# Validation (target) -> cls_loss: 0.827135	accuracy: 75.5214%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.887876	cls_loss: 0.131785	adv_loss_s: 0.914450	adv_loss_t: 0.597732
# Train -> [ 2560/ 5504 (47%)]	loss: 0.910352	cls_loss: 0.167781	adv_loss_s: 0.905825	adv_loss_t: 0.579318
# Train -> [ 5120/ 5504 (93%)]	loss: 0.887610	cls_loss: 0.126535	adv_loss_s: 0.963472	adv_loss_t: 0.558678
# Validation (source) -> cls_loss: 0.187274	accuracy: 94.6133%
# Validation (target) -> cls_loss: 0.674202	accuracy: 79.3085%
# Best model updated and saved at "best_model.pt"
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.970426	cls_loss: 0.219022	adv_loss_s: 0.940820	adv_loss_t: 0.561988
# Train -> [ 2560/ 5504 (47%)]	loss: 0.979439	cls_loss: 0.205109	adv_loss_s: 0.982721	adv_loss_t: 0.565940
# Train -> [ 5120/ 5504 (93%)]	loss: 0.899870	cls_loss: 0.141349	adv_loss_s: 0.942937	adv_loss_t: 0.574105
# Validation (source) -> cls_loss: 0.140839	accuracy: 95.9333%
# Validation (target) -> cls_loss: 0.805434	accuracy: 75.4116%
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.817998	cls_loss: 0.062245	adv_loss_s: 0.965062	adv_loss_t: 0.546446
# Train -> [ 2560/ 5504 (47%)]	loss: 0.830400	cls_loss: 0.100351	adv_loss_s: 0.923612	adv_loss_t: 0.536486
# Train -> [ 5120/ 5504 (93%)]	loss: 0.872881	cls_loss: 0.119677	adv_loss_s: 0.967751	adv_loss_t: 0.538656
# Validation (source) -> cls_loss: 0.123862	accuracy: 96.3267%
# Validation (target) -> cls_loss: 0.730688	accuracy: 76.1251%
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.930877	cls_loss: 0.180995	adv_loss_s: 0.964028	adv_loss_t: 0.535734
# Train -> [ 2560/ 5504 (47%)]	loss: 0.927634	cls_loss: 0.177040	adv_loss_s: 0.986827	adv_loss_t: 0.514361
# Train -> [ 5120/ 5504 (93%)]	loss: 0.858439	cls_loss: 0.101048	adv_loss_s: 0.999694	adv_loss_t: 0.515088
# Validation (source) -> cls_loss: 0.142608	accuracy: 95.7667%
# Validation (target) -> cls_loss: 0.804011	accuracy: 76.7289%
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.850027	cls_loss: 0.071429	adv_loss_s: 1.011688	adv_loss_t: 0.545506
# Train -> [ 2560/ 5504 (47%)]	loss: 0.867666	cls_loss: 0.096361	adv_loss_s: 1.007592	adv_loss_t: 0.535019
# Train -> [ 5120/ 5504 (93%)]	loss: 0.826135	cls_loss: 0.065251	adv_loss_s: 1.025427	adv_loss_t: 0.496340
# Validation (source) -> cls_loss: 0.101270	accuracy: 96.7800%
# Validation (target) -> cls_loss: 0.704877	accuracy: 76.2898%
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.898800	cls_loss: 0.146171	adv_loss_s: 0.995598	adv_loss_t: 0.509660
# Train -> [ 2560/ 5504 (47%)]	loss: 0.857737	cls_loss: 0.064020	adv_loss_s: 1.070821	adv_loss_t: 0.516613
# Train -> [ 5120/ 5504 (93%)]	loss: 0.873681	cls_loss: 0.095311	adv_loss_s: 1.048091	adv_loss_t: 0.508648
# Validation (source) -> cls_loss: 0.087459	accuracy: 97.2667%
# Validation (target) -> cls_loss: 0.685326	accuracy: 78.7047%
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.896840	cls_loss: 0.137809	adv_loss_s: 1.014005	adv_loss_t: 0.504056
# Train -> [ 2560/ 5504 (47%)]	loss: 0.955960	cls_loss: 0.179139	adv_loss_s: 1.039490	adv_loss_t: 0.514152
# Train -> [ 5120/ 5504 (93%)]	loss: 0.835173	cls_loss: 0.075602	adv_loss_s: 1.018175	adv_loss_t: 0.500967
# Validation (source) -> cls_loss: 0.096580	accuracy: 97.0600%
# Validation (target) -> cls_loss: 0.629180	accuracy: 78.5950%
# Best model updated and saved at "best_model.pt"
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.846101	cls_loss: 0.089507	adv_loss_s: 0.996934	adv_loss_t: 0.516254
# Train -> [ 2560/ 5504 (47%)]	loss: 0.795573	cls_loss: 0.045028	adv_loss_s: 0.968222	adv_loss_t: 0.532867
# Train -> [ 5120/ 5504 (93%)]	loss: 0.843339	cls_loss: 0.065968	adv_loss_s: 1.011825	adv_loss_t: 0.542917
# Validation (source) -> cls_loss: 0.087686	accuracy: 97.3600%
# Validation (target) -> cls_loss: 0.750062	accuracy: 76.8386%
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.874003	cls_loss: 0.102483	adv_loss_s: 1.018306	adv_loss_t: 0.524736
# Train -> [ 2560/ 5504 (47%)]	loss: 0.881460	cls_loss: 0.096976	adv_loss_s: 1.054526	adv_loss_t: 0.514443
# Train -> [ 5120/ 5504 (93%)]	loss: 0.868989	cls_loss: 0.085786	adv_loss_s: 1.047389	adv_loss_t: 0.519016
# Validation (source) -> cls_loss: 0.077227	accuracy: 97.5600%
# Validation (target) -> cls_loss: 0.700009	accuracy: 75.4116%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.805844	cls_loss: 0.022162	adv_loss_s: 1.039074	adv_loss_t: 0.528289
# Train -> [ 2560/ 5504 (47%)]	loss: 0.829121	cls_loss: 0.042578	adv_loss_s: 1.062519	adv_loss_t: 0.510566
# Train -> [ 5120/ 5504 (93%)]	loss: 0.852078	cls_loss: 0.045554	adv_loss_s: 1.061936	adv_loss_t: 0.551113
# Validation (source) -> cls_loss: 0.082675	accuracy: 97.5067%
# Validation (target) -> cls_loss: 1.199318	accuracy: 68.8804%
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.833451	cls_loss: 0.053340	adv_loss_s: 1.018944	adv_loss_t: 0.541279
# Train -> [ 2560/ 5504 (47%)]	loss: 0.932953	cls_loss: 0.153905	adv_loss_s: 1.035533	adv_loss_t: 0.522563
# Train -> [ 5120/ 5504 (93%)]	loss: 0.865623	cls_loss: 0.071916	adv_loss_s: 0.997037	adv_loss_t: 0.590377
# Validation (source) -> cls_loss: 0.072566	accuracy: 97.8267%
# Validation (target) -> cls_loss: 0.736245	accuracy: 76.6740%
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.848282	cls_loss: 0.066323	adv_loss_s: 0.999432	adv_loss_t: 0.564484
# Train -> [ 2560/ 5504 (47%)]	loss: 0.826156	cls_loss: 0.046895	adv_loss_s: 1.006265	adv_loss_t: 0.552257
# Train -> [ 5120/ 5504 (93%)]	loss: 0.809848	cls_loss: 0.019662	adv_loss_s: 1.051325	adv_loss_t: 0.529048
# Validation (source) -> cls_loss: 0.069838	accuracy: 97.8733%
# Validation (target) -> cls_loss: 0.797379	accuracy: 75.9605%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.840395	cls_loss: 0.052767	adv_loss_s: 1.057830	adv_loss_t: 0.517425
# Train -> [ 2560/ 5504 (47%)]	loss: 0.828077	cls_loss: 0.036108	adv_loss_s: 1.068275	adv_loss_t: 0.515662
# Train -> [ 5120/ 5504 (93%)]	loss: 0.841368	cls_loss: 0.053571	adv_loss_s: 1.080299	adv_loss_t: 0.495295
# Validation (source) -> cls_loss: 0.079543	accuracy: 97.6133%
# Validation (target) -> cls_loss: 0.744572	accuracy: 77.6070%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.919321	cls_loss: 0.134765	adv_loss_s: 1.058538	adv_loss_t: 0.510576
# Train -> [ 2560/ 5504 (47%)]	loss: 0.885101	cls_loss: 0.099934	adv_loss_s: 1.053042	adv_loss_t: 0.517292
# Train -> [ 5120/ 5504 (93%)]	loss: 0.816962	cls_loss: 0.042623	adv_loss_s: 1.022828	adv_loss_t: 0.525849
# Validation (source) -> cls_loss: 0.069814	accuracy: 97.8800%
# Validation (target) -> cls_loss: 0.921499	accuracy: 75.0823%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.806043	cls_loss: 0.035035	adv_loss_s: 0.994375	adv_loss_t: 0.547643
# Train -> [ 2560/ 5504 (47%)]	loss: 0.791611	cls_loss: 0.003361	adv_loss_s: 1.087750	adv_loss_t: 0.488750
# Train -> [ 5120/ 5504 (93%)]	loss: 0.850409	cls_loss: 0.056259	adv_loss_s: 1.085951	adv_loss_t: 0.502349
# Validation (source) -> cls_loss: 0.066084	accuracy: 97.9800%
# Validation (target) -> cls_loss: 0.989672	accuracy: 71.6795%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.799356	cls_loss: 0.022692	adv_loss_s: 1.049126	adv_loss_t: 0.504201
# Train -> [ 2560/ 5504 (47%)]	loss: 0.818410	cls_loss: 0.027328	adv_loss_s: 1.035078	adv_loss_t: 0.547085
# Train -> [ 5120/ 5504 (93%)]	loss: 0.876776	cls_loss: 0.133406	adv_loss_s: 0.964065	adv_loss_t: 0.522674
# Validation (source) -> cls_loss: 0.068101	accuracy: 97.7333%
# Validation (target) -> cls_loss: 0.690564	accuracy: 78.0461%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.864837	cls_loss: 0.058097	adv_loss_s: 1.080070	adv_loss_t: 0.533410
# Train -> [ 2560/ 5504 (47%)]	loss: 0.810069	cls_loss: 0.025495	adv_loss_s: 1.019086	adv_loss_t: 0.550063
# Train -> [ 5120/ 5504 (93%)]	loss: 0.827889	cls_loss: 0.044908	adv_loss_s: 1.085477	adv_loss_t: 0.480486
# Validation (source) -> cls_loss: 0.055930	accuracy: 98.2733%
# Validation (target) -> cls_loss: 1.103273	accuracy: 68.7157%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.856934	cls_loss: 0.076719	adv_loss_s: 1.045872	adv_loss_t: 0.514559
# Train -> [ 2560/ 5504 (47%)]	loss: 0.850889	cls_loss: 0.049031	adv_loss_s: 1.094995	adv_loss_t: 0.508722
# Train -> [ 5120/ 5504 (93%)]	loss: 0.828905	cls_loss: 0.033980	adv_loss_s: 1.105026	adv_loss_t: 0.484825
# Validation (source) -> cls_loss: 0.065518	accuracy: 98.0200%
# Validation (target) -> cls_loss: 0.988945	accuracy: 71.6795%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.867612	cls_loss: 0.075816	adv_loss_s: 1.071136	adv_loss_t: 0.512456
# Train -> [ 2560/ 5504 (47%)]	loss: 0.833318	cls_loss: 0.012624	adv_loss_s: 1.093542	adv_loss_t: 0.547847
# Train -> [ 5120/ 5504 (93%)]	loss: 0.791020	cls_loss: 0.027954	adv_loss_s: 1.049102	adv_loss_t: 0.477030
# Validation (source) -> cls_loss: 0.056455	accuracy: 98.1800%
# Validation (target) -> cls_loss: 0.959925	accuracy: 73.8749%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.839624	cls_loss: 0.031197	adv_loss_s: 1.073647	adv_loss_t: 0.543206
# Train -> [ 2560/ 5504 (47%)]	loss: 0.846590	cls_loss: 0.071522	adv_loss_s: 1.030662	adv_loss_t: 0.519474
# Train -> [ 5120/ 5504 (93%)]	loss: 0.794808	cls_loss: 0.016642	adv_loss_s: 1.021366	adv_loss_t: 0.534965
# Validation (source) -> cls_loss: 0.060983	accuracy: 98.2467%
# Validation (target) -> cls_loss: 0.807590	accuracy: 74.9726%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.844438	cls_loss: 0.042718	adv_loss_s: 1.053596	adv_loss_t: 0.549844
# Train -> [ 2560/ 5504 (47%)]	loss: 0.818707	cls_loss: 0.017571	adv_loss_s: 1.031746	adv_loss_t: 0.570526
# Train -> [ 5120/ 5504 (93%)]	loss: 0.801385	cls_loss: 0.023417	adv_loss_s: 1.015872	adv_loss_t: 0.540063
# Validation (source) -> cls_loss: 0.052877	accuracy: 98.3400%
# Validation (target) -> cls_loss: 1.016253	accuracy: 69.9232%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.813595	cls_loss: 0.025110	adv_loss_s: 1.033698	adv_loss_t: 0.543272
# Train -> [ 2560/ 5504 (47%)]	loss: 0.812388	cls_loss: 0.032893	adv_loss_s: 1.041700	adv_loss_t: 0.517290
# Train -> [ 5120/ 5504 (93%)]	loss: 0.856052	cls_loss: 0.029967	adv_loss_s: 1.117428	adv_loss_t: 0.534743
# Validation (source) -> cls_loss: 0.069709	accuracy: 97.6600%
# Validation (target) -> cls_loss: 1.088660	accuracy: 71.7892%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.803358	cls_loss: 0.008852	adv_loss_s: 1.074332	adv_loss_t: 0.514678
# Train -> [ 2560/ 5504 (47%)]	loss: 0.864914	cls_loss: 0.054420	adv_loss_s: 1.086782	adv_loss_t: 0.534205
# Train -> [ 5120/ 5504 (93%)]	loss: 0.833137	cls_loss: 0.019968	adv_loss_s: 1.060641	adv_loss_t: 0.565697
# Validation (source) -> cls_loss: 0.056785	accuracy: 98.2933%
# Validation (target) -> cls_loss: 1.025849	accuracy: 71.6246%
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.833193	cls_loss: 0.016545	adv_loss_s: 1.076807	adv_loss_t: 0.556488
# Train -> [ 2560/ 5504 (47%)]	loss: 0.806892	cls_loss: 0.011500	adv_loss_s: 1.075905	adv_loss_t: 0.514878
# Train -> [ 5120/ 5504 (93%)]	loss: 0.794239	cls_loss: 0.003639	adv_loss_s: 1.051417	adv_loss_t: 0.529783
# Validation (source) -> cls_loss: 0.050271	accuracy: 98.4267%
# Validation (target) -> cls_loss: 0.917915	accuracy: 73.5456%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.837083	cls_loss: 0.048887	adv_loss_s: 1.047132	adv_loss_t: 0.529261
# Train -> [ 2560/ 5504 (47%)]	loss: 0.826059	cls_loss: 0.051909	adv_loss_s: 1.055245	adv_loss_t: 0.493055
# Train -> [ 5120/ 5504 (93%)]	loss: 0.889922	cls_loss: 0.048435	adv_loss_s: 1.153410	adv_loss_t: 0.529565
# Validation (source) -> cls_loss: 0.058834	accuracy: 98.0333%
# Validation (target) -> cls_loss: 1.287020	accuracy: 68.2766%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.862512	cls_loss: 0.028272	adv_loss_s: 1.138108	adv_loss_t: 0.530373
# Train -> [ 2560/ 5504 (47%)]	loss: 0.857163	cls_loss: 0.042847	adv_loss_s: 1.086929	adv_loss_t: 0.541703
# Train -> [ 5120/ 5504 (93%)]	loss: 0.822654	cls_loss: 0.005844	adv_loss_s: 1.099924	adv_loss_t: 0.533697
# Validation (source) -> cls_loss: 0.044319	accuracy: 98.6600%
# Validation (target) -> cls_loss: 1.421877	accuracy: 64.1603%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.813992	cls_loss: 0.023108	adv_loss_s: 1.087605	adv_loss_t: 0.494163
# Train -> [ 2560/ 5504 (47%)]	loss: 0.810716	cls_loss: 0.003764	adv_loss_s: 1.078879	adv_loss_t: 0.535025
# Train -> [ 5120/ 5504 (93%)]	loss: 0.816664	cls_loss: 0.015460	adv_loss_s: 1.103666	adv_loss_t: 0.498741
# Validation (source) -> cls_loss: 0.051730	accuracy: 98.4067%
# Validation (target) -> cls_loss: 1.257099	accuracy: 68.3315%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.845124	cls_loss: 0.048020	adv_loss_s: 1.071140	adv_loss_t: 0.523069
# Train -> [ 2560/ 5504 (47%)]	loss: 0.807822	cls_loss: 0.004045	adv_loss_s: 1.102609	adv_loss_t: 0.504945
# Train -> [ 5120/ 5504 (93%)]	loss: 0.832392	cls_loss: 0.042462	adv_loss_s: 1.060559	adv_loss_t: 0.519301
# Validation (source) -> cls_loss: 0.053927	accuracy: 98.3133%
# Validation (target) -> cls_loss: 1.127049	accuracy: 70.7464%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.828579	cls_loss: 0.033857	adv_loss_s: 1.081729	adv_loss_t: 0.507716
# Train -> [ 2560/ 5504 (47%)]	loss: 0.825422	cls_loss: 0.032208	adv_loss_s: 1.057470	adv_loss_t: 0.528958
# Train -> [ 5120/ 5504 (93%)]	loss: 0.821730	cls_loss: 0.025405	adv_loss_s: 1.027496	adv_loss_t: 0.565154
# Validation (source) -> cls_loss: 0.043955	accuracy: 98.6267%
# Validation (target) -> cls_loss: 1.459077	accuracy: 64.6542%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.824608	cls_loss: 0.008561	adv_loss_s: 1.105131	adv_loss_t: 0.526963
# Train -> [ 2560/ 5504 (47%)]	loss: 0.823786	cls_loss: 0.023185	adv_loss_s: 1.053846	adv_loss_t: 0.547355
# Train -> [ 5120/ 5504 (93%)]	loss: 0.815202	cls_loss: 0.005712	adv_loss_s: 1.085939	adv_loss_t: 0.533041
# Validation (source) -> cls_loss: 0.047835	accuracy: 98.5133%
# Validation (target) -> cls_loss: 1.392478	accuracy: 66.3557%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.867611	cls_loss: 0.036173	adv_loss_s: 1.108024	adv_loss_t: 0.554852
# Train -> [ 2560/ 5504 (47%)]	loss: 0.836726	cls_loss: 0.037492	adv_loss_s: 1.066519	adv_loss_t: 0.531950
# Train -> [ 5120/ 5504 (93%)]	loss: 0.792264	cls_loss: 0.020152	adv_loss_s: 1.027329	adv_loss_t: 0.516893
# Validation (source) -> cls_loss: 0.056141	accuracy: 98.1800%
# Validation (target) -> cls_loss: 1.182158	accuracy: 69.8134%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.767137	cls_loss: 0.004447	adv_loss_s: 1.006897	adv_loss_t: 0.518482
# Train -> [ 2560/ 5504 (47%)]	loss: 0.855489	cls_loss: 0.028665	adv_loss_s: 1.114035	adv_loss_t: 0.539613
# Train -> [ 5120/ 5504 (93%)]	loss: 0.812029	cls_loss: 0.016144	adv_loss_s: 1.073310	adv_loss_t: 0.518460
# Validation (source) -> cls_loss: 0.049215	accuracy: 98.4800%
# Validation (target) -> cls_loss: 1.031489	accuracy: 70.4720%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.774194	cls_loss: 0.004062	adv_loss_s: 1.052748	adv_loss_t: 0.487516
# Train -> [ 2560/ 5504 (47%)]	loss: 0.808787	cls_loss: 0.012775	adv_loss_s: 1.102329	adv_loss_t: 0.489695
# Train -> [ 5120/ 5504 (93%)]	loss: 0.851643	cls_loss: 0.039705	adv_loss_s: 1.131459	adv_loss_t: 0.492418
# Validation (source) -> cls_loss: 0.050445	accuracy: 98.4733%
# Validation (target) -> cls_loss: 1.159695	accuracy: 71.6795%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.850240	cls_loss: 0.040528	adv_loss_s: 1.120695	adv_loss_t: 0.498729
# Train -> [ 2560/ 5504 (47%)]	loss: 0.885725	cls_loss: 0.087980	adv_loss_s: 1.095253	adv_loss_t: 0.500238
# Train -> [ 5120/ 5504 (93%)]	loss: 0.811958	cls_loss: 0.048487	adv_loss_s: 0.990782	adv_loss_t: 0.536160
# Validation (source) -> cls_loss: 0.061134	accuracy: 98.3533%
# Validation (target) -> cls_loss: 1.255156	accuracy: 67.9473%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.771386	cls_loss: 0.024114	adv_loss_s: 0.980787	adv_loss_t: 0.513757
# Train -> [ 2560/ 5504 (47%)]	loss: 0.833646	cls_loss: 0.016775	adv_loss_s: 1.103760	adv_loss_t: 0.529982
# Train -> [ 5120/ 5504 (93%)]	loss: 0.796008	cls_loss: 0.027987	adv_loss_s: 1.020252	adv_loss_t: 0.515791
# Validation (source) -> cls_loss: 0.051560	accuracy: 98.6067%
# Validation (target) -> cls_loss: 1.472607	accuracy: 65.6422%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.847558	cls_loss: 0.047732	adv_loss_s: 1.045446	adv_loss_t: 0.554205
# Train -> [ 2560/ 5504 (47%)]	loss: 0.842091	cls_loss: 0.041780	adv_loss_s: 1.102416	adv_loss_t: 0.498204
# Train -> [ 5120/ 5504 (93%)]	loss: 0.839840	cls_loss: 0.042237	adv_loss_s: 1.079144	adv_loss_t: 0.516061
# Validation (source) -> cls_loss: 0.055471	accuracy: 98.3667%
# Validation (target) -> cls_loss: 1.382363	accuracy: 68.3864%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.814470	cls_loss: 0.012545	adv_loss_s: 1.110360	adv_loss_t: 0.493491
# Train -> [ 2560/ 5504 (47%)]	loss: 0.802198	cls_loss: 0.008401	adv_loss_s: 1.046021	adv_loss_t: 0.541574
# Train -> [ 5120/ 5504 (93%)]	loss: 0.791969	cls_loss: 0.010810	adv_loss_s: 1.024931	adv_loss_t: 0.537387
# Validation (source) -> cls_loss: 0.046672	accuracy: 98.6400%
# Validation (target) -> cls_loss: 1.326325	accuracy: 68.2766%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.794005	cls_loss: 0.006152	adv_loss_s: 1.057294	adv_loss_t: 0.518413
# Train -> [ 2560/ 5504 (47%)]	loss: 0.784118	cls_loss: 0.013738	adv_loss_s: 1.005002	adv_loss_t: 0.535757
# Train -> [ 5120/ 5504 (93%)]	loss: 0.836351	cls_loss: 0.011841	adv_loss_s: 1.119493	adv_loss_t: 0.529528
# Validation (source) -> cls_loss: 0.046268	accuracy: 98.5667%
# Validation (target) -> cls_loss: 1.289602	accuracy: 69.4292%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.798094	cls_loss: 0.030372	adv_loss_s: 1.012724	adv_loss_t: 0.522719
# Train -> [ 2560/ 5504 (47%)]	loss: 0.825747	cls_loss: 0.018877	adv_loss_s: 1.055294	adv_loss_t: 0.558445
# Train -> [ 5120/ 5504 (93%)]	loss: 0.805123	cls_loss: 0.007464	adv_loss_s: 1.069463	adv_loss_t: 0.525854
# Validation (source) -> cls_loss: 0.048332	accuracy: 98.5533%
# Validation (target) -> cls_loss: 1.332902	accuracy: 70.7464%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.876229	cls_loss: 0.039134	adv_loss_s: 1.141313	adv_loss_t: 0.532877
# Train -> [ 2560/ 5504 (47%)]	loss: 0.792355	cls_loss: 0.001606	adv_loss_s: 1.045716	adv_loss_t: 0.535782
# Train -> [ 5120/ 5504 (93%)]	loss: 0.870640	cls_loss: 0.054286	adv_loss_s: 1.106166	adv_loss_t: 0.526541
# Validation (source) -> cls_loss: 0.057493	accuracy: 98.3133%
# Validation (target) -> cls_loss: 1.611595	accuracy: 68.3315%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.838884	cls_loss: 0.030223	adv_loss_s: 1.104717	adv_loss_t: 0.512604
# Train -> [ 2560/ 5504 (47%)]	loss: 0.836066	cls_loss: 0.013438	adv_loss_s: 1.077155	adv_loss_t: 0.568101
# Train -> [ 5120/ 5504 (93%)]	loss: 0.824284	cls_loss: 0.004389	adv_loss_s: 1.097058	adv_loss_t: 0.542733
# Validation (source) -> cls_loss: 0.043685	accuracy: 98.7333%
# Validation (target) -> cls_loss: 1.162629	accuracy: 72.5027%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.895710	cls_loss: 0.047215	adv_loss_s: 1.135936	adv_loss_t: 0.561053
# Train -> [ 2560/ 5504 (47%)]	loss: 0.799390	cls_loss: 0.004611	adv_loss_s: 1.035018	adv_loss_t: 0.554541
# Train -> [ 5120/ 5504 (93%)]	loss: 0.841208	cls_loss: 0.022240	adv_loss_s: 1.074088	adv_loss_t: 0.563849
# Validation (source) -> cls_loss: 0.044030	accuracy: 98.7667%
# Validation (target) -> cls_loss: 1.882626	accuracy: 64.2700%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.807936	cls_loss: 0.011014	adv_loss_s: 0.984442	adv_loss_t: 0.609402
# Train -> [ 2560/ 5504 (47%)]	loss: 0.815093	cls_loss: 0.010625	adv_loss_s: 1.039622	adv_loss_t: 0.569313
# Train -> [ 5120/ 5504 (93%)]	loss: 0.840059	cls_loss: 0.039221	adv_loss_s: 1.036064	adv_loss_t: 0.565612
# Validation (source) -> cls_loss: 0.040300	accuracy: 98.8400%
# Validation (target) -> cls_loss: 1.196151	accuracy: 69.4841%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.810875	cls_loss: 0.002654	adv_loss_s: 1.025657	adv_loss_t: 0.590784
# Train -> [ 2560/ 5504 (47%)]	loss: 0.932996	cls_loss: 0.087762	adv_loss_s: 1.092417	adv_loss_t: 0.598052
# Train -> [ 5120/ 5504 (93%)]	loss: 0.891084	cls_loss: 0.042215	adv_loss_s: 1.069003	adv_loss_t: 0.628736
# Validation (source) -> cls_loss: 0.044234	accuracy: 98.6733%
# Validation (target) -> cls_loss: 1.025552	accuracy: 72.9418%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.800137	cls_loss: 0.004532	adv_loss_s: 1.026679	adv_loss_t: 0.564531
# Train -> [ 2560/ 5504 (47%)]	loss: 0.811760	cls_loss: 0.016440	adv_loss_s: 1.067945	adv_loss_t: 0.522696
# Train -> [ 5120/ 5504 (93%)]	loss: 0.868533	cls_loss: 0.042985	adv_loss_s: 1.091291	adv_loss_t: 0.559803
# Validation (source) -> cls_loss: 0.041496	accuracy: 98.7467%
# Validation (target) -> cls_loss: 1.260101	accuracy: 67.5082%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.819220	cls_loss: 0.011935	adv_loss_s: 1.055741	adv_loss_t: 0.558828
# Train -> [ 2560/ 5504 (47%)]	loss: 0.854632	cls_loss: 0.016761	adv_loss_s: 1.110357	adv_loss_t: 0.565386
# Train -> [ 5120/ 5504 (93%)]	loss: 0.876636	cls_loss: 0.025206	adv_loss_s: 1.132455	adv_loss_t: 0.570405
# Validation (source) -> cls_loss: 0.042257	accuracy: 98.7400%
# Validation (target) -> cls_loss: 1.639186	accuracy: 64.6542%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.837383	cls_loss: 0.004271	adv_loss_s: 1.109216	adv_loss_t: 0.557008
# Train -> [ 2560/ 5504 (47%)]	loss: 0.821559	cls_loss: 0.001737	adv_loss_s: 1.105972	adv_loss_t: 0.533673
# Train -> [ 5120/ 5504 (93%)]	loss: 0.860293	cls_loss: 0.014286	adv_loss_s: 1.103752	adv_loss_t: 0.588262
# Validation (source) -> cls_loss: 0.044015	accuracy: 98.7733%
# Validation (target) -> cls_loss: 1.281503	accuracy: 69.2097%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.834743	cls_loss: 0.015649	adv_loss_s: 1.079471	adv_loss_t: 0.558718
# Train -> [ 2560/ 5504 (47%)]	loss: 0.892031	cls_loss: 0.049057	adv_loss_s: 1.108897	adv_loss_t: 0.577052
# Train -> [ 5120/ 5504 (93%)]	loss: 0.933533	cls_loss: 0.131881	adv_loss_s: 1.053407	adv_loss_t: 0.549898
# Validation (source) -> cls_loss: 0.047809	accuracy: 98.5400%
# Validation (target) -> cls_loss: 1.759893	accuracy: 61.7453%
# Test (source) -> cls_loss: 0.081547	accuracy: 97.3900%
# Test (target) -> cls_loss: 0.723738	accuracy: 75.8844%
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─ClassRegressor: 1-2                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 106,058
# Trainable params: 106,058
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.134316	cls_loss: 2.303582	adv_loss_s: 1.347670	adv_loss_t: 0.313797
# Train -> [ 2560/ 5504 (47%)]	loss: 2.344438	cls_loss: 1.491707	adv_loss_s: 1.336633	adv_loss_t: 0.368828
# Train -> [ 5120/ 5504 (93%)]	loss: 1.536383	cls_loss: 0.676761	adv_loss_s: 1.293944	adv_loss_t: 0.425300
# Validation (source) -> cls_loss: 0.610433	accuracy: 80.1800%
# Validation (target) -> cls_loss: 1.522454	accuracy: 54.0066%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.517802	cls_loss: 0.695147	adv_loss_s: 1.252535	adv_loss_t: 0.392776
# Train -> [ 2560/ 5504 (47%)]	loss: 1.066692	cls_loss: 0.267865	adv_loss_s: 1.138420	adv_loss_t: 0.459232
# Train -> [ 5120/ 5504 (93%)]	loss: 0.996077	cls_loss: 0.221586	adv_loss_s: 1.048429	adv_loss_t: 0.500553
# Validation (source) -> cls_loss: 0.327324	accuracy: 89.3067%
# Validation (target) -> cls_loss: 0.848078	accuracy: 71.6246%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.190976	cls_loss: 0.420381	adv_loss_s: 1.032633	adv_loss_t: 0.508557
# Train -> [ 2560/ 5504 (47%)]	loss: 1.031611	cls_loss: 0.252663	adv_loss_s: 1.033959	adv_loss_t: 0.523937
# Train -> [ 5120/ 5504 (93%)]	loss: 1.021395	cls_loss: 0.251093	adv_loss_s: 1.039021	adv_loss_t: 0.501583
# Validation (source) -> cls_loss: 0.188173	accuracy: 94.3267%
# Validation (target) -> cls_loss: 0.792182	accuracy: 74.7530%
# Best model updated and saved at "best_model.pt"
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.001536	cls_loss: 0.239002	adv_loss_s: 1.015507	adv_loss_t: 0.509561
# Train -> [ 2560/ 5504 (47%)]	loss: 1.064670	cls_loss: 0.308885	adv_loss_s: 1.036922	adv_loss_t: 0.474647
# Train -> [ 5120/ 5504 (93%)]	loss: 0.920407	cls_loss: 0.142332	adv_loss_s: 1.015302	adv_loss_t: 0.540847
# Validation (source) -> cls_loss: 0.167901	accuracy: 94.9800%
# Validation (target) -> cls_loss: 0.749666	accuracy: 76.9484%
# Best model updated and saved at "best_model.pt"
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.891325	cls_loss: 0.147078	adv_loss_s: 0.929297	adv_loss_t: 0.559198
# Train -> [ 2560/ 5504 (47%)]	loss: 0.967648	cls_loss: 0.218780	adv_loss_s: 0.961545	adv_loss_t: 0.536192
# Train -> [ 5120/ 5504 (93%)]	loss: 0.858609	cls_loss: 0.108929	adv_loss_s: 0.957388	adv_loss_t: 0.541973
# Validation (source) -> cls_loss: 0.126901	accuracy: 96.1600%
# Validation (target) -> cls_loss: 0.714007	accuracy: 76.8935%
# Best model updated and saved at "best_model.pt"
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.802620	cls_loss: 0.054108	adv_loss_s: 0.961238	adv_loss_t: 0.535786
# Train -> [ 2560/ 5504 (47%)]	loss: 0.797570	cls_loss: 0.032354	adv_loss_s: 0.998966	adv_loss_t: 0.531466
# Train -> [ 5120/ 5504 (93%)]	loss: 0.879671	cls_loss: 0.124575	adv_loss_s: 0.919887	adv_loss_t: 0.590304
# Validation (source) -> cls_loss: 0.123751	accuracy: 96.2133%
# Validation (target) -> cls_loss: 0.659573	accuracy: 79.1987%
# Best model updated and saved at "best_model.pt"
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.850081	cls_loss: 0.104372	adv_loss_s: 0.923800	adv_loss_t: 0.567618
# Train -> [ 2560/ 5504 (47%)]	loss: 0.856624	cls_loss: 0.098704	adv_loss_s: 0.925357	adv_loss_t: 0.590484
# Train -> [ 5120/ 5504 (93%)]	loss: 0.824075	cls_loss: 0.083544	adv_loss_s: 0.907755	adv_loss_t: 0.573306
# Validation (source) -> cls_loss: 0.103497	accuracy: 96.7667%
# Validation (target) -> cls_loss: 0.756011	accuracy: 76.3447%
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.824976	cls_loss: 0.097070	adv_loss_s: 0.862301	adv_loss_t: 0.593511
# Train -> [ 2560/ 5504 (47%)]	loss: 0.860494	cls_loss: 0.077141	adv_loss_s: 0.946379	adv_loss_t: 0.620328
# Train -> [ 5120/ 5504 (93%)]	loss: 0.875140	cls_loss: 0.118982	adv_loss_s: 0.896318	adv_loss_t: 0.615998
# Validation (source) -> cls_loss: 0.090906	accuracy: 97.1867%
# Validation (target) -> cls_loss: 0.760187	accuracy: 75.3019%
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.859355	cls_loss: 0.084678	adv_loss_s: 0.910197	adv_loss_t: 0.639156
# Train -> [ 2560/ 5504 (47%)]	loss: 0.850134	cls_loss: 0.107190	adv_loss_s: 0.824203	adv_loss_t: 0.661687
# Train -> [ 5120/ 5504 (93%)]	loss: 0.834906	cls_loss: 0.118401	adv_loss_s: 0.831710	adv_loss_t: 0.601300
# Validation (source) -> cls_loss: 0.091829	accuracy: 97.1533%
# Validation (target) -> cls_loss: 0.862717	accuracy: 74.0395%
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.811717	cls_loss: 0.071276	adv_loss_s: 0.843544	adv_loss_t: 0.637339
# Train -> [ 2560/ 5504 (47%)]	loss: 0.831642	cls_loss: 0.104481	adv_loss_s: 0.826623	adv_loss_t: 0.627698
# Train -> [ 5120/ 5504 (93%)]	loss: 0.810788	cls_loss: 0.086020	adv_loss_s: 0.827790	adv_loss_t: 0.621746
# Validation (source) -> cls_loss: 0.101114	accuracy: 96.8200%
# Validation (target) -> cls_loss: 0.994980	accuracy: 71.7892%
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.764198	cls_loss: 0.026242	adv_loss_s: 0.841526	adv_loss_t: 0.634387
# Train -> [ 2560/ 5504 (47%)]	loss: 0.830258	cls_loss: 0.081126	adv_loss_s: 0.841949	adv_loss_t: 0.656313
# Train -> [ 5120/ 5504 (93%)]	loss: 0.814125	cls_loss: 0.055431	adv_loss_s: 0.809329	adv_loss_t: 0.708060
# Validation (source) -> cls_loss: 0.077421	accuracy: 97.6533%
# Validation (target) -> cls_loss: 0.865550	accuracy: 74.3139%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.817901	cls_loss: 0.054986	adv_loss_s: 0.803911	adv_loss_t: 0.721918
# Train -> [ 2560/ 5504 (47%)]	loss: 0.898946	cls_loss: 0.154432	adv_loss_s: 0.786034	adv_loss_t: 0.702995
# Train -> [ 5120/ 5504 (93%)]	loss: 0.802045	cls_loss: 0.053275	adv_loss_s: 0.800463	adv_loss_t: 0.697079
# Validation (source) -> cls_loss: 0.078388	accuracy: 97.5467%
# Validation (target) -> cls_loss: 0.755603	accuracy: 77.3326%
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.763873	cls_loss: 0.041240	adv_loss_s: 0.774162	adv_loss_t: 0.671103
# Train -> [ 2560/ 5504 (47%)]	loss: 0.844969	cls_loss: 0.115883	adv_loss_s: 0.777507	adv_loss_t: 0.680666
# Train -> [ 5120/ 5504 (93%)]	loss: 0.884590	cls_loss: 0.126095	adv_loss_s: 0.822932	adv_loss_t: 0.694057
# Validation (source) -> cls_loss: 0.076177	accuracy: 97.7000%
# Validation (target) -> cls_loss: 0.824474	accuracy: 75.6861%
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.888285	cls_loss: 0.087992	adv_loss_s: 0.881790	adv_loss_t: 0.718796
# Train -> [ 2560/ 5504 (47%)]	loss: 0.810668	cls_loss: 0.060747	adv_loss_s: 0.787292	adv_loss_t: 0.712550
# Train -> [ 5120/ 5504 (93%)]	loss: 0.813141	cls_loss: 0.052053	adv_loss_s: 0.805997	adv_loss_t: 0.716179
# Validation (source) -> cls_loss: 0.101585	accuracy: 96.9067%
# Validation (target) -> cls_loss: 1.082161	accuracy: 69.2645%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.828615	cls_loss: 0.079579	adv_loss_s: 0.809928	adv_loss_t: 0.688144
# Train -> [ 2560/ 5504 (47%)]	loss: 0.806309	cls_loss: 0.045319	adv_loss_s: 0.779997	adv_loss_t: 0.741982
# Train -> [ 5120/ 5504 (93%)]	loss: 0.791739	cls_loss: 0.063230	adv_loss_s: 0.759821	adv_loss_t: 0.697195
# Validation (source) -> cls_loss: 0.091011	accuracy: 97.0133%
# Validation (target) -> cls_loss: 0.776036	accuracy: 75.3019%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.821204	cls_loss: 0.091264	adv_loss_s: 0.724107	adv_loss_t: 0.735773
# Train -> [ 2560/ 5504 (47%)]	loss: 0.813791	cls_loss: 0.078462	adv_loss_s: 0.719796	adv_loss_t: 0.750861
# Train -> [ 5120/ 5504 (93%)]	loss: 0.759656	cls_loss: 0.039751	adv_loss_s: 0.734097	adv_loss_t: 0.705714
# Validation (source) -> cls_loss: 0.069841	accuracy: 97.8467%
# Validation (target) -> cls_loss: 0.825247	accuracy: 75.1372%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.763731	cls_loss: 0.043411	adv_loss_s: 0.697756	adv_loss_t: 0.742884
# Train -> [ 2560/ 5504 (47%)]	loss: 0.774923	cls_loss: 0.040156	adv_loss_s: 0.751882	adv_loss_t: 0.717652
# Train -> [ 5120/ 5504 (93%)]	loss: 0.806510	cls_loss: 0.067835	adv_loss_s: 0.775787	adv_loss_t: 0.701563
# Validation (source) -> cls_loss: 0.071517	accuracy: 97.8267%
# Validation (target) -> cls_loss: 1.071649	accuracy: 70.5818%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.793572	cls_loss: 0.061130	adv_loss_s: 0.741263	adv_loss_t: 0.723621
# Train -> [ 2560/ 5504 (47%)]	loss: 0.722967	cls_loss: 0.018283	adv_loss_s: 0.707697	adv_loss_t: 0.701672
# Train -> [ 5120/ 5504 (93%)]	loss: 0.783136	cls_loss: 0.039205	adv_loss_s: 0.720503	adv_loss_t: 0.767358
# Validation (source) -> cls_loss: 0.067125	accuracy: 97.8667%
# Validation (target) -> cls_loss: 0.801598	accuracy: 75.3568%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.790235	cls_loss: 0.057927	adv_loss_s: 0.700139	adv_loss_t: 0.764476
# Train -> [ 2560/ 5504 (47%)]	loss: 0.747356	cls_loss: 0.039652	adv_loss_s: 0.671944	adv_loss_t: 0.743463
# Train -> [ 5120/ 5504 (93%)]	loss: 0.778484	cls_loss: 0.044702	adv_loss_s: 0.718312	adv_loss_t: 0.749253
# Validation (source) -> cls_loss: 0.063990	accuracy: 98.0667%
# Validation (target) -> cls_loss: 1.266159	accuracy: 67.5631%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.835553	cls_loss: 0.097239	adv_loss_s: 0.705314	adv_loss_t: 0.771312
# Train -> [ 2560/ 5504 (47%)]	loss: 0.809207	cls_loss: 0.086713	adv_loss_s: 0.682711	adv_loss_t: 0.762276
# Train -> [ 5120/ 5504 (93%)]	loss: 0.774997	cls_loss: 0.032963	adv_loss_s: 0.731937	adv_loss_t: 0.752130
# Validation (source) -> cls_loss: 0.062887	accuracy: 98.0600%
# Validation (target) -> cls_loss: 1.269168	accuracy: 68.3315%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.802210	cls_loss: 0.077328	adv_loss_s: 0.721414	adv_loss_t: 0.728350
# Train -> [ 2560/ 5504 (47%)]	loss: 0.754823	cls_loss: 0.041711	adv_loss_s: 0.732126	adv_loss_t: 0.694097
# Train -> [ 5120/ 5504 (93%)]	loss: 0.778278	cls_loss: 0.047976	adv_loss_s: 0.688340	adv_loss_t: 0.772263
# Validation (source) -> cls_loss: 0.079310	accuracy: 97.4933%
# Validation (target) -> cls_loss: 1.180665	accuracy: 69.2097%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.779955	cls_loss: 0.058584	adv_loss_s: 0.698960	adv_loss_t: 0.743782
# Train -> [ 2560/ 5504 (47%)]	loss: 0.760774	cls_loss: 0.052869	adv_loss_s: 0.674986	adv_loss_t: 0.740824
# Train -> [ 5120/ 5504 (93%)]	loss: 0.774186	cls_loss: 0.041268	adv_loss_s: 0.700028	adv_loss_t: 0.765808
# Validation (source) -> cls_loss: 0.062516	accuracy: 98.0333%
# Validation (target) -> cls_loss: 1.019509	accuracy: 72.2283%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.765055	cls_loss: 0.017224	adv_loss_s: 0.708477	adv_loss_t: 0.787187
# Train -> [ 2560/ 5504 (47%)]	loss: 0.765180	cls_loss: 0.061041	adv_loss_s: 0.631450	adv_loss_t: 0.776827
# Train -> [ 5120/ 5504 (93%)]	loss: 0.783025	cls_loss: 0.045380	adv_loss_s: 0.722239	adv_loss_t: 0.753050
# Validation (source) -> cls_loss: 0.070250	accuracy: 97.8000%
# Validation (target) -> cls_loss: 0.747104	accuracy: 75.9056%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.775512	cls_loss: 0.030226	adv_loss_s: 0.709712	adv_loss_t: 0.780861
# Train -> [ 2560/ 5504 (47%)]	loss: 0.743130	cls_loss: 0.020574	adv_loss_s: 0.735191	adv_loss_t: 0.709921
# Train -> [ 5120/ 5504 (93%)]	loss: 0.781723	cls_loss: 0.058359	adv_loss_s: 0.679694	adv_loss_t: 0.767033
# Validation (source) -> cls_loss: 0.060425	accuracy: 98.1867%
# Validation (target) -> cls_loss: 1.118461	accuracy: 70.8013%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.768983	cls_loss: 0.043158	adv_loss_s: 0.731949	adv_loss_t: 0.719700
# Train -> [ 2560/ 5504 (47%)]	loss: 0.788816	cls_loss: 0.056504	adv_loss_s: 0.723809	adv_loss_t: 0.740815
# Train -> [ 5120/ 5504 (93%)]	loss: 0.767338	cls_loss: 0.016075	adv_loss_s: 0.750809	adv_loss_t: 0.751717
# Validation (source) -> cls_loss: 0.057128	accuracy: 98.2800%
# Validation (target) -> cls_loss: 1.257949	accuracy: 68.2217%
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.747283	cls_loss: 0.012202	adv_loss_s: 0.711693	adv_loss_t: 0.758468
# Train -> [ 2560/ 5504 (47%)]	loss: 0.756652	cls_loss: 0.013697	adv_loss_s: 0.717218	adv_loss_t: 0.768691
# Train -> [ 5120/ 5504 (93%)]	loss: 0.799107	cls_loss: 0.062921	adv_loss_s: 0.715547	adv_loss_t: 0.756824
# Validation (source) -> cls_loss: 0.056581	accuracy: 98.2600%
# Validation (target) -> cls_loss: 0.971010	accuracy: 72.5027%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.764260	cls_loss: 0.034729	adv_loss_s: 0.689882	adv_loss_t: 0.769180
# Train -> [ 2560/ 5504 (47%)]	loss: 0.780464	cls_loss: 0.065615	adv_loss_s: 0.688892	adv_loss_t: 0.740806
# Train -> [ 5120/ 5504 (93%)]	loss: 0.759466	cls_loss: 0.043690	adv_loss_s: 0.642166	adv_loss_t: 0.789385
# Validation (source) -> cls_loss: 0.055802	accuracy: 98.3067%
# Validation (target) -> cls_loss: 1.027300	accuracy: 71.8441%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.783720	cls_loss: 0.041875	adv_loss_s: 0.681486	adv_loss_t: 0.802204
# Train -> [ 2560/ 5504 (47%)]	loss: 0.815575	cls_loss: 0.067931	adv_loss_s: 0.672630	adv_loss_t: 0.822658
# Train -> [ 5120/ 5504 (93%)]	loss: 0.779501	cls_loss: 0.042326	adv_loss_s: 0.672982	adv_loss_t: 0.801370
# Validation (source) -> cls_loss: 0.064743	accuracy: 98.0067%
# Validation (target) -> cls_loss: 1.352535	accuracy: 67.4533%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.747954	cls_loss: 0.013553	adv_loss_s: 0.699469	adv_loss_t: 0.769334
# Train -> [ 2560/ 5504 (47%)]	loss: 0.757481	cls_loss: 0.028687	adv_loss_s: 0.674438	adv_loss_t: 0.783149
# Train -> [ 5120/ 5504 (93%)]	loss: 0.776705	cls_loss: 0.030357	adv_loss_s: 0.716560	adv_loss_t: 0.776136
# Validation (source) -> cls_loss: 0.065209	accuracy: 98.0600%
# Validation (target) -> cls_loss: 1.151472	accuracy: 70.9111%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.791238	cls_loss: 0.070940	adv_loss_s: 0.659906	adv_loss_t: 0.780690
# Train -> [ 2560/ 5504 (47%)]	loss: 0.727671	cls_loss: 0.018796	adv_loss_s: 0.657136	adv_loss_t: 0.760613
# Train -> [ 5120/ 5504 (93%)]	loss: 0.745447	cls_loss: 0.025106	adv_loss_s: 0.660336	adv_loss_t: 0.780347
# Validation (source) -> cls_loss: 0.070950	accuracy: 97.8667%
# Validation (target) -> cls_loss: 1.218566	accuracy: 67.2338%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.742832	cls_loss: 0.030399	adv_loss_s: 0.669277	adv_loss_t: 0.755587
# Train -> [ 2560/ 5504 (47%)]	loss: 0.771439	cls_loss: 0.066362	adv_loss_s: 0.627111	adv_loss_t: 0.783043
# Train -> [ 5120/ 5504 (93%)]	loss: 0.796892	cls_loss: 0.049388	adv_loss_s: 0.687088	adv_loss_t: 0.807920
# Validation (source) -> cls_loss: 0.056266	accuracy: 98.2867%
# Validation (target) -> cls_loss: 1.097683	accuracy: 71.0757%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.777129	cls_loss: 0.036983	adv_loss_s: 0.671400	adv_loss_t: 0.808891
# Train -> [ 2560/ 5504 (47%)]	loss: 0.770800	cls_loss: 0.039327	adv_loss_s: 0.685923	adv_loss_t: 0.777022
# Train -> [ 5120/ 5504 (93%)]	loss: 0.773481	cls_loss: 0.031216	adv_loss_s: 0.665693	adv_loss_t: 0.818837
# Validation (source) -> cls_loss: 0.056916	accuracy: 98.3133%
# Validation (target) -> cls_loss: 1.036392	accuracy: 72.6674%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.749067	cls_loss: 0.035061	adv_loss_s: 0.652207	adv_loss_t: 0.775806
# Train -> [ 2560/ 5504 (47%)]	loss: 0.837489	cls_loss: 0.082086	adv_loss_s: 0.704721	adv_loss_t: 0.806085
# Train -> [ 5120/ 5504 (93%)]	loss: 0.752435	cls_loss: 0.026236	adv_loss_s: 0.652657	adv_loss_t: 0.799741
# Validation (source) -> cls_loss: 0.053899	accuracy: 98.3200%
# Validation (target) -> cls_loss: 1.050586	accuracy: 72.1734%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.824863	cls_loss: 0.102673	adv_loss_s: 0.608610	adv_loss_t: 0.835771
# Train -> [ 2560/ 5504 (47%)]	loss: 0.777147	cls_loss: 0.028159	adv_loss_s: 0.725543	adv_loss_t: 0.772435
# Train -> [ 5120/ 5504 (93%)]	loss: 0.769963	cls_loss: 0.020405	adv_loss_s: 0.708897	adv_loss_t: 0.790219
# Validation (source) -> cls_loss: 0.064829	accuracy: 98.0467%
# Validation (target) -> cls_loss: 1.111251	accuracy: 72.0637%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.777641	cls_loss: 0.046365	adv_loss_s: 0.691826	adv_loss_t: 0.770728
# Train -> [ 2560/ 5504 (47%)]	loss: 0.776746	cls_loss: 0.009467	adv_loss_s: 0.774681	adv_loss_t: 0.759876
# Train -> [ 5120/ 5504 (93%)]	loss: 0.760839	cls_loss: 0.008926	adv_loss_s: 0.749302	adv_loss_t: 0.754524
# Validation (source) -> cls_loss: 0.046953	accuracy: 98.6267%
# Validation (target) -> cls_loss: 1.232194	accuracy: 69.7036%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.768770	cls_loss: 0.005670	adv_loss_s: 0.754687	adv_loss_t: 0.771512
# Train -> [ 2560/ 5504 (47%)]	loss: 0.794184	cls_loss: 0.047476	adv_loss_s: 0.689251	adv_loss_t: 0.804164
# Train -> [ 5120/ 5504 (93%)]	loss: 0.826039	cls_loss: 0.061704	adv_loss_s: 0.741066	adv_loss_t: 0.787605
# Validation (source) -> cls_loss: 0.061595	accuracy: 98.1467%
# Validation (target) -> cls_loss: 1.312822	accuracy: 69.2097%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.813595	cls_loss: 0.043066	adv_loss_s: 0.733738	adv_loss_t: 0.807321
# Train -> [ 2560/ 5504 (47%)]	loss: 0.840613	cls_loss: 0.097652	adv_loss_s: 0.673283	adv_loss_t: 0.812639
# Train -> [ 5120/ 5504 (93%)]	loss: 0.815987	cls_loss: 0.047939	adv_loss_s: 0.739109	adv_loss_t: 0.796987
# Validation (source) -> cls_loss: 0.052222	accuracy: 98.3933%
# Validation (target) -> cls_loss: 1.231827	accuracy: 68.2766%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.755468	cls_loss: 0.007598	adv_loss_s: 0.672797	adv_loss_t: 0.822943
# Train -> [ 2560/ 5504 (47%)]	loss: 0.822847	cls_loss: 0.025537	adv_loss_s: 0.775401	adv_loss_t: 0.819220
# Train -> [ 5120/ 5504 (93%)]	loss: 0.777516	cls_loss: 0.029592	adv_loss_s: 0.733241	adv_loss_t: 0.762608
# Validation (source) -> cls_loss: 0.073952	accuracy: 97.7400%
# Validation (target) -> cls_loss: 1.239749	accuracy: 68.5510%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.757514	cls_loss: 0.007572	adv_loss_s: 0.704852	adv_loss_t: 0.795033
# Train -> [ 2560/ 5504 (47%)]	loss: 0.808889	cls_loss: 0.027290	adv_loss_s: 0.751961	adv_loss_t: 0.811236
# Train -> [ 5120/ 5504 (93%)]	loss: 0.782463	cls_loss: 0.029789	adv_loss_s: 0.732780	adv_loss_t: 0.772567
# Validation (source) -> cls_loss: 0.049867	accuracy: 98.6133%
# Validation (target) -> cls_loss: 1.485731	accuracy: 65.4226%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.798775	cls_loss: 0.012973	adv_loss_s: 0.777717	adv_loss_t: 0.793887
# Train -> [ 2560/ 5504 (47%)]	loss: 0.735286	cls_loss: 0.005716	adv_loss_s: 0.689138	adv_loss_t: 0.770002
# Train -> [ 5120/ 5504 (93%)]	loss: 0.785197	cls_loss: 0.017376	adv_loss_s: 0.720708	adv_loss_t: 0.814935
# Validation (source) -> cls_loss: 0.045662	accuracy: 98.7000%
# Validation (target) -> cls_loss: 1.270548	accuracy: 69.1548%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.790376	cls_loss: 0.025530	adv_loss_s: 0.706438	adv_loss_t: 0.823255
# Train -> [ 2560/ 5504 (47%)]	loss: 0.735127	cls_loss: 0.012186	adv_loss_s: 0.680201	adv_loss_t: 0.765681
# Train -> [ 5120/ 5504 (93%)]	loss: 0.804550	cls_loss: 0.027317	adv_loss_s: 0.713910	adv_loss_t: 0.840557
# Validation (source) -> cls_loss: 0.049514	accuracy: 98.6200%
# Validation (target) -> cls_loss: 1.320760	accuracy: 69.4292%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.748455	cls_loss: 0.003088	adv_loss_s: 0.719273	adv_loss_t: 0.771461
# Train -> [ 2560/ 5504 (47%)]	loss: 0.778709	cls_loss: 0.003823	adv_loss_s: 0.731602	adv_loss_t: 0.818169
# Train -> [ 5120/ 5504 (93%)]	loss: 0.775414	cls_loss: 0.024625	adv_loss_s: 0.737825	adv_loss_t: 0.763753
# Validation (source) -> cls_loss: 0.048333	accuracy: 98.6267%
# Validation (target) -> cls_loss: 1.101066	accuracy: 70.7464%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.759525	cls_loss: 0.005552	adv_loss_s: 0.708188	adv_loss_t: 0.799756
# Train -> [ 2560/ 5504 (47%)]	loss: 0.797463	cls_loss: 0.034282	adv_loss_s: 0.726831	adv_loss_t: 0.799530
# Train -> [ 5120/ 5504 (93%)]	loss: 0.783866	cls_loss: 0.022223	adv_loss_s: 0.764250	adv_loss_t: 0.759037
# Validation (source) -> cls_loss: 0.045151	accuracy: 98.7333%
# Validation (target) -> cls_loss: 1.191747	accuracy: 71.5697%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.760400	cls_loss: 0.010628	adv_loss_s: 0.727001	adv_loss_t: 0.772543
# Train -> [ 2560/ 5504 (47%)]	loss: 0.750172	cls_loss: 0.003492	adv_loss_s: 0.738241	adv_loss_t: 0.755120
# Train -> [ 5120/ 5504 (93%)]	loss: 0.755104	cls_loss: 0.010821	adv_loss_s: 0.675760	adv_loss_t: 0.812806
# Validation (source) -> cls_loss: 0.045626	accuracy: 98.7200%
# Validation (target) -> cls_loss: 1.393549	accuracy: 67.8924%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.741083	cls_loss: 0.006041	adv_loss_s: 0.674012	adv_loss_t: 0.796071
# Train -> [ 2560/ 5504 (47%)]	loss: 0.772862	cls_loss: 0.029577	adv_loss_s: 0.690931	adv_loss_t: 0.795638
# Train -> [ 5120/ 5504 (93%)]	loss: 0.772727	cls_loss: 0.001994	adv_loss_s: 0.738847	adv_loss_t: 0.802618
# Validation (source) -> cls_loss: 0.044093	accuracy: 98.7600%
# Validation (target) -> cls_loss: 1.340712	accuracy: 67.1789%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.778674	cls_loss: 0.033590	adv_loss_s: 0.682507	adv_loss_t: 0.807661
# Train -> [ 2560/ 5504 (47%)]	loss: 0.800718	cls_loss: 0.026589	adv_loss_s: 0.686688	adv_loss_t: 0.861570
# Train -> [ 5120/ 5504 (93%)]	loss: 0.764556	cls_loss: 0.014115	adv_loss_s: 0.742820	adv_loss_t: 0.758063
# Validation (source) -> cls_loss: 0.055966	accuracy: 98.4267%
# Validation (target) -> cls_loss: 1.287356	accuracy: 69.5390%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.764135	cls_loss: 0.020574	adv_loss_s: 0.724050	adv_loss_t: 0.763073
# Train -> [ 2560/ 5504 (47%)]	loss: 0.751261	cls_loss: 0.018295	adv_loss_s: 0.677541	adv_loss_t: 0.788391
# Train -> [ 5120/ 5504 (93%)]	loss: 0.762776	cls_loss: 0.024291	adv_loss_s: 0.665149	adv_loss_t: 0.811822
# Validation (source) -> cls_loss: 0.045562	accuracy: 98.7533%
# Validation (target) -> cls_loss: 1.341324	accuracy: 67.0143%
# Epoch 48 --------
# ...
# Validation (source) -> cls_loss: 0.105853	accuracy: 96.4000%
# Validation (target) -> cls_loss: 0.928005	accuracy: 72.0637%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.838603	cls_loss: 0.133522	adv_loss_s: 1.000427	adv_loss_t: 0.409736
# Train -> [ 2560/ 5504 (47%)]	loss: 0.839521	cls_loss: 0.079703	adv_loss_s: 1.011872	adv_loss_t: 0.507764
# Train -> [ 5120/ 5504 (93%)]	loss: 0.771924	cls_loss: 0.065161	adv_loss_s: 0.935924	adv_loss_t: 0.477601
# Validation (source) -> cls_loss: 0.078433	accuracy: 97.5533%
# Validation (target) -> cls_loss: 0.762462	accuracy: 75.7958%
# Best model updated and saved at "best_model.pt"
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.776193	cls_loss: 0.044376	adv_loss_s: 0.967248	adv_loss_t: 0.496387
# Train -> [ 2560/ 5504 (47%)]	loss: 0.847920	cls_loss: 0.067636	adv_loss_s: 1.055741	adv_loss_t: 0.504827
# Train -> [ 5120/ 5504 (93%)]	loss: 0.808872	cls_loss: 0.056950	adv_loss_s: 1.022971	adv_loss_t: 0.480872
# Validation (source) -> cls_loss: 0.070316	accuracy: 97.7533%
# Validation (target) -> cls_loss: 0.703888	accuracy: 80.6806%
# Best model updated and saved at "best_model.pt"
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.836456	cls_loss: 0.056601	adv_loss_s: 1.077376	adv_loss_t: 0.482334
# Train -> [ 2560/ 5504 (47%)]	loss: 0.795677	cls_loss: 0.026440	adv_loss_s: 1.024579	adv_loss_t: 0.513894
# Train -> [ 5120/ 5504 (93%)]	loss: 0.763916	cls_loss: 0.019200	adv_loss_s: 1.042970	adv_loss_t: 0.446460
# Validation (source) -> cls_loss: 0.066132	accuracy: 97.9733%
# Validation (target) -> cls_loss: 0.769401	accuracy: 78.0461%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.815136	cls_loss: 0.014010	adv_loss_s: 1.132405	adv_loss_t: 0.469846
# Train -> [ 2560/ 5504 (47%)]	loss: 0.830950	cls_loss: 0.065018	adv_loss_s: 1.073246	adv_loss_t: 0.458619
# Train -> [ 5120/ 5504 (93%)]	loss: 0.751544	cls_loss: 0.028881	adv_loss_s: 1.010067	adv_loss_t: 0.435260
# Validation (source) -> cls_loss: 0.067587	accuracy: 97.8133%
# Validation (target) -> cls_loss: 0.848371	accuracy: 77.2228%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.811080	cls_loss: 0.048010	adv_loss_s: 1.045306	adv_loss_t: 0.480834
# Train -> [ 2560/ 5504 (47%)]	loss: 0.816025	cls_loss: 0.095670	adv_loss_s: 0.946871	adv_loss_t: 0.493838
# Train -> [ 5120/ 5504 (93%)]	loss: 0.780832	cls_loss: 0.037119	adv_loss_s: 1.058895	adv_loss_t: 0.428529
# Validation (source) -> cls_loss: 0.058108	accuracy: 98.1800%
# Validation (target) -> cls_loss: 0.885121	accuracy: 77.7168%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.802650	cls_loss: 0.020031	adv_loss_s: 1.031548	adv_loss_t: 0.533689
# Train -> [ 2560/ 5504 (47%)]	loss: 0.813135	cls_loss: 0.083212	adv_loss_s: 1.008451	adv_loss_t: 0.451396
# Train -> [ 5120/ 5504 (93%)]	loss: 0.748659	cls_loss: 0.014060	adv_loss_s: 1.003129	adv_loss_t: 0.466069
# Validation (source) -> cls_loss: 0.063300	accuracy: 98.1200%
# Validation (target) -> cls_loss: 0.777758	accuracy: 78.2656%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.798179	cls_loss: 0.048845	adv_loss_s: 0.958452	adv_loss_t: 0.540216
# Train -> [ 2560/ 5504 (47%)]	loss: 0.753508	cls_loss: 0.031222	adv_loss_s: 0.968973	adv_loss_t: 0.475600
# Train -> [ 5120/ 5504 (93%)]	loss: 0.791864	cls_loss: 0.051333	adv_loss_s: 0.970862	adv_loss_t: 0.510201
# Validation (source) -> cls_loss: 0.068855	accuracy: 97.8133%
# Validation (target) -> cls_loss: 0.771485	accuracy: 76.8935%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.789138	cls_loss: 0.040215	adv_loss_s: 0.967681	adv_loss_t: 0.530165
# Train -> [ 2560/ 5504 (47%)]	loss: 0.761663	cls_loss: 0.014993	adv_loss_s: 1.001680	adv_loss_t: 0.491660
# Train -> [ 5120/ 5504 (93%)]	loss: 0.738803	cls_loss: 0.005068	adv_loss_s: 1.009709	adv_loss_t: 0.457762
# Validation (source) -> cls_loss: 0.057523	accuracy: 98.2400%
# Validation (target) -> cls_loss: 0.862456	accuracy: 75.7958%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.783184	cls_loss: 0.014511	adv_loss_s: 1.077008	adv_loss_t: 0.460339
# Train -> [ 2560/ 5504 (47%)]	loss: 0.838206	cls_loss: 0.065621	adv_loss_s: 1.101486	adv_loss_t: 0.443683
# Train -> [ 5120/ 5504 (93%)]	loss: 0.799825	cls_loss: 0.051392	adv_loss_s: 0.996216	adv_loss_t: 0.500652
# Validation (source) -> cls_loss: 0.074536	accuracy: 97.6600%
# Validation (target) -> cls_loss: 0.553337	accuracy: 82.4369%
# Best model updated and saved at "best_model.pt"
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.783608	cls_loss: 0.059700	adv_loss_s: 0.977316	adv_loss_t: 0.470501
# Train -> [ 2560/ 5504 (47%)]	loss: 0.793803	cls_loss: 0.038542	adv_loss_s: 1.016263	adv_loss_t: 0.494260
# Train -> [ 5120/ 5504 (93%)]	loss: 0.778562	cls_loss: 0.018999	adv_loss_s: 1.053262	adv_loss_t: 0.465862
# Validation (source) -> cls_loss: 0.056923	accuracy: 98.2600%
# Validation (target) -> cls_loss: 0.834888	accuracy: 77.6070%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.753646	cls_loss: 0.011578	adv_loss_s: 1.013826	adv_loss_t: 0.470311
# Train -> [ 2560/ 5504 (47%)]	loss: 0.809283	cls_loss: 0.099270	adv_loss_s: 0.945228	adv_loss_t: 0.474798
# Train -> [ 5120/ 5504 (93%)]	loss: 0.758777	cls_loss: 0.036600	adv_loss_s: 0.909302	adv_loss_t: 0.535052
# Validation (source) -> cls_loss: 0.056136	accuracy: 98.3267%
# Validation (target) -> cls_loss: 0.686153	accuracy: 78.1559%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.742983	cls_loss: 0.021696	adv_loss_s: 0.877591	adv_loss_t: 0.564983
# Train -> [ 2560/ 5504 (47%)]	loss: 0.783859	cls_loss: 0.049142	adv_loss_s: 0.975650	adv_loss_t: 0.493783
# Train -> [ 5120/ 5504 (93%)]	loss: 0.723522	cls_loss: 0.011947	adv_loss_s: 0.912373	adv_loss_t: 0.510777
# Validation (source) -> cls_loss: 0.052639	accuracy: 98.3200%
# Validation (target) -> cls_loss: 0.703940	accuracy: 79.1438%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.738279	cls_loss: 0.009553	adv_loss_s: 0.962022	adv_loss_t: 0.495429
# Train -> [ 2560/ 5504 (47%)]	loss: 0.767089	cls_loss: 0.032700	adv_loss_s: 0.981740	adv_loss_t: 0.487038
# Train -> [ 5120/ 5504 (93%)]	loss: 0.764958	cls_loss: 0.029096	adv_loss_s: 0.961333	adv_loss_t: 0.510391
# Validation (source) -> cls_loss: 0.056509	accuracy: 98.2533%
# Validation (target) -> cls_loss: 0.746608	accuracy: 77.4424%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.814065	cls_loss: 0.060208	adv_loss_s: 0.994205	adv_loss_t: 0.513509
# Train -> [ 2560/ 5504 (47%)]	loss: 0.717803	cls_loss: 0.020890	adv_loss_s: 0.936176	adv_loss_t: 0.457649
# Train -> [ 5120/ 5504 (93%)]	loss: 0.746352	cls_loss: 0.025385	adv_loss_s: 0.906650	adv_loss_t: 0.535285
# Validation (source) -> cls_loss: 0.054808	accuracy: 98.3200%
# Validation (target) -> cls_loss: 0.684515	accuracy: 79.0340%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.727457	cls_loss: 0.013006	adv_loss_s: 0.930206	adv_loss_t: 0.498696
# Train -> [ 2560/ 5504 (47%)]	loss: 0.761020	cls_loss: 0.065832	adv_loss_s: 0.813671	adv_loss_t: 0.576704
# Train -> [ 5120/ 5504 (93%)]	loss: 0.764703	cls_loss: 0.036161	adv_loss_s: 0.976563	adv_loss_t: 0.480521
# Validation (source) -> cls_loss: 0.054595	accuracy: 98.3733%
# Validation (target) -> cls_loss: 0.842930	accuracy: 75.6861%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.729781	cls_loss: 0.004589	adv_loss_s: 0.955428	adv_loss_t: 0.494955
# Train -> [ 2560/ 5504 (47%)]	loss: 0.707012	cls_loss: 0.017238	adv_loss_s: 0.873032	adv_loss_t: 0.506516
# Train -> [ 5120/ 5504 (93%)]	loss: 0.731899	cls_loss: 0.005869	adv_loss_s: 0.961863	adv_loss_t: 0.490197
# Validation (source) -> cls_loss: 0.060108	accuracy: 98.2200%
# Validation (target) -> cls_loss: 0.782949	accuracy: 79.7475%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.770154	cls_loss: 0.047799	adv_loss_s: 0.999888	adv_loss_t: 0.444823
# Train -> [ 2560/ 5504 (47%)]	loss: 0.742829	cls_loss: 0.015173	adv_loss_s: 0.973010	adv_loss_t: 0.482302
# Train -> [ 5120/ 5504 (93%)]	loss: 0.763756	cls_loss: 0.011677	adv_loss_s: 1.029463	adv_loss_t: 0.474695
# Validation (source) -> cls_loss: 0.056060	accuracy: 98.3667%
# Validation (target) -> cls_loss: 0.716858	accuracy: 80.1866%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.754338	cls_loss: 0.030198	adv_loss_s: 1.026582	adv_loss_t: 0.421698
# Train -> [ 2560/ 5504 (47%)]	loss: 0.790222	cls_loss: 0.047667	adv_loss_s: 0.949082	adv_loss_t: 0.536028
# Train -> [ 5120/ 5504 (93%)]	loss: 0.742265	cls_loss: 0.008865	adv_loss_s: 0.997174	adv_loss_t: 0.469626
# Validation (source) -> cls_loss: 0.049609	accuracy: 98.3733%
# Validation (target) -> cls_loss: 0.837056	accuracy: 78.8145%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.747031	cls_loss: 0.010194	adv_loss_s: 0.992576	adv_loss_t: 0.481098
# Train -> [ 2560/ 5504 (47%)]	loss: 0.799035	cls_loss: 0.045047	adv_loss_s: 1.040763	adv_loss_t: 0.467214
# Train -> [ 5120/ 5504 (93%)]	loss: 0.783404	cls_loss: 0.041242	adv_loss_s: 0.915463	adv_loss_t: 0.568861
# Validation (source) -> cls_loss: 0.050432	accuracy: 98.4467%
# Validation (target) -> cls_loss: 0.628227	accuracy: 81.7234%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.792953	cls_loss: 0.029133	adv_loss_s: 0.939565	adv_loss_t: 0.588074
# Train -> [ 2560/ 5504 (47%)]	loss: 0.751110	cls_loss: 0.024152	adv_loss_s: 0.928298	adv_loss_t: 0.525619
# Train -> [ 5120/ 5504 (93%)]	loss: 0.744691	cls_loss: 0.009843	adv_loss_s: 0.978394	adv_loss_t: 0.491302
# Validation (source) -> cls_loss: 0.057241	accuracy: 98.3600%
# Validation (target) -> cls_loss: 0.803714	accuracy: 78.9791%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.757016	cls_loss: 0.022531	adv_loss_s: 1.005817	adv_loss_t: 0.463153
# Train -> [ 2560/ 5504 (47%)]	loss: 0.743205	cls_loss: 0.037859	adv_loss_s: 0.886475	adv_loss_t: 0.524217
# Train -> [ 5120/ 5504 (93%)]	loss: 0.815236	cls_loss: 0.081850	adv_loss_s: 1.006618	adv_loss_t: 0.460155
# Validation (source) -> cls_loss: 0.049471	accuracy: 98.4200%
# Validation (target) -> cls_loss: 0.760508	accuracy: 79.1987%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.713347	cls_loss: 0.006191	adv_loss_s: 0.920366	adv_loss_t: 0.493948
# Train -> [ 2560/ 5504 (47%)]	loss: 0.728500	cls_loss: 0.029738	adv_loss_s: 0.914648	adv_loss_t: 0.482875
# Train -> [ 5120/ 5504 (93%)]	loss: 0.786925	cls_loss: 0.055099	adv_loss_s: 0.957655	adv_loss_t: 0.505997
# Validation (source) -> cls_loss: 0.051098	accuracy: 98.5267%
# Validation (target) -> cls_loss: 0.820924	accuracy: 79.9122%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.724870	cls_loss: 0.012983	adv_loss_s: 0.920083	adv_loss_t: 0.503690
# Train -> [ 2560/ 5504 (47%)]	loss: 0.709828	cls_loss: 0.026178	adv_loss_s: 0.894104	adv_loss_t: 0.473198
# Train -> [ 5120/ 5504 (93%)]	loss: 0.715061	cls_loss: 0.034441	adv_loss_s: 0.901823	adv_loss_t: 0.459416
# Validation (source) -> cls_loss: 0.065099	accuracy: 98.2333%
# Validation (target) -> cls_loss: 0.965037	accuracy: 74.8079%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.718812	cls_loss: 0.024215	adv_loss_s: 0.877084	adv_loss_t: 0.512110
# Train -> [ 2560/ 5504 (47%)]	loss: 0.701589	cls_loss: 0.032982	adv_loss_s: 0.800690	adv_loss_t: 0.536524
# Train -> [ 5120/ 5504 (93%)]	loss: 0.776052	cls_loss: 0.085267	adv_loss_s: 0.841785	adv_loss_t: 0.539784
# Validation (source) -> cls_loss: 0.049652	accuracy: 98.4667%
# Validation (target) -> cls_loss: 0.830334	accuracy: 79.5280%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.711385	cls_loss: 0.036865	adv_loss_s: 0.837216	adv_loss_t: 0.511824
# Train -> [ 2560/ 5504 (47%)]	loss: 0.735562	cls_loss: 0.026668	adv_loss_s: 0.913642	adv_loss_t: 0.504145
# Train -> [ 5120/ 5504 (93%)]	loss: 0.749718	cls_loss: 0.021751	adv_loss_s: 0.980655	adv_loss_t: 0.475279
# Validation (source) -> cls_loss: 0.044014	accuracy: 98.7333%
# Validation (target) -> cls_loss: 0.853325	accuracy: 79.4731%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.764720	cls_loss: 0.057989	adv_loss_s: 0.942011	adv_loss_t: 0.471450
# Train -> [ 2560/ 5504 (47%)]	loss: 0.733446	cls_loss: 0.005632	adv_loss_s: 1.005689	adv_loss_t: 0.449939
# Train -> [ 5120/ 5504 (93%)]	loss: 0.712675	cls_loss: 0.015393	adv_loss_s: 0.852333	adv_loss_t: 0.542231
# Validation (source) -> cls_loss: 0.050069	accuracy: 98.4533%
# Validation (target) -> cls_loss: 0.813617	accuracy: 77.7168%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.691697	cls_loss: 0.020781	adv_loss_s: 0.845433	adv_loss_t: 0.496398
# Train -> [ 2560/ 5504 (47%)]	loss: 0.695268	cls_loss: 0.008172	adv_loss_s: 0.872536	adv_loss_t: 0.501657
# Train -> [ 5120/ 5504 (93%)]	loss: 0.692444	cls_loss: 0.021644	adv_loss_s: 0.850628	adv_loss_t: 0.490972
# Validation (source) -> cls_loss: 0.047619	accuracy: 98.5800%
# Validation (target) -> cls_loss: 0.655314	accuracy: 81.6136%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.685081	cls_loss: 0.002268	adv_loss_s: 0.881552	adv_loss_t: 0.484073
# Train -> [ 2560/ 5504 (47%)]	loss: 0.716286	cls_loss: 0.004795	adv_loss_s: 0.889343	adv_loss_t: 0.533638
# Train -> [ 5120/ 5504 (93%)]	loss: 0.754095	cls_loss: 0.043537	adv_loss_s: 0.957221	adv_loss_t: 0.463896
# Validation (source) -> cls_loss: 0.045631	accuracy: 98.6267%
# Validation (target) -> cls_loss: 0.685407	accuracy: 81.8880%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.714979	cls_loss: 0.017365	adv_loss_s: 0.917995	adv_loss_t: 0.477233
# Train -> [ 2560/ 5504 (47%)]	loss: 0.739040	cls_loss: 0.050445	adv_loss_s: 0.897511	adv_loss_t: 0.479680
# Train -> [ 5120/ 5504 (93%)]	loss: 0.743743	cls_loss: 0.030973	adv_loss_s: 0.899589	adv_loss_t: 0.525950
# Validation (source) -> cls_loss: 0.044406	accuracy: 98.7933%
# Validation (target) -> cls_loss: 0.685703	accuracy: 80.7355%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.751952	cls_loss: 0.053610	adv_loss_s: 0.907487	adv_loss_t: 0.489197
# Train -> [ 2560/ 5504 (47%)]	loss: 0.709260	cls_loss: 0.007682	adv_loss_s: 0.987467	adv_loss_t: 0.415689
# Train -> [ 5120/ 5504 (93%)]	loss: 0.742139	cls_loss: 0.034615	adv_loss_s: 0.948566	adv_loss_t: 0.466480
# Validation (source) -> cls_loss: 0.047759	accuracy: 98.5467%
# Validation (target) -> cls_loss: 0.746527	accuracy: 78.1010%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.711122	cls_loss: 0.014624	adv_loss_s: 0.936801	adv_loss_t: 0.456195
# Train -> [ 2560/ 5504 (47%)]	loss: 0.691447	cls_loss: 0.001181	adv_loss_s: 0.933721	adv_loss_t: 0.446811
# Train -> [ 5120/ 5504 (93%)]	loss: 0.693904	cls_loss: 0.004507	adv_loss_s: 0.915431	adv_loss_t: 0.463364
# Validation (source) -> cls_loss: 0.069142	accuracy: 97.9000%
# Validation (target) -> cls_loss: 0.816864	accuracy: 81.8332%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.778506	cls_loss: 0.048128	adv_loss_s: 0.953354	adv_loss_t: 0.507402
# Train -> [ 2560/ 5504 (47%)]	loss: 0.717807	cls_loss: 0.029475	adv_loss_s: 0.903479	adv_loss_t: 0.473185
# Train -> [ 5120/ 5504 (93%)]	loss: 0.716270	cls_loss: 0.008776	adv_loss_s: 0.903883	adv_loss_t: 0.511106
# Validation (source) -> cls_loss: 0.049118	accuracy: 98.4533%
# Validation (target) -> cls_loss: 0.698241	accuracy: 81.2843%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.691538	cls_loss: 0.003816	adv_loss_s: 0.862086	adv_loss_t: 0.513358
# Train -> [ 2560/ 5504 (47%)]	loss: 0.693063	cls_loss: 0.014425	adv_loss_s: 0.813416	adv_loss_t: 0.543862
# Train -> [ 5120/ 5504 (93%)]	loss: 0.690804	cls_loss: 0.022570	adv_loss_s: 0.850986	adv_loss_t: 0.485481
# Validation (source) -> cls_loss: 0.042057	accuracy: 98.8200%
# Validation (target) -> cls_loss: 0.868048	accuracy: 78.7047%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.722504	cls_loss: 0.028889	adv_loss_s: 0.843777	adv_loss_t: 0.543453
# Train -> [ 2560/ 5504 (47%)]	loss: 0.705159	cls_loss: 0.008396	adv_loss_s: 0.883920	adv_loss_t: 0.509606
# Train -> [ 5120/ 5504 (93%)]	loss: 0.710146	cls_loss: 0.010648	adv_loss_s: 0.892146	adv_loss_t: 0.506850
# Validation (source) -> cls_loss: 0.046747	accuracy: 98.6333%
# Validation (target) -> cls_loss: 0.879244	accuracy: 80.2415%
# Test (source) -> cls_loss: 0.054493	accuracy: 98.0800%
# Test (target) -> cls_loss: 0.647817	accuracy: 79.5217%

# %%
np.save('all_loss_train.npy', all_loss_train)
np.save('all_loss_val.npy', all_loss_val)
np.save('all_loss_test.npy', all_loss_test)

plot_losses(
    list(np.mean(all_loss_train, axis=0).T),
    loss_labels_train,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training'
)
plot_losses(
    list(np.mean(all_loss_val, axis=0).T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation'
)
print(np.mean(all_loss_test, axis=0))
# Out:
# [0.09311426 0.96958    0.65122097 0.78804185]
