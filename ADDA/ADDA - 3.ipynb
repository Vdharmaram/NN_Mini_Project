# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('./data', train=True,  download=True, transform=transform)
    test_set  = dataset('./data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %% [markdown]
# ## Dimensionality reducer

# %%
class DimensionReducer(nn.Module):
    def __init__(
        self,
        in_features: int,
        hidden_size: int,
        beta: float = 5,
        esp:  float = 1e-8
    ):
        super().__init__()
        
        self.beta = beta
        self.esp = esp
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=hidden_size*2,
                nhead=1
            ),
            num_layers=1
        )
        self.output_layer_ks = nn.Sequential(
            nn.Linear(hidden_size*2, 1),
            nn.Sigmoid()
        )
        self.output_layer_kd = nn.Sequential(
            nn.Linear(hidden_size*2, 1),
            nn.Sigmoid()
        )
    
    def forward(self, xs: torch.Tensor, xt: torch.Tensor, ks=None, kt=None) -> torch.Tensor:
        if ks is None or kt is None:
            xs1 = self.projection(xs)
            xt1 = self.projection(xt)
            x_combined = torch.cat((xs1, xt1), dim=1)
            z = self.transformer(x_combined)[0, :]
            ks = self.output_layer_ks(z)
            kt = self.output_layer_kd(z)
        
        kd = min(xs.shape[0], xs.shape[1])
        
        xs = xs - torch.mean(xs, dim=0)
        # xs = xs + self.esp
        us, ss, vhs = torch.linalg.svd(xs, full_matrices=True)
        
        xt = xt - torch.mean(xt, dim=0)
        # xt = xt + self.esp
        ut, st, vht = torch.linalg.svd(xt, full_matrices=True)
        
        i = torch.arange(kd, device=xs.device)
        ws = torch.sigmoid(-self.beta*(i - ks*kd))
        wd = torch.sigmoid(-self.beta*(i - kt*kd))
        
        ss1 = torch.diag(ss * ws)
        ss1 = torch.cat((ss1, torch.zeros((xs.shape[0] - kd, kd), device=xs.device)), dim=0)
        ss1 = torch.cat((ss1, torch.zeros((xs.shape[0], xs.shape[1] - kd), device=xs.device)), dim=1)
        xs = torch.mm(torch.mm(us, ss1), vhs)
        
        st1 = torch.diag(st * wd)
        st1 = torch.cat((st1, torch.zeros((xt.shape[0] - kd, kd), device=xt.device)), dim=0)
        st1 = torch.cat((st1, torch.zeros((xt.shape[0], xt.shape[1] - kd), device=xt.device)), dim=1)
        xt = torch.mm(torch.mm(ut, st1), vht)
        
        return (xs, xt, ks, kt)

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor   = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
        self.dimension_reducer = DimensionReducer(self.class_regressor.in_features, 128) 
    
    def forward(self, x, k=None):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x, _, k, _ = self.dimension_reducer(x, x, k, k)
        x = self.class_regressor(x)
        return (x, k)

# %% [markdown]
# ## Domain discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_features: int, hidden_size: int):
        super().__init__()
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=hidden_size, nhead=1), num_layers=1
        )
        self.op_layer = nn.Sequential(nn.Linear(hidden_size, 1), nn.Sigmoid())
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        x = self.transformer(x)[0, :]
        x = self.op_layer(x)
        return x

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & model creation

# %%
lr_c = 1e-3
lr_d = 1e-10
batch_size = 128
model_save_path = 'best_model.pt'

classifier = MyModel(
    input_shape=(1, 28, 28),
    output_shape=10,
    cnn_out_features=[16, 32, 64],
    fnn_out_features=[128, 64],
).to(device)
discriminator = Discriminator(classifier.class_regressor.in_features, 128).to(device)

cls_loss_fn = nn.CrossEntropyLoss()
adv_loss_fn = nn.BCELoss()

optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)
optimizer_d = torch.optim.Adam(discriminator.parameters(), lr=lr_d)

# %%
torchinfo.summary(classifier, input_size=[(batch_size, 1, 28, 28), (1,)])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                  [128, 576]                1,389,442
# ├─ClassRegressor: 1-3                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 1,495,500
# Trainable params: 1,495,500
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, k=None, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred, _ = model_c(x, k)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha):
    N = xs.shape[0]
    
    xs = classifier.feature_extractor(xs)
    xs = torch.flatten(xs, start_dim=1)
    xt = classifier.feature_extractor(xt)
    xt = torch.flatten(xt, start_dim=1)
    
    xs, xt, ks, kt = classifier.dimension_reducer(xs, xt)
    
    ####
    # discriminator training
    ####
    label_s = torch.zeros(1, device=device)
    label_t = torch.ones(1, device=device)
    
    pt_s = discriminator(xs.detach())
    pt_t = discriminator(xt.detach())
    
    adv_loss_s = adv_loss_fn(pt_s, label_s)
    adv_loss_t = adv_loss_fn(pt_t, label_t)
    
    loss_d = (adv_loss_s + adv_loss_t)/2
    optimizer_d.zero_grad()
    loss_d.backward()
    optimizer_d.step()
    
    ####
    # classifier training
    ####
    ys_pred = classifier.class_regressor(xs)
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    
    pt_s_c = discriminator(xs)
    pt_t_c = discriminator(xt)
    
    # classifier tries to trick discriminator
    adv_loss_s_c = adv_loss_fn(pt_s_c, label_t)
    adv_loss_t_c = adv_loss_fn(pt_t_c, label_s)
    
    loss_c = cls_loss + alpha*(adv_loss_s_c + adv_loss_t_c)/2
    optimizer_c.zero_grad()
    cls_loss.backward()
    optimizer_c.step()
    
    return (loss_c.item(),
            cls_loss.item(),
            adv_loss_s_c.item(),
            adv_loss_t_c.item(),
            ks.item(),
            kt.item())

# %% [markdown]
# # Main

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data\MNIST\raw\train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\train-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data\MNIST\raw\train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\train-labels-idx1-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data\MNIST\raw\t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\t10k-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw
#
# Downloading https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass/usps.bz2 to ./data\usps.bz2
#   0%|          | 0/6579383 [00:00<?, ?it/s]
# Downloading https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass/usps.t.bz2 to ./data\usps.t.bz2
#   0%|          | 0/1831726 [00:00<?, ?it/s]

# %%
num_epochs = 50
checkpoint = 20

all_loss = np.zeros((num_epochs, 6))
loss_labels = ['loss', 'cls_loss', 'adv_loss_s', 'adv_loss_t', 'ks', 'kt']

all_loss_val_s = np.zeros((num_epochs, 2))
all_loss_val_t = np.zeros((num_epochs, 2))
loss_labels_val = ['cls_loss', 'accuracy']

best_val_loss = float('inf')
best_k = 1

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1} --------')
    
    classifier.train()
    discriminator.train()
    
    len_dataloader = min(len(train_s), len(train_t))
    iter_s = iter(train_s)
    iter_t = iter(train_t)
    
    avg_loss = np.zeros(all_loss.shape[1])
    
    for batch_idx in range(len_dataloader):
        # alpha = (epoch*len_dataloader + batch_idx) / (num_epochs*len_dataloader)
        alpha = 1
        data_s = next(iter_s)
        data_t = next(iter_t)
        
        xs, ys_true = data_s
        xt, yt_true = data_t
        if xs.shape[0] != xt.shape[0]:
            continue
        
        xs = xs.to(device)
        xt = xt.to(device)
        ys_true = ys_true.to(device)
        yt_true = yt_true.to(device)
        
        losses = train_step(xs, xt, ys_true, alpha)
        avg_loss += losses
        
        if checkpoint is not None and batch_idx % checkpoint == 0:
            print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                    batch_idx * batch_size,
                    len_dataloader * batch_size,
                    batch_idx / len_dataloader * 100
                ),
                end='\t'
            )
            for loss, label in zip(losses, loss_labels):
                print(f'{label}: {loss:.6f}', end='\t')
            print('')
    
    avg_loss = avg_loss / len_dataloader
    all_loss[epoch] = losses
    
    val_losses_s = evaluate(classifier, val_s, cls_loss_fn, k=None, mode='Validation (source)')
    val_losses_t = evaluate(classifier, val_t, cls_loss_fn, k=None, mode='Validation (target)')
    
    all_loss_val_s[epoch] = val_losses_s
    all_loss_val_t[epoch] = val_losses_t
    
    val_loss = val_losses_t[0]
    
    if val_loss < best_val_loss:
        torch.save(classifier.state_dict(), model_save_path)
        best_k = avg_loss[-1]
        best_val_loss = val_loss
        print(f'Best model updated and saved at "{model_save_path}"')
# Out:
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.915249	cls_loss: 2.302041	adv_loss_s: 0.649510	adv_loss_t: 0.576907	ks: 0.584050	kt: 0.586042
# Train -> [ 2560/ 5504 (47%)]	loss: 1.887069	cls_loss: 1.374905	adv_loss_s: 0.500332	adv_loss_t: 0.523997	ks: 0.999388	kt: 0.386030
# Train -> [ 5120/ 5504 (93%)]	loss: 1.090940	cls_loss: 0.401912	adv_loss_s: 0.672570	adv_loss_t: 0.705484	ks: 0.999330	kt: 0.407048
# Validation (source) -> cls_loss: 0.396653	accuracy: 88.2133%
# Validation (target) -> cls_loss: 0.977100	accuracy: 69.9780%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.854086	cls_loss: 0.240285	adv_loss_s: 0.883164	adv_loss_t: 0.344438	ks: 0.999430	kt: 0.330435
# Train -> [ 2560/ 5504 (47%)]	loss: 0.816720	cls_loss: 0.143993	adv_loss_s: 0.638006	adv_loss_t: 0.707447	ks: 0.999300	kt: 0.320680
# Train -> [ 5120/ 5504 (93%)]	loss: 0.803165	cls_loss: 0.144712	adv_loss_s: 0.613330	adv_loss_t: 0.703576	ks: 0.999422	kt: 0.366809
# Validation (source) -> cls_loss: 0.157511	accuracy: 95.1733%
# Validation (target) -> cls_loss: 0.781910	accuracy: 76.3996%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.680834	cls_loss: 0.128567	adv_loss_s: 0.718555	adv_loss_t: 0.385978	ks: 0.999350	kt: 0.363888
# Train -> [ 2560/ 5504 (47%)]	loss: 0.859623	cls_loss: 0.078411	adv_loss_s: 0.734673	adv_loss_t: 0.827751	ks: 0.999437	kt: 0.400177
# Train -> [ 5120/ 5504 (93%)]	loss: 1.166412	cls_loss: 0.159815	adv_loss_s: 1.317987	adv_loss_t: 0.695207	ks: 0.999396	kt: 0.381658
# Validation (source) -> cls_loss: 0.119292	accuracy: 96.2933%
# Validation (target) -> cls_loss: 0.683586	accuracy: 79.4731%
# Best model updated and saved at "best_model.pt"
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.686723	cls_loss: 0.093030	adv_loss_s: 0.518087	adv_loss_t: 0.669300	ks: 0.999312	kt: 0.379966
# Train -> [ 2560/ 5504 (47%)]	loss: 1.104512	cls_loss: 0.240126	adv_loss_s: 1.121043	adv_loss_t: 0.607730	ks: 0.999471	kt: 0.392915
# Train -> [ 5120/ 5504 (93%)]	loss: 0.547866	cls_loss: 0.051861	adv_loss_s: 0.633632	adv_loss_t: 0.358377	ks: 0.999387	kt: 0.388926
# Validation (source) -> cls_loss: 0.093166	accuracy: 97.0733%
# Validation (target) -> cls_loss: 0.592161	accuracy: 83.0955%
# Best model updated and saved at "best_model.pt"
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.768317	cls_loss: 0.120696	adv_loss_s: 0.628186	adv_loss_t: 0.667057	ks: 0.999287	kt: 0.363977
# Train -> [ 2560/ 5504 (47%)]	loss: 0.388536	cls_loss: 0.017628	adv_loss_s: 0.377904	adv_loss_t: 0.363913	ks: 0.999352	kt: 0.318304
# Train -> [ 5120/ 5504 (93%)]	loss: 0.869329	cls_loss: 0.096104	adv_loss_s: 0.864483	adv_loss_t: 0.681966	ks: 0.999321	kt: 0.361455
# Validation (source) -> cls_loss: 0.082637	accuracy: 97.4067%
# Validation (target) -> cls_loss: 0.696976	accuracy: 80.6806%
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.665870	cls_loss: 0.042066	adv_loss_s: 0.632788	adv_loss_t: 0.614820	ks: 0.999382	kt: 0.456388
# Train -> [ 2560/ 5504 (47%)]	loss: 0.772099	cls_loss: 0.037112	adv_loss_s: 0.804220	adv_loss_t: 0.665753	ks: 0.999444	kt: 0.345024
# Train -> [ 5120/ 5504 (93%)]	loss: 0.762642	cls_loss: 0.092391	adv_loss_s: 0.673951	adv_loss_t: 0.666551	ks: 0.999387	kt: 0.427547
# Validation (source) -> cls_loss: 0.090235	accuracy: 97.3000%
# Validation (target) -> cls_loss: 0.583801	accuracy: 81.8332%
# Best model updated and saved at "best_model.pt"
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.969546	cls_loss: 0.078778	adv_loss_s: 1.293459	adv_loss_t: 0.488076	ks: 0.999379	kt: 0.350205
# Train -> [ 2560/ 5504 (47%)]	loss: 0.715966	cls_loss: 0.048987	adv_loss_s: 0.736811	adv_loss_t: 0.597147	ks: 0.999378	kt: 0.356053
# Train -> [ 5120/ 5504 (93%)]	loss: 0.601774	cls_loss: 0.074463	adv_loss_s: 0.689166	adv_loss_t: 0.365456	ks: 0.999478	kt: 0.353605
# Validation (source) -> cls_loss: 0.074704	accuracy: 97.5333%
# Validation (target) -> cls_loss: 0.696019	accuracy: 76.3447%
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.929256	cls_loss: 0.053472	adv_loss_s: 0.850227	adv_loss_t: 0.901341	ks: 0.999408	kt: 0.367541
# Train -> [ 2560/ 5504 (47%)]	loss: 0.728469	cls_loss: 0.061790	adv_loss_s: 0.847730	adv_loss_t: 0.485629	ks: 0.999344	kt: 0.387013
# Train -> [ 5120/ 5504 (93%)]	loss: 0.656132	cls_loss: 0.053935	adv_loss_s: 0.404034	adv_loss_t: 0.800359	ks: 0.999451	kt: 0.381017
# Validation (source) -> cls_loss: 0.060397	accuracy: 98.0733%
# Validation (target) -> cls_loss: 0.679195	accuracy: 79.8573%
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.508128	cls_loss: 0.031037	adv_loss_s: 0.424606	adv_loss_t: 0.529577	ks: 0.999293	kt: 0.424321
# Train -> [ 2560/ 5504 (47%)]	loss: 0.794300	cls_loss: 0.029613	adv_loss_s: 1.042572	adv_loss_t: 0.486802	ks: 0.999374	kt: 0.386711
# Train -> [ 5120/ 5504 (93%)]	loss: 0.641372	cls_loss: 0.009970	adv_loss_s: 0.727034	adv_loss_t: 0.535771	ks: 0.999351	kt: 0.375261
# Validation (source) -> cls_loss: 0.059796	accuracy: 98.0000%
# Validation (target) -> cls_loss: 0.606747	accuracy: 83.9737%
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.755613	cls_loss: 0.080468	adv_loss_s: 0.798828	adv_loss_t: 0.551463	ks: 0.999287	kt: 0.452137
# Train -> [ 2560/ 5504 (47%)]	loss: 0.551879	cls_loss: 0.094382	adv_loss_s: 0.496344	adv_loss_t: 0.418650	ks: 0.999410	kt: 0.371785
# Train -> [ 5120/ 5504 (93%)]	loss: 0.581331	cls_loss: 0.123630	adv_loss_s: 0.409259	adv_loss_t: 0.506144	ks: 0.999483	kt: 0.347993
# Validation (source) -> cls_loss: 0.065194	accuracy: 97.9000%
# Validation (target) -> cls_loss: 0.750461	accuracy: 79.5280%
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.804159	cls_loss: 0.091753	adv_loss_s: 0.773745	adv_loss_t: 0.651067	ks: 0.999373	kt: 0.395680
# Train -> [ 2560/ 5504 (47%)]	loss: 0.683390	cls_loss: 0.036230	adv_loss_s: 0.894987	adv_loss_t: 0.399334	ks: 0.999343	kt: 0.439057
# Train -> [ 5120/ 5504 (93%)]	loss: 0.500370	cls_loss: 0.091378	adv_loss_s: 0.541915	adv_loss_t: 0.276068	ks: 0.999338	kt: 0.378780
# Validation (source) -> cls_loss: 0.065076	accuracy: 97.8533%
# Validation (target) -> cls_loss: 0.859751	accuracy: 73.7651%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.977356	cls_loss: 0.031443	adv_loss_s: 1.092488	adv_loss_t: 0.799339	ks: 0.999297	kt: 0.364864
# Train -> [ 2560/ 5504 (47%)]	loss: 1.028564	cls_loss: 0.048686	adv_loss_s: 1.510236	adv_loss_t: 0.449521	ks: 0.999431	kt: 0.334513
# Train -> [ 5120/ 5504 (93%)]	loss: 0.724935	cls_loss: 0.107783	adv_loss_s: 0.703581	adv_loss_t: 0.530723	ks: 0.999435	kt: 0.387610
# Validation (source) -> cls_loss: 0.068811	accuracy: 97.6867%
# Validation (target) -> cls_loss: 0.673690	accuracy: 78.4852%
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.985489	cls_loss: 0.098311	adv_loss_s: 0.768539	adv_loss_t: 1.005816	ks: 0.999408	kt: 0.353024
# Train -> [ 2560/ 5504 (47%)]	loss: 0.732865	cls_loss: 0.035797	adv_loss_s: 0.790443	adv_loss_t: 0.603693	ks: 0.999409	kt: 0.396171
# Train -> [ 5120/ 5504 (93%)]	loss: 0.585696	cls_loss: 0.042368	adv_loss_s: 0.651797	adv_loss_t: 0.434859	ks: 0.999437	kt: 0.432448
# Validation (source) -> cls_loss: 0.061465	accuracy: 97.9533%
# Validation (target) -> cls_loss: 0.758651	accuracy: 77.0582%
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.935458	cls_loss: 0.056025	adv_loss_s: 1.209372	adv_loss_t: 0.549494	ks: 0.999389	kt: 0.403521
# Train -> [ 2560/ 5504 (47%)]	loss: 0.935102	cls_loss: 0.008189	adv_loss_s: 1.238663	adv_loss_t: 0.615164	ks: 0.999263	kt: 0.349230
# Train -> [ 5120/ 5504 (93%)]	loss: 0.534467	cls_loss: 0.036541	adv_loss_s: 0.656678	adv_loss_t: 0.339173	ks: 0.999429	kt: 0.360907
# Validation (source) -> cls_loss: 0.055089	accuracy: 98.1733%
# Validation (target) -> cls_loss: 0.678469	accuracy: 79.6378%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.562204	cls_loss: 0.045637	adv_loss_s: 0.687625	adv_loss_t: 0.345509	ks: 0.999379	kt: 0.379864
# Train -> [ 2560/ 5504 (47%)]	loss: 0.953095	cls_loss: 0.078903	adv_loss_s: 1.124370	adv_loss_t: 0.624016	ks: 0.999344	kt: 0.372629
# Train -> [ 5120/ 5504 (93%)]	loss: 0.901497	cls_loss: 0.017254	adv_loss_s: 1.121643	adv_loss_t: 0.646842	ks: 0.999377	kt: 0.393141
# Validation (source) -> cls_loss: 0.050802	accuracy: 98.3200%
# Validation (target) -> cls_loss: 0.585545	accuracy: 83.4797%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.620911	cls_loss: 0.019312	adv_loss_s: 0.483231	adv_loss_t: 0.719967	ks: 0.999437	kt: 0.373324
# Train -> [ 2560/ 5504 (47%)]	loss: 0.505423	cls_loss: 0.006497	adv_loss_s: 0.587427	adv_loss_t: 0.410425	ks: 0.999366	kt: 0.390468
# Train -> [ 5120/ 5504 (93%)]	loss: 0.484698	cls_loss: 0.042534	adv_loss_s: 0.525367	adv_loss_t: 0.358961	ks: 0.999362	kt: 0.396713
# Validation (source) -> cls_loss: 0.046535	accuracy: 98.4733%
# Validation (target) -> cls_loss: 0.650255	accuracy: 81.4490%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.164515	cls_loss: 0.036512	adv_loss_s: 1.275262	adv_loss_t: 0.980744	ks: 0.999339	kt: 0.384226
# Train -> [ 2560/ 5504 (47%)]	loss: 0.451257	cls_loss: 0.018376	adv_loss_s: 0.549209	adv_loss_t: 0.316553	ks: 0.999397	kt: 0.379022
# Train -> [ 5120/ 5504 (93%)]	loss: 0.870025	cls_loss: 0.086827	adv_loss_s: 0.892199	adv_loss_t: 0.674196	ks: 0.999329	kt: 0.409992
# Validation (source) -> cls_loss: 0.051492	accuracy: 98.4467%
# Validation (target) -> cls_loss: 0.741181	accuracy: 74.4237%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.501120	cls_loss: 0.005533	adv_loss_s: 0.676139	adv_loss_t: 0.315036	ks: 0.999267	kt: 0.353968
# Train -> [ 2560/ 5504 (47%)]	loss: 0.609460	cls_loss: 0.029981	adv_loss_s: 0.493799	adv_loss_t: 0.665160	ks: 0.999308	kt: 0.437227
# Train -> [ 5120/ 5504 (93%)]	loss: 0.609546	cls_loss: 0.119030	adv_loss_s: 0.639558	adv_loss_t: 0.341472	ks: 0.999382	kt: 0.382942
# Validation (source) -> cls_loss: 0.051697	accuracy: 98.4000%
# Validation (target) -> cls_loss: 0.536715	accuracy: 85.4007%
# Best model updated and saved at "best_model.pt"
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.001670	cls_loss: 0.017490	adv_loss_s: 1.325211	adv_loss_t: 0.643149	ks: 0.999363	kt: 0.438954
# Train -> [ 2560/ 5504 (47%)]	loss: 0.853616	cls_loss: 0.030967	adv_loss_s: 0.661535	adv_loss_t: 0.983764	ks: 0.999319	kt: 0.444461
# Train -> [ 5120/ 5504 (93%)]	loss: 0.769857	cls_loss: 0.024187	adv_loss_s: 1.116391	adv_loss_t: 0.374950	ks: 0.999250	kt: 0.436261
# Validation (source) -> cls_loss: 0.046469	accuracy: 98.5467%
# Validation (target) -> cls_loss: 0.811335	accuracy: 79.4731%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.806343	cls_loss: 0.084687	adv_loss_s: 0.977175	adv_loss_t: 0.466136	ks: 0.999337	kt: 0.393535
# Train -> [ 2560/ 5504 (47%)]	loss: 0.546427	cls_loss: 0.005420	adv_loss_s: 0.478513	adv_loss_t: 0.603500	ks: 0.999369	kt: 0.351799
# Train -> [ 5120/ 5504 (93%)]	loss: 0.673878	cls_loss: 0.023988	adv_loss_s: 0.759220	adv_loss_t: 0.540561	ks: 0.999324	kt: 0.412666
# Validation (source) -> cls_loss: 0.045225	accuracy: 98.4933%
# Validation (target) -> cls_loss: 0.663370	accuracy: 79.9122%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.716378	cls_loss: 0.033773	adv_loss_s: 0.750460	adv_loss_t: 0.614749	ks: 0.999302	kt: 0.372215
# Train -> [ 2560/ 5504 (47%)]	loss: 1.007533	cls_loss: 0.042108	adv_loss_s: 0.964223	adv_loss_t: 0.966626	ks: 0.999334	kt: 0.383129
# Train -> [ 5120/ 5504 (93%)]	loss: 0.478279	cls_loss: 0.018178	adv_loss_s: 0.526193	adv_loss_t: 0.394010	ks: 0.999254	kt: 0.348588
# Validation (source) -> cls_loss: 0.046817	accuracy: 98.5800%
# Validation (target) -> cls_loss: 0.737075	accuracy: 78.0461%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.781072	cls_loss: 0.017981	adv_loss_s: 0.677359	adv_loss_t: 0.848822	ks: 0.999328	kt: 0.360860
# Train -> [ 2560/ 5504 (47%)]	loss: 0.638510	cls_loss: 0.016756	adv_loss_s: 0.583020	adv_loss_t: 0.660488	ks: 0.999428	kt: 0.371431
# Train -> [ 5120/ 5504 (93%)]	loss: 0.806199	cls_loss: 0.025182	adv_loss_s: 0.702309	adv_loss_t: 0.859724	ks: 0.999344	kt: 0.402267
# Validation (source) -> cls_loss: 0.049946	accuracy: 98.4800%
# Validation (target) -> cls_loss: 0.721299	accuracy: 80.5708%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.958167	cls_loss: 0.016307	adv_loss_s: 1.357642	adv_loss_t: 0.526077	ks: 0.999388	kt: 0.392907
# Train -> [ 2560/ 5504 (47%)]	loss: 0.881836	cls_loss: 0.035604	adv_loss_s: 1.118440	adv_loss_t: 0.574023	ks: 0.999329	kt: 0.422227
# Train -> [ 5120/ 5504 (93%)]	loss: 0.638124	cls_loss: 0.047354	adv_loss_s: 0.770263	adv_loss_t: 0.411277	ks: 0.999274	kt: 0.382199
# Validation (source) -> cls_loss: 0.048604	accuracy: 98.4533%
# Validation (target) -> cls_loss: 0.635386	accuracy: 80.7355%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.628473	cls_loss: 0.019205	adv_loss_s: 0.423096	adv_loss_t: 0.795441	ks: 0.999371	kt: 0.285446
# Train -> [ 2560/ 5504 (47%)]	loss: 0.859047	cls_loss: 0.015861	adv_loss_s: 1.056440	adv_loss_t: 0.629932	ks: 0.999226	kt: 0.408186
# Train -> [ 5120/ 5504 (93%)]	loss: 0.954080	cls_loss: 0.003639	adv_loss_s: 0.768994	adv_loss_t: 1.131889	ks: 0.999311	kt: 0.383765
# Validation (source) -> cls_loss: 0.046160	accuracy: 98.5800%
# Validation (target) -> cls_loss: 0.689612	accuracy: 79.0889%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.868513	cls_loss: 0.015616	adv_loss_s: 0.913313	adv_loss_t: 0.792482	ks: 0.999342	kt: 0.355702
# Train -> [ 2560/ 5504 (47%)]	loss: 0.578946	cls_loss: 0.006688	adv_loss_s: 0.801133	adv_loss_t: 0.343383	ks: 0.999211	kt: 0.372550
# Train -> [ 5120/ 5504 (93%)]	loss: 1.131328	cls_loss: 0.034383	adv_loss_s: 0.903616	adv_loss_t: 1.290274	ks: 0.999381	kt: 0.367923
# Validation (source) -> cls_loss: 0.049512	accuracy: 98.4200%
# Validation (target) -> cls_loss: 0.518960	accuracy: 83.4248%
# Best model updated and saved at "best_model.pt"
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.980285	cls_loss: 0.049883	adv_loss_s: 1.012146	adv_loss_t: 0.848659	ks: 0.999283	kt: 0.349707
# Train -> [ 2560/ 5504 (47%)]	loss: 0.663655	cls_loss: 0.005370	adv_loss_s: 0.643437	adv_loss_t: 0.673134	ks: 0.999351	kt: 0.448317
# Train -> [ 5120/ 5504 (93%)]	loss: 0.816610	cls_loss: 0.039809	adv_loss_s: 1.066584	adv_loss_t: 0.487018	ks: 0.999337	kt: 0.405904
# Validation (source) -> cls_loss: 0.043743	accuracy: 98.6467%
# Validation (target) -> cls_loss: 0.674606	accuracy: 80.4061%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.638199	cls_loss: 0.047098	adv_loss_s: 0.491282	adv_loss_t: 0.690919	ks: 0.999232	kt: 0.366836
# Train -> [ 2560/ 5504 (47%)]	loss: 0.811239	cls_loss: 0.011401	adv_loss_s: 0.779534	adv_loss_t: 0.820143	ks: 0.999311	kt: 0.382385
# Train -> [ 5120/ 5504 (93%)]	loss: 0.575382	cls_loss: 0.004468	adv_loss_s: 0.681977	adv_loss_t: 0.459852	ks: 0.999210	kt: 0.364290
# Validation (source) -> cls_loss: 0.048792	accuracy: 98.4133%
# Validation (target) -> cls_loss: 0.695297	accuracy: 80.0768%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.848571	cls_loss: 0.027857	adv_loss_s: 1.143441	adv_loss_t: 0.497986	ks: 0.999274	kt: 0.337209
# Train -> [ 2560/ 5504 (47%)]	loss: 0.871459	cls_loss: 0.035831	adv_loss_s: 1.139569	adv_loss_t: 0.531688	ks: 0.999216	kt: 0.416196
# Train -> [ 5120/ 5504 (93%)]	loss: 0.922872	cls_loss: 0.025086	adv_loss_s: 0.956232	adv_loss_t: 0.839340	ks: 0.999326	kt: 0.455158
# Validation (source) -> cls_loss: 0.043729	accuracy: 98.6867%
# Validation (target) -> cls_loss: 0.547185	accuracy: 84.1383%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.739059	cls_loss: 0.007244	adv_loss_s: 0.805714	adv_loss_t: 0.657917	ks: 0.999315	kt: 0.436703
# Train -> [ 2560/ 5504 (47%)]	loss: 0.752487	cls_loss: 0.011331	adv_loss_s: 0.959976	adv_loss_t: 0.522335	ks: 0.999269	kt: 0.388182
# Train -> [ 5120/ 5504 (93%)]	loss: 0.564548	cls_loss: 0.004512	adv_loss_s: 0.626209	adv_loss_t: 0.493862	ks: 0.999335	kt: 0.411773
# Validation (source) -> cls_loss: 0.044412	accuracy: 98.5533%
# Validation (target) -> cls_loss: 0.674877	accuracy: 76.5093%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.015697	cls_loss: 0.001972	adv_loss_s: 0.854962	adv_loss_t: 1.172487	ks: 0.999240	kt: 0.368657
# Train -> [ 2560/ 5504 (47%)]	loss: 1.053753	cls_loss: 0.086227	adv_loss_s: 1.017110	adv_loss_t: 0.917941	ks: 0.999439	kt: 0.408626
# Train -> [ 5120/ 5504 (93%)]	loss: 0.704095	cls_loss: 0.004263	adv_loss_s: 0.924391	adv_loss_t: 0.475273	ks: 0.999330	kt: 0.346832
# Validation (source) -> cls_loss: 0.044025	accuracy: 98.5600%
# Validation (target) -> cls_loss: 0.634843	accuracy: 81.6685%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.560865	cls_loss: 0.017447	adv_loss_s: 0.709750	adv_loss_t: 0.377087	ks: 0.999392	kt: 0.306326
# Train -> [ 2560/ 5504 (47%)]	loss: 0.890292	cls_loss: 0.037231	adv_loss_s: 0.891447	adv_loss_t: 0.814674	ks: 0.999386	kt: 0.379075
# Train -> [ 5120/ 5504 (93%)]	loss: 0.770543	cls_loss: 0.009173	adv_loss_s: 0.724649	adv_loss_t: 0.798091	ks: 0.999370	kt: 0.411086
# Validation (source) -> cls_loss: 0.041453	accuracy: 98.7333%
# Validation (target) -> cls_loss: 0.599812	accuracy: 83.5346%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.564451	cls_loss: 0.012070	adv_loss_s: 0.599546	adv_loss_t: 0.505216	ks: 0.999406	kt: 0.353171
# Train -> [ 2560/ 5504 (47%)]	loss: 0.930222	cls_loss: 0.023583	adv_loss_s: 0.635263	adv_loss_t: 1.178017	ks: 0.999316	kt: 0.378256
# Train -> [ 5120/ 5504 (93%)]	loss: 0.557281	cls_loss: 0.003154	adv_loss_s: 0.520607	adv_loss_t: 0.587647	ks: 0.999400	kt: 0.381134
# Validation (source) -> cls_loss: 0.041186	accuracy: 98.6933%
# Validation (target) -> cls_loss: 0.542454	accuracy: 84.9067%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.596119	cls_loss: 0.014442	adv_loss_s: 0.746705	adv_loss_t: 0.416647	ks: 0.999346	kt: 0.394939
# Train -> [ 2560/ 5504 (47%)]	loss: 0.656384	cls_loss: 0.042316	adv_loss_s: 0.778642	adv_loss_t: 0.449494	ks: 0.999399	kt: 0.343211
# Train -> [ 5120/ 5504 (93%)]	loss: 0.981863	cls_loss: 0.005849	adv_loss_s: 0.452911	adv_loss_t: 1.499116	ks: 0.999419	kt: 0.376980
# Validation (source) -> cls_loss: 0.048213	accuracy: 98.5733%
# Validation (target) -> cls_loss: 0.599727	accuracy: 83.2602%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.590511	cls_loss: 0.010879	adv_loss_s: 0.475487	adv_loss_t: 0.683776	ks: 0.999396	kt: 0.398864
# Train -> [ 2560/ 5504 (47%)]	loss: 0.781077	cls_loss: 0.006508	adv_loss_s: 0.917502	adv_loss_t: 0.631636	ks: 0.999414	kt: 0.408922
# Train -> [ 5120/ 5504 (93%)]	loss: 0.579139	cls_loss: 0.037041	adv_loss_s: 0.646538	adv_loss_t: 0.437659	ks: 0.999287	kt: 0.400596
# Validation (source) -> cls_loss: 0.043017	accuracy: 98.6200%
# Validation (target) -> cls_loss: 0.569160	accuracy: 82.4918%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.068994	cls_loss: 0.088936	adv_loss_s: 1.124793	adv_loss_t: 0.835323	ks: 0.999357	kt: 0.375946
# Train -> [ 2560/ 5504 (47%)]	loss: 0.959637	cls_loss: 0.012410	adv_loss_s: 0.969439	adv_loss_t: 0.925015	ks: 0.999365	kt: 0.425418
# Train -> [ 5120/ 5504 (93%)]	loss: 0.731523	cls_loss: 0.006620	adv_loss_s: 0.998761	adv_loss_t: 0.451045	ks: 0.999366	kt: 0.408309
# Validation (source) -> cls_loss: 0.047347	accuracy: 98.5600%
# Validation (target) -> cls_loss: 0.493515	accuracy: 85.1811%
# Best model updated and saved at "best_model.pt"
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.082993	cls_loss: 0.013525	adv_loss_s: 0.724647	adv_loss_t: 1.414288	ks: 0.999389	kt: 0.459170
# Train -> [ 2560/ 5504 (47%)]	loss: 0.548531	cls_loss: 0.004787	adv_loss_s: 0.662082	adv_loss_t: 0.425406	ks: 0.999369	kt: 0.371660
# Train -> [ 5120/ 5504 (93%)]	loss: 0.748165	cls_loss: 0.018218	adv_loss_s: 0.937399	adv_loss_t: 0.522496	ks: 0.999431	kt: 0.329032
# Validation (source) -> cls_loss: 0.045438	accuracy: 98.5867%
# Validation (target) -> cls_loss: 0.626127	accuracy: 82.2173%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.667785	cls_loss: 0.012144	adv_loss_s: 0.486574	adv_loss_t: 0.824709	ks: 0.999368	kt: 0.375602
# Train -> [ 2560/ 5504 (47%)]	loss: 0.668911	cls_loss: 0.056688	adv_loss_s: 0.482283	adv_loss_t: 0.742163	ks: 0.999353	kt: 0.425908
# Train -> [ 5120/ 5504 (93%)]	loss: 1.005772	cls_loss: 0.036111	adv_loss_s: 0.966150	adv_loss_t: 0.973173	ks: 0.999331	kt: 0.415859
# Validation (source) -> cls_loss: 0.041903	accuracy: 98.6800%
# Validation (target) -> cls_loss: 0.476990	accuracy: 86.6630%
# Best model updated and saved at "best_model.pt"
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.809194	cls_loss: 0.014362	adv_loss_s: 0.640967	adv_loss_t: 0.948697	ks: 0.999417	kt: 0.384920
# Train -> [ 2560/ 5504 (47%)]	loss: 0.759554	cls_loss: 0.010006	adv_loss_s: 0.853071	adv_loss_t: 0.646024	ks: 0.999424	kt: 0.393483
# Train -> [ 5120/ 5504 (93%)]	loss: 0.495097	cls_loss: 0.003111	adv_loss_s: 0.536493	adv_loss_t: 0.447479	ks: 0.999439	kt: 0.368278
# Validation (source) -> cls_loss: 0.046458	accuracy: 98.4133%
# Validation (target) -> cls_loss: 0.698158	accuracy: 78.9791%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.859342	cls_loss: 0.003134	adv_loss_s: 0.978616	adv_loss_t: 0.733799	ks: 0.999376	kt: 0.365702
# Train -> [ 2560/ 5504 (47%)]	loss: 0.693511	cls_loss: 0.006200	adv_loss_s: 0.760595	adv_loss_t: 0.614028	ks: 0.999374	kt: 0.366067
# Train -> [ 5120/ 5504 (93%)]	loss: 0.690402	cls_loss: 0.052165	adv_loss_s: 0.875473	adv_loss_t: 0.401002	ks: 0.999383	kt: 0.422477
# Validation (source) -> cls_loss: 0.042876	accuracy: 98.6933%
# Validation (target) -> cls_loss: 0.665378	accuracy: 83.0406%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.583030	cls_loss: 0.010382	adv_loss_s: 0.599215	adv_loss_t: 0.546080	ks: 0.999404	kt: 0.399876
# Train -> [ 2560/ 5504 (47%)]	loss: 0.634160	cls_loss: 0.001601	adv_loss_s: 0.650194	adv_loss_t: 0.614925	ks: 0.999342	kt: 0.367299
# Train -> [ 5120/ 5504 (93%)]	loss: 0.964437	cls_loss: 0.007103	adv_loss_s: 1.127001	adv_loss_t: 0.787667	ks: 0.999358	kt: 0.473110
# Validation (source) -> cls_loss: 0.040369	accuracy: 98.7133%
# Validation (target) -> cls_loss: 0.540977	accuracy: 86.2239%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.799830	cls_loss: 0.017185	adv_loss_s: 0.423767	adv_loss_t: 1.141524	ks: 0.999350	kt: 0.413146
# Train -> [ 2560/ 5504 (47%)]	loss: 0.572373	cls_loss: 0.072015	adv_loss_s: 0.635361	adv_loss_t: 0.365356	ks: 0.999462	kt: 0.346345
# Train -> [ 5120/ 5504 (93%)]	loss: 0.636477	cls_loss: 0.001329	adv_loss_s: 0.733000	adv_loss_t: 0.537296	ks: 0.999379	kt: 0.385579
# Validation (source) -> cls_loss: 0.043188	accuracy: 98.6533%
# Validation (target) -> cls_loss: 0.539924	accuracy: 84.8518%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.832300	cls_loss: 0.006139	adv_loss_s: 0.871651	adv_loss_t: 0.780670	ks: 0.999382	kt: 0.363247
# Train -> [ 2560/ 5504 (47%)]	loss: 0.795701	cls_loss: 0.003355	adv_loss_s: 1.043218	adv_loss_t: 0.541473	ks: 0.999426	kt: 0.336858
# Train -> [ 5120/ 5504 (93%)]	loss: 0.643941	cls_loss: 0.017263	adv_loss_s: 0.803399	adv_loss_t: 0.449956	ks: 0.999338	kt: 0.324002
# Validation (source) -> cls_loss: 0.045965	accuracy: 98.5333%
# Validation (target) -> cls_loss: 0.544828	accuracy: 84.9616%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.855916	cls_loss: 0.031419	adv_loss_s: 0.860673	adv_loss_t: 0.788321	ks: 0.999394	kt: 0.386806
# Train -> [ 2560/ 5504 (47%)]	loss: 0.844334	cls_loss: 0.000631	adv_loss_s: 1.142811	adv_loss_t: 0.544595	ks: 0.999329	kt: 0.460702
# Train -> [ 5120/ 5504 (93%)]	loss: 1.011422	cls_loss: 0.002599	adv_loss_s: 1.119636	adv_loss_t: 0.898010	ks: 0.999355	kt: 0.372755
# Validation (source) -> cls_loss: 0.041860	accuracy: 98.6867%
# Validation (target) -> cls_loss: 0.592314	accuracy: 83.9188%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.652927	cls_loss: 0.010023	adv_loss_s: 0.800128	adv_loss_t: 0.485681	ks: 0.999325	kt: 0.342257
# Train -> [ 2560/ 5504 (47%)]	loss: 0.595212	cls_loss: 0.018198	adv_loss_s: 0.680810	adv_loss_t: 0.473219	ks: 0.999251	kt: 0.382180
# Train -> [ 5120/ 5504 (93%)]	loss: 0.784216	cls_loss: 0.003296	adv_loss_s: 0.775186	adv_loss_t: 0.786654	ks: 0.999408	kt: 0.437266
# Validation (source) -> cls_loss: 0.045268	accuracy: 98.6000%
# Validation (target) -> cls_loss: 0.634448	accuracy: 81.2843%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.783751	cls_loss: 0.005391	adv_loss_s: 0.652029	adv_loss_t: 0.904692	ks: 0.999342	kt: 0.356648
# Train -> [ 2560/ 5504 (47%)]	loss: 0.409702	cls_loss: 0.005713	adv_loss_s: 0.323911	adv_loss_t: 0.484067	ks: 0.999412	kt: 0.441656
# Train -> [ 5120/ 5504 (93%)]	loss: 0.463133	cls_loss: 0.002056	adv_loss_s: 0.584674	adv_loss_t: 0.337480	ks: 0.999352	kt: 0.351401
# Validation (source) -> cls_loss: 0.042499	accuracy: 98.8133%
# Validation (target) -> cls_loss: 0.829337	accuracy: 77.4424%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.749939	cls_loss: 0.000806	adv_loss_s: 0.818520	adv_loss_t: 0.679747	ks: 0.999454	kt: 0.306828
# Train -> [ 2560/ 5504 (47%)]	loss: 0.636547	cls_loss: 0.005210	adv_loss_s: 0.894674	adv_loss_t: 0.368001	ks: 0.999284	kt: 0.327248
# Train -> [ 5120/ 5504 (93%)]	loss: 0.462267	cls_loss: 0.006514	adv_loss_s: 0.470321	adv_loss_t: 0.441185	ks: 0.999310	kt: 0.413378
# Validation (source) -> cls_loss: 0.039619	accuracy: 98.8333%
# Validation (target) -> cls_loss: 0.665664	accuracy: 83.3699%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.561852	cls_loss: 0.092152	adv_loss_s: 0.301467	adv_loss_t: 0.637932	ks: 0.999119	kt: 0.417771
# Train -> [ 2560/ 5504 (47%)]	loss: 0.708730	cls_loss: 0.045968	adv_loss_s: 0.575370	adv_loss_t: 0.750153	ks: 0.999399	kt: 0.382222
# Train -> [ 5120/ 5504 (93%)]	loss: 1.038003	cls_loss: 0.026768	adv_loss_s: 0.952798	adv_loss_t: 1.069673	ks: 0.999371	kt: 0.367630
# Validation (source) -> cls_loss: 0.046215	accuracy: 98.6467%
# Validation (target) -> cls_loss: 0.680164	accuracy: 81.3941%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.517630	cls_loss: 0.017134	adv_loss_s: 0.496873	adv_loss_t: 0.504118	ks: 0.999418	kt: 0.410315
# Train -> [ 2560/ 5504 (47%)]	loss: 0.903340	cls_loss: 0.013824	adv_loss_s: 1.027099	adv_loss_t: 0.751934	ks: 0.999367	kt: 0.389795
# Train -> [ 5120/ 5504 (93%)]	loss: 0.738849	cls_loss: 0.018293	adv_loss_s: 0.874853	adv_loss_t: 0.566259	ks: 0.999395	kt: 0.394403
# Validation (source) -> cls_loss: 0.046152	accuracy: 98.6667%
# Validation (target) -> cls_loss: 0.558593	accuracy: 84.7420%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.560258	cls_loss: 0.028554	adv_loss_s: 0.525647	adv_loss_t: 0.537760	ks: 0.999446	kt: 0.357108
# Train -> [ 2560/ 5504 (47%)]	loss: 0.573170	cls_loss: 0.016315	adv_loss_s: 0.630786	adv_loss_t: 0.482922	ks: 0.999382	kt: 0.358295
# Train -> [ 5120/ 5504 (93%)]	loss: 1.010786	cls_loss: 0.000384	adv_loss_s: 1.676828	adv_loss_t: 0.343977	ks: 0.999376	kt: 0.410316
# Validation (source) -> cls_loss: 0.041047	accuracy: 98.8133%
# Validation (target) -> cls_loss: 0.570239	accuracy: 84.1383%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.839745	cls_loss: 0.031786	adv_loss_s: 1.085032	adv_loss_t: 0.530884	ks: 0.999404	kt: 0.413791
# Train -> [ 2560/ 5504 (47%)]	loss: 0.650880	cls_loss: 0.005505	adv_loss_s: 1.014844	adv_loss_t: 0.275907	ks: 0.999465	kt: 0.387376
# Train -> [ 5120/ 5504 (93%)]	loss: 1.095332	cls_loss: 0.002913	adv_loss_s: 0.877563	adv_loss_t: 1.307275	ks: 0.999427	kt: 0.412859
# Validation (source) -> cls_loss: 0.043112	accuracy: 98.6667%
# Validation (target) -> cls_loss: 0.714815	accuracy: 80.9001%

# %%
plot_losses(
    list(all_loss.T),
    loss_labels,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training (source)'
)
plot_losses(
    list(all_loss_val_s.T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation (source)'
)
plot_losses(
    list(all_loss_val_t.T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation (target)'
)

# %%
classifier.load_state_dict(torch.load(model_save_path))
evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
# Out:
# Test (source) -> cls_loss: 0.034175	accuracy: 98.8900%
# Test (target) -> cls_loss: 0.660954	accuracy: 82.3119%
# (0.6609537526965141, 0.8231190832087693)
