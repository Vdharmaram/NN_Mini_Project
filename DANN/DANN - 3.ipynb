# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('./data', train=True,  download=True, transform=transform)
    test_set  = dataset('./data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## Gradient Reversal Layer

# %%
class ReverseLayerF(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha
        return output, None

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %% [markdown]
# ## Dimensionality reducer

# %%
class DimensionReducer(nn.Module):
    def __init__(
        self,
        in_features: int,
        hidden_size: int,
        beta: float = 5,
        esp:  float = 1e-8
    ):
        super().__init__()
        
        self.beta = beta
        self.esp = esp
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=hidden_size*2,
                nhead=1
            ),
            num_layers=1
        )
        self.output_layer_ks = nn.Sequential(
            nn.Linear(hidden_size*2, 1),
            nn.Sigmoid()
        )
        self.output_layer_kd = nn.Sequential(
            nn.Linear(hidden_size*2, 1),
            nn.Sigmoid()
        )
    
    def forward(self, xs: torch.Tensor, xt: torch.Tensor, ks=None, kt=None) -> torch.Tensor:
        if ks is None or kt is None:
            xs1 = self.projection(xs)
            xt1 = self.projection(xt)
            x_combined = torch.cat((xs1, xt1), dim=1)
            z = self.transformer(x_combined)[0, :]
            ks = self.output_layer_ks(z)
            kt = self.output_layer_kd(z)
        
        kd = min(xs.shape[0], xs.shape[1])
        
        xs = xs - torch.mean(xs, dim=0)
        # xs = xs + self.esp
        us, ss, vhs = torch.linalg.svd(xs, full_matrices=True)
        
        xt = xt - torch.mean(xt, dim=0)
        # xt = xt + self.esp
        ut, st, vht = torch.linalg.svd(xt, full_matrices=True)
        
        i = torch.arange(kd, device=xs.device)
        ws = torch.sigmoid(-self.beta*(i - ks*kd))
        wd = torch.sigmoid(-self.beta*(i - kt*kd))
        
        ss1 = torch.diag(ss * ws)
        ss1 = torch.cat((ss1, torch.zeros((xs.shape[0] - kd, kd), device=xs.device)), dim=0)
        ss1 = torch.cat((ss1, torch.zeros((xs.shape[0], xs.shape[1] - kd), device=xs.device)), dim=1)
        xs = torch.mm(torch.mm(us, ss1), vhs)
        
        st1 = torch.diag(ss * wd)
        st1 = torch.cat((st1, torch.zeros((xt.shape[0] - kd, kd), device=xt.device)), dim=0)
        st1 = torch.cat((st1, torch.zeros((xt.shape[0], xt.shape[1] - kd), device=xt.device)), dim=1)
        xt = torch.mm(torch.mm(ut, st1), vht)
        
        return (xs, xt, ks, kt)

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor   = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
        self.dimension_reducer = DimensionReducer(self.class_regressor.in_features, 128) 
    
    def forward(self, x, k=None):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x, _, k, _ = self.dimension_reducer(x, x, k, k)
        x = self.class_regressor(x)
        return (x, k)

# %% [markdown]
# ## Domain discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_features: int, hidden_size: int):
        super().__init__()
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=hidden_size, nhead=1), num_layers=1
        )
        self.op_layer = nn.Sequential(nn.Linear(hidden_size, 1), nn.Sigmoid())
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        x = self.transformer(x)[0, :]
        x = self.op_layer(x)
        return x

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & model creation

# %%
lr_c = 1e-3
batch_size = 128
model_save_path = 'best_model.pt'

classifier = MyModel(
    input_shape=(1, 28, 28),
    output_shape=10,
    cnn_out_features=[16, 32, 64],
    fnn_out_features=[128, 64],
).to(device)
discriminator = Discriminator(classifier.class_regressor.in_features, 128).to(device)

cls_loss_fn = nn.CrossEntropyLoss()
adv_loss_fn = nn.BCELoss()

optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)

# %%
torchinfo.summary(classifier, input_size=[(batch_size, 1, 28, 28), (1,)])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                  [128, 576]                1,389,442
# ├─ClassRegressor: 1-3                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 1,495,500
# Trainable params: 1,495,500
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, k=None, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred, _ = model_c(x, k)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha):
    N = xs.shape[0]
    
    xs = classifier.feature_extractor(xs)
    xs = torch.flatten(xs, start_dim=1)
    xt = classifier.feature_extractor(xt)
    xt = torch.flatten(xt, start_dim=1)
    
    xs, xt, ks, kt = classifier.dimension_reducer(xs, xt)
    
    xs_reverse = ReverseLayerF.apply(xs, alpha)
    pt_s = discriminator(xs_reverse)
    
    xt_reverse = ReverseLayerF.apply(xt, alpha)
    pt_t = discriminator(xt_reverse)
    
    ys_pred = classifier.class_regressor(xs)
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    
    label_s = torch.zeros(1, device=device)
    label_t = torch.ones(1, device=device)
    
    adv_loss_s = adv_loss_fn(pt_s, label_s)
    adv_loss_t = adv_loss_fn(pt_t, label_t)
    
    loss = cls_loss + adv_loss_s + adv_loss_t
    
    optimizer_c.zero_grad()
    loss.backward()
    optimizer_c.step()
    
    return (loss.item(),
            cls_loss.item(),
            adv_loss_s.item(),
            adv_loss_t.item(),
            ks.item(),
            kt.item())

# %% [markdown]
# # Main

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)

# %%
num_epochs = 50
checkpoint = 20

all_loss = np.zeros((num_epochs, 6))
loss_labels = ['loss', 'cls_loss', 'adv_loss_s', 'adv_loss_t', 'ks', 'kt']

all_loss_val_s = np.zeros((num_epochs, 2))
all_loss_val_t = np.zeros((num_epochs, 2))
loss_labels_val = ['cls_loss', 'accuracy']

best_val_loss = float('inf')
best_k = 1

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1} --------')
    
    classifier.train()
    discriminator.train()
    
    len_dataloader = min(len(train_s), len(train_t))
    iter_s = iter(train_s)
    iter_t = iter(train_t)
    
    avg_loss = np.zeros(all_loss.shape[1])
    
    for batch_idx in range(len_dataloader):
        # p = float(batch_idx + epoch * len_dataloader) / num_epochs / len_dataloader
        # alpha = 2. / (1. + np.exp(-20 * p)) - 1
        alpha = 1
        
        data_s = next(iter_s)
        data_t = next(iter_t)
        
        xs, ys_true = data_s
        xt, yt_true = data_t
        if xs.shape[0] != xt.shape[0]:
            continue
        
        xs = xs.to(device)
        xt = xt.to(device)
        ys_true = ys_true.to(device)
        yt_true = yt_true.to(device)
        
        losses = train_step(xs, xt, ys_true, alpha)
        avg_loss += losses
        
        if checkpoint is not None and batch_idx % checkpoint == 0:
            print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                    batch_idx * batch_size,
                    len_dataloader * batch_size,
                    batch_idx / len_dataloader * 100
                ),
                end='\t'
            )
            for loss, label in zip(losses, loss_labels):
                print(f'{label}: {loss:.6f}', end='\t')
            print('')
    
    avg_loss = avg_loss / len_dataloader
    all_loss[epoch] = losses
    
    val_losses_s = evaluate(classifier, val_s, cls_loss_fn, k=None, mode='Validation (source)')
    val_losses_t = evaluate(classifier, val_t, cls_loss_fn, k=None, mode='Validation (target)')
    
    all_loss_val_s[epoch] = val_losses_s
    all_loss_val_t[epoch] = val_losses_t
    
    val_loss = val_losses_t[0]
    
    if val_loss < best_val_loss:
        torch.save(classifier.state_dict(), model_save_path)
        best_k = avg_loss[-1]
        best_val_loss = val_loss
        print(f'Best model updated and saved at "{model_save_path}"')
# Out:
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.907691	cls_loss: 2.302041	adv_loss_s: 0.795423	adv_loss_t: 0.810228	ks: 0.584050	kt: 0.586042
# Train -> [ 2560/ 5504 (47%)]	loss: 3.720386	cls_loss: 2.112834	adv_loss_s: 0.401163	adv_loss_t: 1.206388	ks: 0.972489	kt: 0.001125
# Train -> [ 5120/ 5504 (93%)]	loss: 6.484165	cls_loss: 1.279468	adv_loss_s: 3.695888	adv_loss_t: 1.508809	ks: 0.930597	kt: 0.988123
# Validation (source) -> cls_loss: 1.237792	accuracy: 63.8600%
# Validation (target) -> cls_loss: 1.487594	accuracy: 53.4029%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.826464	cls_loss: 1.172718	adv_loss_s: 2.358535	adv_loss_t: 0.295211	ks: 0.906695	kt: 0.995062
# Train -> [ 2560/ 5504 (47%)]	loss: 5.041624	cls_loss: 0.568271	adv_loss_s: 4.457350	adv_loss_t: 0.016002	ks: 0.880495	kt: 0.997320
# Train -> [ 5120/ 5504 (93%)]	loss: 2.262380	cls_loss: 0.335408	adv_loss_s: 1.761287	adv_loss_t: 0.165684	ks: 0.977585	kt: 0.994944
# Validation (source) -> cls_loss: 0.381051	accuracy: 89.1600%
# Validation (target) -> cls_loss: 0.890198	accuracy: 72.4479%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.187087	cls_loss: 0.422672	adv_loss_s: 2.282233	adv_loss_t: 3.482182	ks: 0.981610	kt: 0.993654
# Train -> [ 2560/ 5504 (47%)]	loss: 0.425798	cls_loss: 0.193862	adv_loss_s: 0.220004	adv_loss_t: 0.011933	ks: 0.986323	kt: 0.994047
# Train -> [ 5120/ 5504 (93%)]	loss: 0.927696	cls_loss: 0.310773	adv_loss_s: 0.144694	adv_loss_t: 0.472229	ks: 0.984743	kt: 0.994722
# Validation (source) -> cls_loss: 0.235749	accuracy: 92.9133%
# Validation (target) -> cls_loss: 0.957572	accuracy: 65.4226%
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.802812	cls_loss: 0.151920	adv_loss_s: 4.832193	adv_loss_t: 0.818699	ks: 0.986415	kt: 0.994944
# Train -> [ 2560/ 5504 (47%)]	loss: 0.980736	cls_loss: 0.361341	adv_loss_s: 0.544000	adv_loss_t: 0.075395	ks: 0.979575	kt: 0.993437
# Train -> [ 5120/ 5504 (93%)]	loss: 8.929615	cls_loss: 0.126815	adv_loss_s: 3.377768	adv_loss_t: 5.425033	ks: 0.988291	kt: 0.993129
# Validation (source) -> cls_loss: 0.175238	accuracy: 94.8133%
# Validation (target) -> cls_loss: 0.783967	accuracy: 73.1065%
# Best model updated and saved at "best_model.pt"
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.376391	cls_loss: 0.213753	adv_loss_s: 5.156091	adv_loss_t: 0.006547	ks: 0.987696	kt: 0.994114
# Train -> [ 2560/ 5504 (47%)]	loss: 7.706781	cls_loss: 0.078804	adv_loss_s: 4.569216	adv_loss_t: 3.058761	ks: 0.988067	kt: 0.993036
# Train -> [ 5120/ 5504 (93%)]	loss: 5.191843	cls_loss: 0.144695	adv_loss_s: 0.258102	adv_loss_t: 4.789046	ks: 0.985677	kt: 0.993902
# Validation (source) -> cls_loss: 0.157279	accuracy: 95.2933%
# Validation (target) -> cls_loss: 0.706856	accuracy: 78.7047%
# Best model updated and saved at "best_model.pt"
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.131284	cls_loss: 0.111324	adv_loss_s: 0.014855	adv_loss_t: 0.005106	ks: 0.986796	kt: 0.994021
# Train -> [ 2560/ 5504 (47%)]	loss: 5.246011	cls_loss: 0.102289	adv_loss_s: 0.019927	adv_loss_t: 5.123795	ks: 0.978780	kt: 0.993541
# Train -> [ 5120/ 5504 (93%)]	loss: 6.075118	cls_loss: 0.118621	adv_loss_s: 2.647731	adv_loss_t: 3.308766	ks: 0.975445	kt: 0.994353
# Validation (source) -> cls_loss: 0.146672	accuracy: 95.4933%
# Validation (target) -> cls_loss: 0.865725	accuracy: 73.1614%
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.132532	cls_loss: 0.103717	adv_loss_s: 0.004720	adv_loss_t: 0.024096	ks: 0.979658	kt: 0.993444
# Train -> [ 2560/ 5504 (47%)]	loss: 5.076771	cls_loss: 0.152583	adv_loss_s: 4.901089	adv_loss_t: 0.023100	ks: 0.970955	kt: 0.995259
# Train -> [ 5120/ 5504 (93%)]	loss: 2.133234	cls_loss: 0.143420	adv_loss_s: 1.963256	adv_loss_t: 0.026558	ks: 0.973381	kt: 0.995626
# Validation (source) -> cls_loss: 0.138390	accuracy: 95.5667%
# Validation (target) -> cls_loss: 0.854693	accuracy: 70.1976%
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 4.459850	cls_loss: 0.147049	adv_loss_s: 0.022197	adv_loss_t: 4.290605	ks: 0.974793	kt: 0.995499
# Train -> [ 2560/ 5504 (47%)]	loss: 5.986237	cls_loss: 0.155849	adv_loss_s: 1.407643	adv_loss_t: 4.422745	ks: 0.980049	kt: 0.994577
# Train -> [ 5120/ 5504 (93%)]	loss: 5.645781	cls_loss: 0.099425	adv_loss_s: 5.534794	adv_loss_t: 0.011561	ks: 0.981962	kt: 0.994511
# Validation (source) -> cls_loss: 0.126305	accuracy: 96.0600%
# Validation (target) -> cls_loss: 0.902690	accuracy: 68.4962%
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.199406	cls_loss: 0.058601	adv_loss_s: 0.137641	adv_loss_t: 1.003164	ks: 0.981482	kt: 0.995230
# Train -> [ 2560/ 5504 (47%)]	loss: 4.220244	cls_loss: 0.135926	adv_loss_s: 2.672365	adv_loss_t: 1.411953	ks: 0.985444	kt: 0.994675
# Train -> [ 5120/ 5504 (93%)]	loss: 4.610487	cls_loss: 0.057918	adv_loss_s: 0.911784	adv_loss_t: 3.640784	ks: 0.978886	kt: 0.993538
# Validation (source) -> cls_loss: 0.150156	accuracy: 95.0933%
# Validation (target) -> cls_loss: 0.945611	accuracy: 67.6180%
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.731357	cls_loss: 0.160740	adv_loss_s: 0.007761	adv_loss_t: 5.562855	ks: 0.979961	kt: 0.993903
# Train -> [ 2560/ 5504 (47%)]	loss: 9.658119	cls_loss: 0.135506	adv_loss_s: 3.812424	adv_loss_t: 5.710188	ks: 0.984033	kt: 0.993937
# Train -> [ 5120/ 5504 (93%)]	loss: 2.013574	cls_loss: 0.175148	adv_loss_s: 1.833464	adv_loss_t: 0.004962	ks: 0.985705	kt: 0.992642
# Validation (source) -> cls_loss: 0.119349	accuracy: 95.9600%
# Validation (target) -> cls_loss: 1.169053	accuracy: 68.6608%
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.563348	cls_loss: 0.151064	adv_loss_s: 2.366848	adv_loss_t: 0.045435	ks: 0.983657	kt: 0.993926
# Train -> [ 2560/ 5504 (47%)]	loss: 4.575933	cls_loss: 0.092126	adv_loss_s: 0.006755	adv_loss_t: 4.477053	ks: 0.984539	kt: 0.992891
# Train -> [ 5120/ 5504 (93%)]	loss: 10.178759	cls_loss: 0.080630	adv_loss_s: 4.492170	adv_loss_t: 5.605958	ks: 0.987484	kt: 0.993378
# Validation (source) -> cls_loss: 0.112633	accuracy: 96.5533%
# Validation (target) -> cls_loss: 1.166044	accuracy: 67.0692%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.302950	cls_loss: 0.073934	adv_loss_s: 2.027107	adv_loss_t: 0.201910	ks: 0.976224	kt: 0.971669
# Train -> [ 2560/ 5504 (47%)]	loss: 3.234984	cls_loss: 0.098906	adv_loss_s: 3.126524	adv_loss_t: 0.009553	ks: 0.981246	kt: 0.982179
# Train -> [ 5120/ 5504 (93%)]	loss: 2.204571	cls_loss: 0.068423	adv_loss_s: 2.122020	adv_loss_t: 0.014127	ks: 0.984977	kt: 0.989222
# Validation (source) -> cls_loss: 0.128539	accuracy: 95.6267%
# Validation (target) -> cls_loss: 0.749884	accuracy: 76.7838%
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.395127	cls_loss: 0.104049	adv_loss_s: 0.028731	adv_loss_t: 2.262347	ks: 0.986625	kt: 0.994317
# Train -> [ 2560/ 5504 (47%)]	loss: 0.127790	cls_loss: 0.075902	adv_loss_s: 0.006136	adv_loss_t: 0.045753	ks: 0.985839	kt: 0.994172
# Train -> [ 5120/ 5504 (93%)]	loss: 9.886450	cls_loss: 0.093957	adv_loss_s: 4.010019	adv_loss_t: 5.782473	ks: 0.987163	kt: 0.993974
# Validation (source) -> cls_loss: 0.111329	accuracy: 96.3533%
# Validation (target) -> cls_loss: 0.868113	accuracy: 72.2832%
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.953763	cls_loss: 0.118063	adv_loss_s: 0.092106	adv_loss_t: 5.743593	ks: 0.987326	kt: 0.990642
# Train -> [ 2560/ 5504 (47%)]	loss: 5.372800	cls_loss: 0.070531	adv_loss_s: 0.004458	adv_loss_t: 5.297812	ks: 0.988980	kt: 0.994173
# Train -> [ 5120/ 5504 (93%)]	loss: 1.987080	cls_loss: 0.084657	adv_loss_s: 0.042326	adv_loss_t: 1.860097	ks: 0.988363	kt: 0.990644
# Validation (source) -> cls_loss: 0.125187	accuracy: 95.9067%
# Validation (target) -> cls_loss: 1.195678	accuracy: 63.4468%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.434761	cls_loss: 0.200105	adv_loss_s: 0.032777	adv_loss_t: 5.201879	ks: 0.986563	kt: 0.992535
# Train -> [ 2560/ 5504 (47%)]	loss: 4.820985	cls_loss: 0.144457	adv_loss_s: 0.003755	adv_loss_t: 4.672773	ks: 0.986883	kt: 0.991127
# Train -> [ 5120/ 5504 (93%)]	loss: 0.243342	cls_loss: 0.070625	adv_loss_s: 0.168712	adv_loss_t: 0.004005	ks: 0.975650	kt: 0.993989
# Validation (source) -> cls_loss: 0.111230	accuracy: 96.5667%
# Validation (target) -> cls_loss: 1.107717	accuracy: 65.5324%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 7.548882	cls_loss: 0.061945	adv_loss_s: 1.733254	adv_loss_t: 5.753683	ks: 0.979222	kt: 0.994404
# Train -> [ 2560/ 5504 (47%)]	loss: 2.057224	cls_loss: 0.051444	adv_loss_s: 1.731426	adv_loss_t: 0.274355	ks: 0.950624	kt: 0.996703
# Train -> [ 5120/ 5504 (93%)]	loss: 8.917884	cls_loss: 0.158220	adv_loss_s: 2.906571	adv_loss_t: 5.853093	ks: 0.999214	kt: 0.943139
# Validation (source) -> cls_loss: 0.106133	accuracy: 96.5067%
# Validation (target) -> cls_loss: 0.984331	accuracy: 69.4292%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.139276	cls_loss: 0.052905	adv_loss_s: 5.082675	adv_loss_t: 0.003696	ks: 0.999346	kt: 0.922961
# Train -> [ 2560/ 5504 (47%)]	loss: 6.379840	cls_loss: 0.066634	adv_loss_s: 0.013217	adv_loss_t: 6.299989	ks: 0.999630	kt: 0.749161
# Train -> [ 5120/ 5504 (93%)]	loss: 5.217767	cls_loss: 0.139063	adv_loss_s: 5.072322	adv_loss_t: 0.006381	ks: 0.986731	kt: 0.000401
# Validation (source) -> cls_loss: 0.153564	accuracy: 95.1800%
# Validation (target) -> cls_loss: 1.522844	accuracy: 68.7706%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.346817	cls_loss: 0.047888	adv_loss_s: 0.073484	adv_loss_t: 0.225445	ks: 0.983966	kt: 0.000453
# Train -> [ 2560/ 5504 (47%)]	loss: 4.879983	cls_loss: 0.162631	adv_loss_s: 4.714040	adv_loss_t: 0.003312	ks: 0.962491	kt: 0.005298
# Train -> [ 5120/ 5504 (93%)]	loss: 6.674514	cls_loss: 0.193508	adv_loss_s: 0.136016	adv_loss_t: 6.344989	ks: 0.990889	kt: 0.000321
# Validation (source) -> cls_loss: 0.110482	accuracy: 96.5867%
# Validation (target) -> cls_loss: 1.236069	accuracy: 68.7157%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.073720	cls_loss: 0.064236	adv_loss_s: 0.006723	adv_loss_t: 0.002761	ks: 0.991853	kt: 0.000338
# Train -> [ 2560/ 5504 (47%)]	loss: 6.305480	cls_loss: 0.069970	adv_loss_s: 0.008082	adv_loss_t: 6.227428	ks: 0.991502	kt: 0.001020
# Train -> [ 5120/ 5504 (93%)]	loss: 0.066838	cls_loss: 0.054946	adv_loss_s: 0.008144	adv_loss_t: 0.003749	ks: 0.990990	kt: 0.003355
# Validation (source) -> cls_loss: 0.092791	accuracy: 96.9600%
# Validation (target) -> cls_loss: 1.465158	accuracy: 66.1910%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.127249	cls_loss: 0.050509	adv_loss_s: 0.004919	adv_loss_t: 6.071820	ks: 0.991925	kt: 0.002630
# Train -> [ 2560/ 5504 (47%)]	loss: 1.426837	cls_loss: 0.078862	adv_loss_s: 1.321067	adv_loss_t: 0.026908	ks: 0.990233	kt: 0.001285
# Train -> [ 5120/ 5504 (93%)]	loss: 0.369041	cls_loss: 0.129285	adv_loss_s: 0.224771	adv_loss_t: 0.014986	ks: 0.985674	kt: 0.001413
# Validation (source) -> cls_loss: 0.160887	accuracy: 95.7333%
# Validation (target) -> cls_loss: 1.752656	accuracy: 65.0384%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 10.458290	cls_loss: 0.175130	adv_loss_s: 4.317851	adv_loss_t: 5.965309	ks: 0.985400	kt: 0.000463
# Train -> [ 2560/ 5504 (47%)]	loss: 5.346255	cls_loss: 0.085212	adv_loss_s: 0.033110	adv_loss_t: 5.227932	ks: 0.987029	kt: 0.000023
# Train -> [ 5120/ 5504 (93%)]	loss: 0.503296	cls_loss: 0.117330	adv_loss_s: 0.381533	adv_loss_t: 0.004433	ks: 0.983558	kt: 0.000026
# Validation (source) -> cls_loss: 0.114617	accuracy: 96.5667%
# Validation (target) -> cls_loss: 1.573491	accuracy: 69.3743%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.853159	cls_loss: 0.122060	adv_loss_s: 2.727305	adv_loss_t: 0.003794	ks: 0.986231	kt: 0.000026
# Train -> [ 2560/ 5504 (47%)]	loss: 8.661325	cls_loss: 0.022449	adv_loss_s: 2.395754	adv_loss_t: 6.243122	ks: 0.987374	kt: 0.000022
# Train -> [ 5120/ 5504 (93%)]	loss: 1.056611	cls_loss: 0.158047	adv_loss_s: 0.892139	adv_loss_t: 0.006425	ks: 0.987383	kt: 0.000023
# Validation (source) -> cls_loss: 0.144199	accuracy: 95.7600%
# Validation (target) -> cls_loss: 1.752255	accuracy: 64.9286%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 10.508810	cls_loss: 0.084702	adv_loss_s: 4.879574	adv_loss_t: 5.544535	ks: 0.994990	kt: 0.000028
# Train -> [ 2560/ 5504 (47%)]	loss: 5.579795	cls_loss: 0.123223	adv_loss_s: 5.450653	adv_loss_t: 0.005919	ks: 0.982428	kt: 0.000028
# Train -> [ 5120/ 5504 (93%)]	loss: 0.677098	cls_loss: 0.186650	adv_loss_s: 0.485600	adv_loss_t: 0.004848	ks: 0.987038	kt: 0.000021
# Validation (source) -> cls_loss: 0.111775	accuracy: 96.6000%
# Validation (target) -> cls_loss: 1.323563	accuracy: 69.2645%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 1.102978	cls_loss: 0.070331	adv_loss_s: 1.028537	adv_loss_t: 0.004110	ks: 0.989912	kt: 0.000026
# Train -> [ 2560/ 5504 (47%)]	loss: 6.024898	cls_loss: 0.053048	adv_loss_s: 0.002531	adv_loss_t: 5.969319	ks: 0.986309	kt: 0.000021
# Train -> [ 5120/ 5504 (93%)]	loss: 11.904672	cls_loss: 0.022712	adv_loss_s: 5.689174	adv_loss_t: 6.192786	ks: 0.986851	kt: 0.000023
# Validation (source) -> cls_loss: 0.101832	accuracy: 96.9400%
# Validation (target) -> cls_loss: 1.100828	accuracy: 67.0143%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 9.205469	cls_loss: 0.016903	adv_loss_s: 3.535554	adv_loss_t: 5.653012	ks: 0.994750	kt: 0.000025
# Train -> [ 2560/ 5504 (47%)]	loss: 0.072166	cls_loss: 0.023991	adv_loss_s: 0.042897	adv_loss_t: 0.005279	ks: 0.987629	kt: 0.000023
# Train -> [ 5120/ 5504 (93%)]	loss: 0.227493	cls_loss: 0.185138	adv_loss_s: 0.021684	adv_loss_t: 0.020671	ks: 0.987138	kt: 0.000023
# Validation (source) -> cls_loss: 0.105907	accuracy: 96.8533%
# Validation (target) -> cls_loss: 1.051016	accuracy: 69.3743%
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.665526	cls_loss: 0.104911	adv_loss_s: 0.002796	adv_loss_t: 5.557818	ks: 0.988230	kt: 0.000023
# Train -> [ 2560/ 5504 (47%)]	loss: 5.060172	cls_loss: 0.057796	adv_loss_s: 4.996979	adv_loss_t: 0.005397	ks: 0.982664	kt: 0.000048
# Train -> [ 5120/ 5504 (93%)]	loss: 0.231796	cls_loss: 0.189534	adv_loss_s: 0.009054	adv_loss_t: 0.033207	ks: 0.990423	kt: 0.000030
# Validation (source) -> cls_loss: 0.111058	accuracy: 96.7000%
# Validation (target) -> cls_loss: 1.480432	accuracy: 59.4402%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.498967	cls_loss: 0.141865	adv_loss_s: 5.352033	adv_loss_t: 0.005070	ks: 0.985015	kt: 0.000049
# Train -> [ 2560/ 5504 (47%)]	loss: 9.941650	cls_loss: 0.019638	adv_loss_s: 3.906384	adv_loss_t: 6.015630	ks: 0.989395	kt: 0.000037
# Train -> [ 5120/ 5504 (93%)]	loss: 10.953898	cls_loss: 0.057362	adv_loss_s: 4.693653	adv_loss_t: 6.202884	ks: 0.985998	kt: 0.000076
# Validation (source) -> cls_loss: 0.097430	accuracy: 96.9200%
# Validation (target) -> cls_loss: 1.511329	accuracy: 60.9221%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.639040	cls_loss: 0.032858	adv_loss_s: 3.588429	adv_loss_t: 0.017752	ks: 0.987295	kt: 0.000037
# Train -> [ 2560/ 5504 (47%)]	loss: 10.495714	cls_loss: 0.048206	adv_loss_s: 4.103280	adv_loss_t: 6.344229	ks: 0.982786	kt: 0.000050
# Train -> [ 5120/ 5504 (93%)]	loss: 9.892477	cls_loss: 0.072750	adv_loss_s: 3.463084	adv_loss_t: 6.356643	ks: 0.989470	kt: 0.000052
# Validation (source) -> cls_loss: 0.086101	accuracy: 97.3267%
# Validation (target) -> cls_loss: 1.288323	accuracy: 66.1361%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.431598	cls_loss: 0.063213	adv_loss_s: 0.010614	adv_loss_t: 6.357771	ks: 0.985749	kt: 0.000058
# Train -> [ 2560/ 5504 (47%)]	loss: 10.623074	cls_loss: 0.036133	adv_loss_s: 4.567034	adv_loss_t: 6.019907	ks: 0.989386	kt: 0.000052
# Train -> [ 5120/ 5504 (93%)]	loss: 10.683767	cls_loss: 0.070795	adv_loss_s: 4.315466	adv_loss_t: 6.297507	ks: 0.985187	kt: 0.000078
# Validation (source) -> cls_loss: 0.089290	accuracy: 97.2333%
# Validation (target) -> cls_loss: 1.139907	accuracy: 71.1306%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.347121	cls_loss: 0.014653	adv_loss_s: 0.020962	adv_loss_t: 6.311506	ks: 0.983314	kt: 0.000089
# Train -> [ 2560/ 5504 (47%)]	loss: 6.575464	cls_loss: 0.157693	adv_loss_s: 0.007471	adv_loss_t: 6.410299	ks: 0.994952	kt: 0.000119
# Train -> [ 5120/ 5504 (93%)]	loss: 0.079061	cls_loss: 0.067624	adv_loss_s: 0.008237	adv_loss_t: 0.003200	ks: 0.985223	kt: 0.000074
# Validation (source) -> cls_loss: 0.089113	accuracy: 97.1400%
# Validation (target) -> cls_loss: 1.004451	accuracy: 73.7102%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.293376	cls_loss: 0.048103	adv_loss_s: 5.242450	adv_loss_t: 0.002824	ks: 0.984365	kt: 0.000080
# Train -> [ 2560/ 5504 (47%)]	loss: 0.165408	cls_loss: 0.115923	adv_loss_s: 0.044654	adv_loss_t: 0.004832	ks: 0.983110	kt: 0.000088
# Train -> [ 5120/ 5504 (93%)]	loss: 5.184529	cls_loss: 0.050436	adv_loss_s: 5.130246	adv_loss_t: 0.003847	ks: 0.981872	kt: 0.000146
# Validation (source) -> cls_loss: 0.088500	accuracy: 97.3000%
# Validation (target) -> cls_loss: 1.220393	accuracy: 69.6487%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.669642	cls_loss: 0.053782	adv_loss_s: 0.612483	adv_loss_t: 0.003376	ks: 0.981473	kt: 0.000140
# Train -> [ 2560/ 5504 (47%)]	loss: 11.519413	cls_loss: 0.029526	adv_loss_s: 5.269217	adv_loss_t: 6.220669	ks: 0.979780	kt: 0.000154
# Train -> [ 5120/ 5504 (93%)]	loss: 4.193443	cls_loss: 0.037857	adv_loss_s: 0.547393	adv_loss_t: 3.608193	ks: 0.993234	kt: 0.000157
# Validation (source) -> cls_loss: 0.138474	accuracy: 95.8733%
# Validation (target) -> cls_loss: 1.578076	accuracy: 64.7640%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 5.816007	cls_loss: 0.106698	adv_loss_s: 0.009952	adv_loss_t: 5.699358	ks: 0.993852	kt: 0.000283
# Train -> [ 2560/ 5504 (47%)]	loss: 10.666214	cls_loss: 0.068621	adv_loss_s: 4.587530	adv_loss_t: 6.010064	ks: 0.984633	kt: 0.000420
# Train -> [ 5120/ 5504 (93%)]	loss: 11.459158	cls_loss: 0.049843	adv_loss_s: 5.492396	adv_loss_t: 5.916919	ks: 0.983365	kt: 0.000330
# Validation (source) -> cls_loss: 0.107519	accuracy: 96.8267%
# Validation (target) -> cls_loss: 0.932799	accuracy: 77.8814%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.040639	cls_loss: 0.052087	adv_loss_s: 2.984998	adv_loss_t: 0.003554	ks: 0.986211	kt: 0.000305
# Train -> [ 2560/ 5504 (47%)]	loss: 4.384055	cls_loss: 0.050603	adv_loss_s: 4.328665	adv_loss_t: 0.004787	ks: 0.985031	kt: 0.000612
# Train -> [ 5120/ 5504 (93%)]	loss: 6.200875	cls_loss: 0.083050	adv_loss_s: 0.129971	adv_loss_t: 5.987854	ks: 0.971099	kt: 0.000545
# Validation (source) -> cls_loss: 0.125733	accuracy: 96.2467%
# Validation (target) -> cls_loss: 1.453669	accuracy: 67.8924%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 4.682559	cls_loss: 0.217574	adv_loss_s: 4.460378	adv_loss_t: 0.004608	ks: 0.971595	kt: 0.000522
# Train -> [ 2560/ 5504 (47%)]	loss: 5.260294	cls_loss: 0.062713	adv_loss_s: 0.209165	adv_loss_t: 4.988416	ks: 0.941251	kt: 0.922273
# Train -> [ 5120/ 5504 (93%)]	loss: 8.358505	cls_loss: 0.114716	adv_loss_s: 2.172981	adv_loss_t: 6.070808	ks: 0.188962	kt: 0.000904
# Validation (source) -> cls_loss: 0.418398	accuracy: 88.1867%
# Validation (target) -> cls_loss: 1.639935	accuracy: 59.9890%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 10.052719	cls_loss: 0.322721	adv_loss_s: 4.850947	adv_loss_t: 4.879050	ks: 0.093681	kt: 0.000765
# Train -> [ 2560/ 5504 (47%)]	loss: 9.576683	cls_loss: 0.064329	adv_loss_s: 3.761894	adv_loss_t: 5.750460	ks: 0.973274	kt: 0.000480
# Train -> [ 5120/ 5504 (93%)]	loss: 5.982611	cls_loss: 0.022923	adv_loss_s: 0.003078	adv_loss_t: 5.956610	ks: 0.991668	kt: 0.007042
# Validation (source) -> cls_loss: 0.093067	accuracy: 97.2667%
# Validation (target) -> cls_loss: 0.908874	accuracy: 74.3688%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.053025	cls_loss: 0.028626	adv_loss_s: 0.003679	adv_loss_t: 6.020720	ks: 0.993432	kt: 0.001040
# Train -> [ 2560/ 5504 (47%)]	loss: 6.668917	cls_loss: 0.046236	adv_loss_s: 0.468152	adv_loss_t: 6.154529	ks: 0.994563	kt: 0.004307
# Train -> [ 5120/ 5504 (93%)]	loss: 11.406324	cls_loss: 0.100705	adv_loss_s: 5.071534	adv_loss_t: 6.234087	ks: 0.994040	kt: 0.000097
# Validation (source) -> cls_loss: 0.093509	accuracy: 97.1733%
# Validation (target) -> cls_loss: 0.624700	accuracy: 83.2053%
# Best model updated and saved at "best_model.pt"
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.053300	cls_loss: 0.031887	adv_loss_s: 0.013833	adv_loss_t: 0.007580	ks: 0.979806	kt: 0.000042
# Train -> [ 2560/ 5504 (47%)]	loss: 6.515904	cls_loss: 0.117329	adv_loss_s: 0.034012	adv_loss_t: 6.364563	ks: 0.993530	kt: 0.000074
# Train -> [ 5120/ 5504 (93%)]	loss: 6.356058	cls_loss: 0.027012	adv_loss_s: 0.006910	adv_loss_t: 6.322136	ks: 0.993151	kt: 0.000117
# Validation (source) -> cls_loss: 0.083228	accuracy: 97.4533%
# Validation (target) -> cls_loss: 0.963995	accuracy: 69.9780%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 11.829851	cls_loss: 0.048770	adv_loss_s: 5.449543	adv_loss_t: 6.331540	ks: 0.994495	kt: 0.000045
# Train -> [ 2560/ 5504 (47%)]	loss: 10.089306	cls_loss: 0.066633	adv_loss_s: 3.834143	adv_loss_t: 6.188530	ks: 0.994238	kt: 0.000047
# Train -> [ 5120/ 5504 (93%)]	loss: 6.217816	cls_loss: 0.105330	adv_loss_s: 0.198921	adv_loss_t: 5.913565	ks: 0.993881	kt: 0.000105
# Validation (source) -> cls_loss: 0.092643	accuracy: 97.2333%
# Validation (target) -> cls_loss: 1.424144	accuracy: 62.6784%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.471171	cls_loss: 0.096986	adv_loss_s: 0.311694	adv_loss_t: 6.062492	ks: 0.994163	kt: 0.000071
# Train -> [ 2560/ 5504 (47%)]	loss: 1.585234	cls_loss: 0.051611	adv_loss_s: 1.456305	adv_loss_t: 0.077318	ks: 0.994169	kt: 0.000072
# Train -> [ 5120/ 5504 (93%)]	loss: 6.443890	cls_loss: 0.060794	adv_loss_s: 0.044723	adv_loss_t: 6.338373	ks: 0.993188	kt: 0.000198
# Validation (source) -> cls_loss: 0.074366	accuracy: 97.6933%
# Validation (target) -> cls_loss: 1.399915	accuracy: 66.7398%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 11.200976	cls_loss: 0.043873	adv_loss_s: 4.797412	adv_loss_t: 6.359691	ks: 0.992037	kt: 0.000143
# Train -> [ 2560/ 5504 (47%)]	loss: 5.594838	cls_loss: 0.035421	adv_loss_s: 5.556487	adv_loss_t: 0.002930	ks: 0.993320	kt: 0.000132
# Train -> [ 5120/ 5504 (93%)]	loss: 8.915924	cls_loss: 0.045425	adv_loss_s: 2.490205	adv_loss_t: 6.380295	ks: 0.993846	kt: 0.000187
# Validation (source) -> cls_loss: 0.081687	accuracy: 97.3867%
# Validation (target) -> cls_loss: 1.300393	accuracy: 67.1240%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.946752	cls_loss: 0.046999	adv_loss_s: 3.896646	adv_loss_t: 0.003108	ks: 0.991370	kt: 0.000245
# Train -> [ 2560/ 5504 (47%)]	loss: 0.085243	cls_loss: 0.052563	adv_loss_s: 0.028705	adv_loss_t: 0.003976	ks: 0.987204	kt: 0.000085
# Train -> [ 5120/ 5504 (93%)]	loss: 0.076125	cls_loss: 0.039650	adv_loss_s: 0.032691	adv_loss_t: 0.003784	ks: 0.990352	kt: 0.000660
# Validation (source) -> cls_loss: 0.075473	accuracy: 97.7733%
# Validation (target) -> cls_loss: 1.322345	accuracy: 66.9594%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.452269	cls_loss: 0.085976	adv_loss_s: 0.004342	adv_loss_t: 6.361951	ks: 0.982426	kt: 0.000079
# Train -> [ 2560/ 5504 (47%)]	loss: 0.053202	cls_loss: 0.032190	adv_loss_s: 0.015406	adv_loss_t: 0.005605	ks: 0.986444	kt: 0.002321
# Train -> [ 5120/ 5504 (93%)]	loss: 6.228160	cls_loss: 0.081246	adv_loss_s: 0.017356	adv_loss_t: 6.129558	ks: 0.981024	kt: 0.001359
# Validation (source) -> cls_loss: 0.084666	accuracy: 97.4533%
# Validation (target) -> cls_loss: 1.431530	accuracy: 65.5873%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.239942	cls_loss: 0.059555	adv_loss_s: 0.083941	adv_loss_t: 6.096446	ks: 0.987152	kt: 0.001587
# Train -> [ 2560/ 5504 (47%)]	loss: 11.651182	cls_loss: 0.070279	adv_loss_s: 5.330751	adv_loss_t: 6.250152	ks: 0.976336	kt: 0.000354
# Train -> [ 5120/ 5504 (93%)]	loss: 6.270188	cls_loss: 0.040841	adv_loss_s: 0.009754	adv_loss_t: 6.219593	ks: 0.989835	kt: 0.000947
# Validation (source) -> cls_loss: 0.100859	accuracy: 96.9867%
# Validation (target) -> cls_loss: 1.703468	accuracy: 57.2448%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.497458	cls_loss: 0.095592	adv_loss_s: 0.236440	adv_loss_t: 6.165426	ks: 0.991114	kt: 0.000919
# Train -> [ 2560/ 5504 (47%)]	loss: 0.121209	cls_loss: 0.111936	adv_loss_s: 0.004871	adv_loss_t: 0.004403	ks: 0.990086	kt: 0.001361
# Train -> [ 5120/ 5504 (93%)]	loss: 0.557375	cls_loss: 0.059902	adv_loss_s: 0.493674	adv_loss_t: 0.003799	ks: 0.971593	kt: 0.000942
# Validation (source) -> cls_loss: 0.098516	accuracy: 96.9800%
# Validation (target) -> cls_loss: 1.188079	accuracy: 70.6915%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 4.173258	cls_loss: 0.038866	adv_loss_s: 4.130893	adv_loss_t: 0.003499	ks: 0.975423	kt: 0.000908
# Train -> [ 2560/ 5504 (47%)]	loss: 1.271396	cls_loss: 0.150101	adv_loss_s: 1.093426	adv_loss_t: 0.027869	ks: 0.987050	kt: 0.001059
# Train -> [ 5120/ 5504 (93%)]	loss: 2.321853	cls_loss: 0.058414	adv_loss_s: 2.260678	adv_loss_t: 0.002761	ks: 0.988410	kt: 0.000450
# Validation (source) -> cls_loss: 0.088271	accuracy: 97.3933%
# Validation (target) -> cls_loss: 0.901249	accuracy: 75.0274%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 11.262496	cls_loss: 0.088601	adv_loss_s: 4.991850	adv_loss_t: 6.182045	ks: 0.986687	kt: 0.000626
# Train -> [ 2560/ 5504 (47%)]	loss: 9.117197	cls_loss: 0.025348	adv_loss_s: 3.701957	adv_loss_t: 5.389892	ks: 0.986219	kt: 0.001282
# Train -> [ 5120/ 5504 (93%)]	loss: 10.019051	cls_loss: 0.035877	adv_loss_s: 3.790536	adv_loss_t: 6.192637	ks: 0.987538	kt: 0.004149
# Validation (source) -> cls_loss: 0.080154	accuracy: 97.5200%
# Validation (target) -> cls_loss: 1.227347	accuracy: 68.6608%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 7.548061	cls_loss: 0.009948	adv_loss_s: 1.568680	adv_loss_t: 5.969434	ks: 0.988402	kt: 0.003884
# Train -> [ 2560/ 5504 (47%)]	loss: 6.325537	cls_loss: 0.023716	adv_loss_s: 0.003009	adv_loss_t: 6.298812	ks: 0.990195	kt: 0.001551
# Train -> [ 5120/ 5504 (93%)]	loss: 6.492209	cls_loss: 0.155636	adv_loss_s: 0.004023	adv_loss_t: 6.332549	ks: 0.991430	kt: 0.000525
# Validation (source) -> cls_loss: 0.075392	accuracy: 97.6400%
# Validation (target) -> cls_loss: 1.006461	accuracy: 71.5697%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 3.971108	cls_loss: 0.042256	adv_loss_s: 3.925867	adv_loss_t: 0.002986	ks: 0.990962	kt: 0.000509
# Train -> [ 2560/ 5504 (47%)]	loss: 0.104527	cls_loss: 0.038305	adv_loss_s: 0.059517	adv_loss_t: 0.006705	ks: 0.992475	kt: 0.000256
# Train -> [ 5120/ 5504 (93%)]	loss: 0.056542	cls_loss: 0.037500	adv_loss_s: 0.015925	adv_loss_t: 0.003117	ks: 0.988333	kt: 0.000297
# Validation (source) -> cls_loss: 0.072876	accuracy: 97.6867%
# Validation (target) -> cls_loss: 1.238010	accuracy: 65.4775%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 6.490860	cls_loss: 0.065956	adv_loss_s: 0.003088	adv_loss_t: 6.421817	ks: 0.993114	kt: 0.000031
# Train -> [ 2560/ 5504 (47%)]	loss: 4.272561	cls_loss: 0.017111	adv_loss_s: 4.252356	adv_loss_t: 0.003094	ks: 0.992733	kt: 0.000238
# Train -> [ 5120/ 5504 (93%)]	loss: 6.487009	cls_loss: 0.067195	adv_loss_s: 0.003626	adv_loss_t: 6.416188	ks: 0.991671	kt: 0.000449
# Validation (source) -> cls_loss: 0.080022	accuracy: 97.4667%
# Validation (target) -> cls_loss: 0.980724	accuracy: 72.5576%

# %%
plot_losses(
    list(all_loss.T),
    loss_labels,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training (source)'
)
plot_losses(
    list(all_loss_val_s.T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation (source)'
)
plot_losses(
    list(all_loss_val_t.T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation (target)'
)

# %%
classifier.load_state_dict(torch.load(model_save_path))
evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
# Out:
# Test (source) -> cls_loss: 0.077894	accuracy: 97.6500%
# Test (target) -> cls_loss: 0.849830	accuracy: 79.2227%
# (0.8498296402394772, 0.7922272047832586)
