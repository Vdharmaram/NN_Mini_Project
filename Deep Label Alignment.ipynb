# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('./data', train=True,  download=True, transform=transform)
    test_set  = dataset('./data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %% [markdown]
# ## K-Regressor

# %%
class KRegressor(nn.Module):
    def __init__(self, input_shape: int, hidden_size: int):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=hidden_size,
                nhead=1
            ),
            num_layers=1
        )
        self.output_layer = nn.Sequential(
            nn.Linear(hidden_size, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        z = self.transformer(x)[0, :]
        k = self.output_layer(z)
        return k

# %% [markdown]
# ## Dimensionality reducer

# %%
class DimensionReducer(nn.Module):
    def __init__(
        self,
        in_features: int,
        hidden_size: int,
        beta: float = 5.0,
        esp:  float = 1e-8
    ):
        super().__init__()
        
        self.beta = beta
        self.esp = esp
        self.k_regressor = KRegressor(in_features, hidden_size)
        self.k = nn.Parameter(torch.randn(1))
        self.k.requires_grad = True
    
    def forward(self, xs: torch.Tensor) -> torch.Tensor:
        kd = min(xs.shape[0], xs.shape[1])
        # ks = self.k_regressor(xs)
        ks = F.sigmoid(self.k)
        
        xs = xs - torch.mean(xs, dim=0)
        # xs = xs + self.esp
        us, ss, vhs = torch.linalg.svd(xs, full_matrices=False)
        
        i = torch.arange(kd, device=xs.device)
        ws = torch.sigmoid(-self.beta*(i - ks*kd))
        
        ss1 = torch.diag(ss * ws)
        xs = torch.mm(torch.mm(us, ss1), vhs)
        
        return (xs, ks)

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor   = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
        self.dimension_reducer = DimensionReducer(self.feature_extractor.output_shape, hidden_size=128)
    
    def forward(self, x):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x, k = self.dimension_reducer(x)
        x = self.class_regressor(x)
        return (x, k)

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & dataset creation

# %%
lr_c = 1e-3
batch_size = 128
model_save_path = 'best_model.pt'

num_epochs = 50
checkpoint = 20

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred, _ = model_c(x)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha, gamma):
    N = xs.shape[0]
    
    ys_pred, ks = classifier(xs)
    
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    k_loss = ks**2
    
    # alignment to target
    kd = min(xs.shape[0], xs.shape[1])
    
    xt = classifier.feature_extractor(xt)
    xt = torch.flatten(xt, start_dim=1)
    
    xt = xt - torch.mean(xt, dim=0)
    # xs = xs + self.esp
    ut, st, vht = torch.linalg.svd(xt, full_matrices=False)

    i = torch.arange(kd, device=xs.device)
    beta = classifier.dimension_reducer.beta
    wt = torch.sigmoid(-beta*(i - ks*kd))
    wt = 1 - wt

    st1 = torch.diag(st * wt)
    xt = torch.mm(torch.mm(ut, st1), vht)
    
    yt_pred = classifier.class_regressor(xt)
    yt_true = torch.zeros(N, classifier.class_regressor.out_features, device=device)
    
    lat_loss = F.mse_loss(yt_pred, yt_true)
    
    loss = cls_loss + alpha*ks + gamma*lat_loss
    
    optimizer_c.zero_grad()
    loss.backward()
    optimizer_c.step()
    
    return (
        loss.item(),
        cls_loss.item(),
        k_loss.item(),
        ks.item(),
        lat_loss.item()
    )

# %% [markdown]
# # Main

# %%
def main():
    global classifier, dimension_reducer
    global cls_loss_fn
    global optimizer_c
    global loss_labels_train, loss_labels_val
    
    classifier = MyModel(
        input_shape=(1, 28, 28),
        output_shape=10,
        cnn_out_features=[16, 32, 64],
        fnn_out_features=[128, 64],
    ).to(device)
    
    dimension_reducer = DimensionReducer(
        classifier.class_regressor.in_features,
        hidden_size=128
    ).to(device)
    
    print(torchinfo.summary(classifier, input_size=(batch_size, 1, 28, 28)))
    
    cls_loss_fn = nn.CrossEntropyLoss()
    optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)
    
    all_loss = np.zeros((num_epochs, 5))
    loss_labels_train = ['loss', 'cls_loss', 'k_loss', 'k', 'lat_loss']

    all_loss_val = np.zeros((num_epochs, 4))
    all_loss_test = np.zeros((1, 4))
    loss_labels_val = ['cls_loss_s', 'accuracy_s', 'cls_loss_t', 'accuracy_t']
    
    best_val_loss = float('inf')
    best_k = 1
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1} --------')

        classifier.train()

        len_dataloader = min(len(train_s), len(train_t))
        iter_s = iter(train_s)
        iter_t = iter(train_t)

        avg_loss = np.zeros(all_loss.shape[1])

        for batch_idx in range(len_dataloader):
            p = float(batch_idx + epoch*len_dataloader) / (num_epochs*len_dataloader)
            # alpha = 2 / (1 + np.exp(-10 * p)) - 1
            alpha = 1e-3
            gamma = 1e-3
            
            # if epoch % 5 == 0 and epoch != 0:
            #     for param in classifier.feature_extractor.parameters():
            #         param.requires_grad = False
            #     for param in classifier.dimension_reducer.parameters():
            #         param.requires_grad = False
            # else:
            #     for param in classifier.feature_extractor.parameters():
            #         param.requires_grad = True
            #     for param in classifier.dimension_reducer.parameters():
            #         param.requires_grad = True

            data_s = next(iter_s)
            data_t = next(iter_t)

            xs, ys_true = data_s
            xt, yt_true = data_t
            if xs.shape[0] != xt.shape[0]:
                continue

            xs = xs.to(device)
            xt = xt.to(device)
            ys_true = ys_true.to(device)
            yt_true = yt_true.to(device)

            losses = train_step(xs, xt, ys_true, alpha, gamma)
            avg_loss += losses

            if checkpoint is not None and batch_idx % checkpoint == 0:
                print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                        batch_idx * batch_size,
                        len_dataloader * batch_size,
                        batch_idx / len_dataloader * 100
                    ),
                    end='\t'
                )
                for loss, label in zip(losses, loss_labels_train):
                    print(f'{label}: {loss:.6f}', end='\t')
                print('')

        avg_loss = avg_loss / len_dataloader
        all_loss[epoch] = losses

        val_losses_s = evaluate(classifier, val_s, cls_loss_fn, mode='Validation (source)')
        val_losses_t = evaluate(classifier, val_t, cls_loss_fn, mode='Validation (target)')

        all_loss_val[epoch] = val_losses_s + val_losses_t

        val_loss = val_losses_t[0]

        if val_loss < best_val_loss:
            torch.save(classifier.state_dict(), model_save_path)
            best_k = avg_loss[-1]
            best_val_loss = val_loss
            print(f'Best model updated and saved at "{model_save_path}"')
    
    classifier.load_state_dict(torch.load(model_save_path))
    test_loss_s = evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
    test_loss_t = evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
    
    all_loss_test = test_loss_s + test_loss_t
    
    return (all_loss, all_loss_val, all_loss_test)

# %%
all_loss_train = []
all_loss_val   = []
all_loss_test  = []
for i in range(5):
    loss_train, loss_val, loss_test = main()
    all_loss_train.append(loss_train)
    all_loss_val.append(loss_val)
    all_loss_test.append(loss_test)

all_loss_train = np.array(all_loss_train)
all_loss_val   = np.array(all_loss_val)
all_loss_test  = np.array(all_loss_test)
# Out:
# C:\Program Files\Python310\lib\site-packages\torch\nn\functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                  [128, 576]                667,010
# ├─ClassRegressor: 1-3                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 773,068
# Trainable params: 773,068
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.308138	cls_loss: 2.307955	k_loss: 0.032407	k: 0.180019	lat_loss: 0.002849
# Train -> [ 2560/ 5504 (47%)]	loss: 1.393409	cls_loss: 1.393159	k_loss: 0.032612	k: 0.180587	lat_loss: 0.069721
# Train -> [ 5120/ 5504 (93%)]	loss: 0.415123	cls_loss: 0.414379	k_loss: 0.033551	k: 0.183169	lat_loss: 0.559953
# Validation (source) -> cls_loss: 0.387486	accuracy: 89.0067%
# Validation (target) -> cls_loss: 1.033392	accuracy: 64.4347%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.400017	cls_loss: 0.399291	k_loss: 0.033650	k: 0.183440	lat_loss: 0.542019
# Train -> [ 2560/ 5504 (47%)]	loss: 0.200454	cls_loss: 0.199549	k_loss: 0.034230	k: 0.185013	lat_loss: 0.720052
# Train -> [ 5120/ 5504 (93%)]	loss: 0.190754	cls_loss: 0.190022	k_loss: 0.035162	k: 0.187516	lat_loss: 0.544694
# Validation (source) -> cls_loss: 0.208489	accuracy: 93.7267%
# Validation (target) -> cls_loss: 0.928003	accuracy: 68.5510%
# Best model updated and saved at "best_model.pt"
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.174308	cls_loss: 0.173577	k_loss: 0.035211	k: 0.187647	lat_loss: 0.543808
# Train -> [ 2560/ 5504 (47%)]	loss: 0.147632	cls_loss: 0.146866	k_loss: 0.035939	k: 0.189575	lat_loss: 0.576908
# Train -> [ 5120/ 5504 (93%)]	loss: 0.076487	cls_loss: 0.075679	k_loss: 0.036524	k: 0.191113	lat_loss: 0.616820
# Validation (source) -> cls_loss: 0.151446	accuracy: 95.4000%
# Validation (target) -> cls_loss: 0.985263	accuracy: 66.9045%
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.150205	cls_loss: 0.149383	k_loss: 0.036569	k: 0.191231	lat_loss: 0.630516
# Train -> [ 2560/ 5504 (47%)]	loss: 0.085974	cls_loss: 0.085110	k_loss: 0.036866	k: 0.192004	lat_loss: 0.671564
# Train -> [ 5120/ 5504 (93%)]	loss: 0.070213	cls_loss: 0.069339	k_loss: 0.037185	k: 0.192833	lat_loss: 0.680785
# Validation (source) -> cls_loss: 0.127214	accuracy: 96.1600%
# Validation (target) -> cls_loss: 0.963630	accuracy: 68.4962%
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.104296	cls_loss: 0.103464	k_loss: 0.037227	k: 0.192943	lat_loss: 0.638460
# Train -> [ 2560/ 5504 (47%)]	loss: 0.096995	cls_loss: 0.096126	k_loss: 0.038093	k: 0.195174	lat_loss: 0.674204
# Train -> [ 5120/ 5504 (93%)]	loss: 0.134149	cls_loss: 0.133291	k_loss: 0.038695	k: 0.196710	lat_loss: 0.661531
# Validation (source) -> cls_loss: 0.114780	accuracy: 96.4200%
# Validation (target) -> cls_loss: 1.094353	accuracy: 69.7585%
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.109197	cls_loss: 0.108331	k_loss: 0.038694	k: 0.196708	lat_loss: 0.669001
# Train -> [ 2560/ 5504 (47%)]	loss: 0.087720	cls_loss: 0.086827	k_loss: 0.039033	k: 0.197567	lat_loss: 0.695242
# Train -> [ 5120/ 5504 (93%)]	loss: 0.048496	cls_loss: 0.047528	k_loss: 0.039366	k: 0.198408	lat_loss: 0.769321
# Validation (source) -> cls_loss: 0.095831	accuracy: 97.0933%
# Validation (target) -> cls_loss: 0.999869	accuracy: 72.2283%
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.034450	cls_loss: 0.033442	k_loss: 0.039399	k: 0.198491	lat_loss: 0.809480
# Train -> [ 2560/ 5504 (47%)]	loss: 0.047126	cls_loss: 0.046131	k_loss: 0.039574	k: 0.198931	lat_loss: 0.795321
# Train -> [ 5120/ 5504 (93%)]	loss: 0.077452	cls_loss: 0.076510	k_loss: 0.039817	k: 0.199543	lat_loss: 0.741917
# Validation (source) -> cls_loss: 0.098158	accuracy: 96.9667%
# Validation (target) -> cls_loss: 0.812534	accuracy: 76.5642%
# Best model updated and saved at "best_model.pt"
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.057152	cls_loss: 0.056165	k_loss: 0.039837	k: 0.199593	lat_loss: 0.787472
# Train -> [ 2560/ 5504 (47%)]	loss: 0.042754	cls_loss: 0.041727	k_loss: 0.040029	k: 0.200073	lat_loss: 0.827405
# Train -> [ 5120/ 5504 (93%)]	loss: 0.093461	cls_loss: 0.092437	k_loss: 0.040374	k: 0.200932	lat_loss: 0.823503
# Validation (source) -> cls_loss: 0.083021	accuracy: 97.6333%
# Validation (target) -> cls_loss: 0.928435	accuracy: 71.7344%
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.059039	cls_loss: 0.058117	k_loss: 0.040380	k: 0.200947	lat_loss: 0.720686
# Train -> [ 2560/ 5504 (47%)]	loss: 0.076500	cls_loss: 0.075515	k_loss: 0.040745	k: 0.201855	lat_loss: 0.782886
# Train -> [ 5120/ 5504 (93%)]	loss: 0.042382	cls_loss: 0.041296	k_loss: 0.041164	k: 0.202890	lat_loss: 0.883031
# Validation (source) -> cls_loss: 0.084612	accuracy: 97.3400%
# Validation (target) -> cls_loss: 0.997904	accuracy: 73.1614%
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.095231	cls_loss: 0.094163	k_loss: 0.041189	k: 0.202950	lat_loss: 0.865073
# Train -> [ 2560/ 5504 (47%)]	loss: 0.035121	cls_loss: 0.034158	k_loss: 0.041458	k: 0.203611	lat_loss: 0.759617
# Train -> [ 5120/ 5504 (93%)]	loss: 0.080895	cls_loss: 0.079904	k_loss: 0.041996	k: 0.204930	lat_loss: 0.786674
# Validation (source) -> cls_loss: 0.076636	accuracy: 97.7133%
# Validation (target) -> cls_loss: 0.759476	accuracy: 77.3875%
# Best model updated and saved at "best_model.pt"
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.022145	cls_loss: 0.021122	k_loss: 0.041988	k: 0.204909	lat_loss: 0.818858
# Train -> [ 2560/ 5504 (47%)]	loss: 0.061308	cls_loss: 0.060452	k_loss: 0.042293	k: 0.205652	lat_loss: 0.650105
# Train -> [ 5120/ 5504 (93%)]	loss: 0.050861	cls_loss: 0.049913	k_loss: 0.042616	k: 0.206436	lat_loss: 0.741628
# Validation (source) -> cls_loss: 0.073126	accuracy: 97.8267%
# Validation (target) -> cls_loss: 0.843708	accuracy: 74.3139%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.086479	cls_loss: 0.085604	k_loss: 0.042655	k: 0.206531	lat_loss: 0.668953
# Train -> [ 2560/ 5504 (47%)]	loss: 0.038698	cls_loss: 0.037642	k_loss: 0.042742	k: 0.206742	lat_loss: 0.848856
# Train -> [ 5120/ 5504 (93%)]	loss: 0.141189	cls_loss: 0.140280	k_loss: 0.042794	k: 0.206868	lat_loss: 0.701904
# Validation (source) -> cls_loss: 0.066804	accuracy: 97.9467%
# Validation (target) -> cls_loss: 0.881400	accuracy: 72.5027%
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.013513	cls_loss: 0.012655	k_loss: 0.042804	k: 0.206892	lat_loss: 0.651509
# Train -> [ 2560/ 5504 (47%)]	loss: 0.040365	cls_loss: 0.039359	k_loss: 0.042820	k: 0.206930	lat_loss: 0.798964
# Train -> [ 5120/ 5504 (93%)]	loss: 0.080865	cls_loss: 0.079850	k_loss: 0.043006	k: 0.207378	lat_loss: 0.808084
# Validation (source) -> cls_loss: 0.070667	accuracy: 97.8867%
# Validation (target) -> cls_loss: 0.720010	accuracy: 77.7717%
# Best model updated and saved at "best_model.pt"
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.037733	cls_loss: 0.036699	k_loss: 0.043031	k: 0.207440	lat_loss: 0.826003
# Train -> [ 2560/ 5504 (47%)]	loss: 0.084932	cls_loss: 0.083907	k_loss: 0.043255	k: 0.207979	lat_loss: 0.817059
# Train -> [ 5120/ 5504 (93%)]	loss: 0.087539	cls_loss: 0.086446	k_loss: 0.043635	k: 0.208891	lat_loss: 0.883836
# Validation (source) -> cls_loss: 0.077222	accuracy: 97.7200%
# Validation (target) -> cls_loss: 1.005326	accuracy: 72.9418%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.085850	cls_loss: 0.084744	k_loss: 0.043691	k: 0.209023	lat_loss: 0.897400
# Train -> [ 2560/ 5504 (47%)]	loss: 0.034280	cls_loss: 0.033375	k_loss: 0.044146	k: 0.210110	lat_loss: 0.694809
# Train -> [ 5120/ 5504 (93%)]	loss: 0.063249	cls_loss: 0.062178	k_loss: 0.044450	k: 0.210831	lat_loss: 0.860531
# Validation (source) -> cls_loss: 0.073526	accuracy: 97.7133%
# Validation (target) -> cls_loss: 1.024164	accuracy: 70.1976%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.037620	cls_loss: 0.036550	k_loss: 0.044425	k: 0.210773	lat_loss: 0.859975
# Train -> [ 2560/ 5504 (47%)]	loss: 0.016432	cls_loss: 0.015581	k_loss: 0.044172	k: 0.210171	lat_loss: 0.641381
# Train -> [ 5120/ 5504 (93%)]	loss: 0.035930	cls_loss: 0.034965	k_loss: 0.044994	k: 0.212118	lat_loss: 0.753092
# Validation (source) -> cls_loss: 0.063217	accuracy: 98.1533%
# Validation (target) -> cls_loss: 0.939048	accuracy: 72.1734%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.032220	cls_loss: 0.031211	k_loss: 0.045021	k: 0.212181	lat_loss: 0.797093
# Train -> [ 2560/ 5504 (47%)]	loss: 0.024846	cls_loss: 0.023920	k_loss: 0.045204	k: 0.212613	lat_loss: 0.712988
# Train -> [ 5120/ 5504 (93%)]	loss: 0.030027	cls_loss: 0.029152	k_loss: 0.045362	k: 0.212984	lat_loss: 0.662346
# Validation (source) -> cls_loss: 0.074079	accuracy: 97.6733%
# Validation (target) -> cls_loss: 0.936079	accuracy: 73.7651%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.058721	cls_loss: 0.057814	k_loss: 0.045381	k: 0.213028	lat_loss: 0.694051
# Train -> [ 2560/ 5504 (47%)]	loss: 0.068981	cls_loss: 0.068140	k_loss: 0.045528	k: 0.213374	lat_loss: 0.627967
# Train -> [ 5120/ 5504 (93%)]	loss: 0.056391	cls_loss: 0.055575	k_loss: 0.045957	k: 0.214376	lat_loss: 0.601563
# Validation (source) -> cls_loss: 0.063928	accuracy: 97.9733%
# Validation (target) -> cls_loss: 0.867551	accuracy: 74.3139%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.014096	cls_loss: 0.013203	k_loss: 0.046005	k: 0.214487	lat_loss: 0.677943
# Train -> [ 2560/ 5504 (47%)]	loss: 0.148620	cls_loss: 0.147799	k_loss: 0.046323	k: 0.215227	lat_loss: 0.605322
# Train -> [ 5120/ 5504 (93%)]	loss: 0.004862	cls_loss: 0.003973	k_loss: 0.046547	k: 0.215748	lat_loss: 0.673050
# Validation (source) -> cls_loss: 0.062447	accuracy: 98.1133%
# Validation (target) -> cls_loss: 0.724725	accuracy: 76.8386%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.018764	cls_loss: 0.017908	k_loss: 0.046550	k: 0.215754	lat_loss: 0.640158
# Train -> [ 2560/ 5504 (47%)]	loss: 0.117286	cls_loss: 0.116350	k_loss: 0.046704	k: 0.216111	lat_loss: 0.719574
# Train -> [ 5120/ 5504 (93%)]	loss: 0.092013	cls_loss: 0.090964	k_loss: 0.046926	k: 0.216624	lat_loss: 0.831619
# Validation (source) -> cls_loss: 0.057634	accuracy: 98.3533%
# Validation (target) -> cls_loss: 0.770086	accuracy: 78.7047%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.070136	cls_loss: 0.069176	k_loss: 0.046977	k: 0.216742	lat_loss: 0.743712
# Train -> [ 2560/ 5504 (47%)]	loss: 0.021143	cls_loss: 0.020271	k_loss: 0.047532	k: 0.218018	lat_loss: 0.653920
# Train -> [ 5120/ 5504 (93%)]	loss: 0.022635	cls_loss: 0.021559	k_loss: 0.047917	k: 0.218899	lat_loss: 0.857469
# Validation (source) -> cls_loss: 0.059768	accuracy: 98.2667%
# Validation (target) -> cls_loss: 0.913039	accuracy: 74.6432%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.042633	cls_loss: 0.041567	k_loss: 0.047892	k: 0.218842	lat_loss: 0.847149
# Train -> [ 2560/ 5504 (47%)]	loss: 0.059151	cls_loss: 0.058247	k_loss: 0.047653	k: 0.218296	lat_loss: 0.685912
# Train -> [ 5120/ 5504 (93%)]	loss: 0.040728	cls_loss: 0.039772	k_loss: 0.048089	k: 0.219292	lat_loss: 0.736934
# Validation (source) -> cls_loss: 0.062623	accuracy: 98.2200%
# Validation (target) -> cls_loss: 0.736802	accuracy: 75.2470%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.044004	cls_loss: 0.043046	k_loss: 0.048152	k: 0.219434	lat_loss: 0.738524
# Train -> [ 2560/ 5504 (47%)]	loss: 0.024790	cls_loss: 0.023898	k_loss: 0.048692	k: 0.220662	lat_loss: 0.671436
# Train -> [ 5120/ 5504 (93%)]	loss: 0.017699	cls_loss: 0.016792	k_loss: 0.048993	k: 0.221343	lat_loss: 0.685662
# Validation (source) -> cls_loss: 0.069057	accuracy: 98.0000%
# Validation (target) -> cls_loss: 0.899504	accuracy: 72.8869%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.016636	cls_loss: 0.015692	k_loss: 0.049036	k: 0.221442	lat_loss: 0.721767
# Train -> [ 2560/ 5504 (47%)]	loss: 0.052565	cls_loss: 0.051667	k_loss: 0.049602	k: 0.222714	lat_loss: 0.675247
# Train -> [ 5120/ 5504 (93%)]	loss: 0.032681	cls_loss: 0.031769	k_loss: 0.049687	k: 0.222905	lat_loss: 0.688679
# Validation (source) -> cls_loss: 0.064646	accuracy: 98.2000%
# Validation (target) -> cls_loss: 0.988640	accuracy: 74.2591%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.125708	cls_loss: 0.124776	k_loss: 0.049703	k: 0.222941	lat_loss: 0.708114
# Train -> [ 2560/ 5504 (47%)]	loss: 0.005404	cls_loss: 0.004531	k_loss: 0.049926	k: 0.223442	lat_loss: 0.650241
# Train -> [ 5120/ 5504 (93%)]	loss: 0.009475	cls_loss: 0.008619	k_loss: 0.050185	k: 0.224020	lat_loss: 0.631635
# Validation (source) -> cls_loss: 0.058007	accuracy: 98.3267%
# Validation (target) -> cls_loss: 0.956608	accuracy: 71.5697%
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.049363	cls_loss: 0.048529	k_loss: 0.050192	k: 0.224036	lat_loss: 0.610103
# Train -> [ 2560/ 5504 (47%)]	loss: 0.008174	cls_loss: 0.007410	k_loss: 0.050269	k: 0.224208	lat_loss: 0.540524
# Train -> [ 5120/ 5504 (93%)]	loss: 0.018512	cls_loss: 0.017641	k_loss: 0.050607	k: 0.224960	lat_loss: 0.645730
# Validation (source) -> cls_loss: 0.049859	accuracy: 98.5333%
# Validation (target) -> cls_loss: 0.664064	accuracy: 80.0220%
# Best model updated and saved at "best_model.pt"
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.073263	cls_loss: 0.072461	k_loss: 0.050618	k: 0.224985	lat_loss: 0.576470
# Train -> [ 2560/ 5504 (47%)]	loss: 0.049845	cls_loss: 0.049020	k_loss: 0.050942	k: 0.225704	lat_loss: 0.599674
# Train -> [ 5120/ 5504 (93%)]	loss: 0.033985	cls_loss: 0.033099	k_loss: 0.051166	k: 0.226200	lat_loss: 0.659806
# Validation (source) -> cls_loss: 0.055346	accuracy: 98.3600%
# Validation (target) -> cls_loss: 0.803870	accuracy: 75.2470%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.025001	cls_loss: 0.024160	k_loss: 0.051197	k: 0.226268	lat_loss: 0.615360
# Train -> [ 2560/ 5504 (47%)]	loss: 0.026149	cls_loss: 0.025309	k_loss: 0.051203	k: 0.226282	lat_loss: 0.613655
# Train -> [ 5120/ 5504 (93%)]	loss: 0.006968	cls_loss: 0.006139	k_loss: 0.051974	k: 0.227978	lat_loss: 0.600363
# Validation (source) -> cls_loss: 0.063334	accuracy: 98.2067%
# Validation (target) -> cls_loss: 0.915239	accuracy: 72.6125%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.026750	cls_loss: 0.025934	k_loss: 0.052035	k: 0.228113	lat_loss: 0.588072
# Train -> [ 2560/ 5504 (47%)]	loss: 0.006155	cls_loss: 0.005231	k_loss: 0.052844	k: 0.229878	lat_loss: 0.694305
# Train -> [ 5120/ 5504 (93%)]	loss: 0.013920	cls_loss: 0.013133	k_loss: 0.053281	k: 0.230827	lat_loss: 0.556102
# Validation (source) -> cls_loss: 0.052350	accuracy: 98.4200%
# Validation (target) -> cls_loss: 0.950298	accuracy: 71.4050%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.089474	cls_loss: 0.088681	k_loss: 0.053315	k: 0.230901	lat_loss: 0.561390
# Train -> [ 2560/ 5504 (47%)]	loss: 0.005203	cls_loss: 0.004316	k_loss: 0.053602	k: 0.231520	lat_loss: 0.655118
# Train -> [ 5120/ 5504 (93%)]	loss: 0.007069	cls_loss: 0.006224	k_loss: 0.054028	k: 0.232439	lat_loss: 0.613112
# Validation (source) -> cls_loss: 0.048670	accuracy: 98.5933%
# Validation (target) -> cls_loss: 0.794516	accuracy: 73.7651%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.031140	cls_loss: 0.030324	k_loss: 0.054061	k: 0.232509	lat_loss: 0.583416
# Train -> [ 2560/ 5504 (47%)]	loss: 0.041538	cls_loss: 0.040581	k_loss: 0.054313	k: 0.233051	lat_loss: 0.723515
# Train -> [ 5120/ 5504 (93%)]	loss: 0.018175	cls_loss: 0.017308	k_loss: 0.054589	k: 0.233643	lat_loss: 0.633182
# Validation (source) -> cls_loss: 0.057259	accuracy: 98.3733%
# Validation (target) -> cls_loss: 0.728781	accuracy: 75.3568%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.070199	cls_loss: 0.069370	k_loss: 0.054545	k: 0.233549	lat_loss: 0.595615
# Train -> [ 2560/ 5504 (47%)]	loss: 0.017816	cls_loss: 0.017000	k_loss: 0.055357	k: 0.235280	lat_loss: 0.581388
# Train -> [ 5120/ 5504 (93%)]	loss: 0.024976	cls_loss: 0.024117	k_loss: 0.055994	k: 0.236630	lat_loss: 0.621848
# Validation (source) -> cls_loss: 0.050877	accuracy: 98.4933%
# Validation (target) -> cls_loss: 0.857036	accuracy: 73.4358%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.012990	cls_loss: 0.012195	k_loss: 0.055997	k: 0.236638	lat_loss: 0.558483
# Train -> [ 2560/ 5504 (47%)]	loss: 0.034358	cls_loss: 0.033470	k_loss: 0.055945	k: 0.236527	lat_loss: 0.651443
# Train -> [ 5120/ 5504 (93%)]	loss: 0.021969	cls_loss: 0.021089	k_loss: 0.056002	k: 0.236647	lat_loss: 0.643727
# Validation (source) -> cls_loss: 0.048072	accuracy: 98.5133%
# Validation (target) -> cls_loss: 0.809392	accuracy: 73.5456%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.015836	cls_loss: 0.015028	k_loss: 0.056030	k: 0.236706	lat_loss: 0.571287
# Train -> [ 2560/ 5504 (47%)]	loss: 0.070293	cls_loss: 0.069487	k_loss: 0.056233	k: 0.237135	lat_loss: 0.569192
# Train -> [ 5120/ 5504 (93%)]	loss: 0.018528	cls_loss: 0.017698	k_loss: 0.056214	k: 0.237096	lat_loss: 0.593067
# Validation (source) -> cls_loss: 0.050829	accuracy: 98.6533%
# Validation (target) -> cls_loss: 0.668897	accuracy: 77.9363%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.011174	cls_loss: 0.010364	k_loss: 0.056221	k: 0.237110	lat_loss: 0.572981
# Train -> [ 2560/ 5504 (47%)]	loss: 0.015266	cls_loss: 0.014422	k_loss: 0.056372	k: 0.237429	lat_loss: 0.606595
# Train -> [ 5120/ 5504 (93%)]	loss: 0.040368	cls_loss: 0.039515	k_loss: 0.056305	k: 0.237288	lat_loss: 0.615886
# Validation (source) -> cls_loss: 0.054846	accuracy: 98.4867%
# Validation (target) -> cls_loss: 0.657523	accuracy: 75.3568%
# Best model updated and saved at "best_model.pt"
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.051038	cls_loss: 0.050245	k_loss: 0.056358	k: 0.237398	lat_loss: 0.555770
# Train -> [ 2560/ 5504 (47%)]	loss: 0.036476	cls_loss: 0.035746	k_loss: 0.056262	k: 0.237196	lat_loss: 0.493351
# Train -> [ 5120/ 5504 (93%)]	loss: 0.019159	cls_loss: 0.018270	k_loss: 0.056188	k: 0.237040	lat_loss: 0.651837
# Validation (source) -> cls_loss: 0.050251	accuracy: 98.6133%
# Validation (target) -> cls_loss: 0.973128	accuracy: 71.4050%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.050746	cls_loss: 0.049917	k_loss: 0.056182	k: 0.237027	lat_loss: 0.591904
# Train -> [ 2560/ 5504 (47%)]	loss: 0.047364	cls_loss: 0.046590	k_loss: 0.055989	k: 0.236620	lat_loss: 0.537414
# Train -> [ 5120/ 5504 (93%)]	loss: 0.023628	cls_loss: 0.022751	k_loss: 0.056150	k: 0.236960	lat_loss: 0.640297
# Validation (source) -> cls_loss: 0.049200	accuracy: 98.5133%
# Validation (target) -> cls_loss: 0.820702	accuracy: 76.1251%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.029151	cls_loss: 0.028259	k_loss: 0.056190	k: 0.237044	lat_loss: 0.655432
# Train -> [ 2560/ 5504 (47%)]	loss: 0.016792	cls_loss: 0.015928	k_loss: 0.056119	k: 0.236894	lat_loss: 0.626913
# Train -> [ 5120/ 5504 (93%)]	loss: 0.009189	cls_loss: 0.008247	k_loss: 0.055985	k: 0.236611	lat_loss: 0.705087
# Validation (source) -> cls_loss: 0.049661	accuracy: 98.5600%
# Validation (target) -> cls_loss: 0.826761	accuracy: 75.3019%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.081188	cls_loss: 0.080294	k_loss: 0.055959	k: 0.236556	lat_loss: 0.657364
# Train -> [ 2560/ 5504 (47%)]	loss: 0.046796	cls_loss: 0.045994	k_loss: 0.056018	k: 0.236680	lat_loss: 0.565220
# Train -> [ 5120/ 5504 (93%)]	loss: 0.008422	cls_loss: 0.007603	k_loss: 0.055812	k: 0.236245	lat_loss: 0.582537
# Validation (source) -> cls_loss: 0.045498	accuracy: 98.7200%
# Validation (target) -> cls_loss: 0.629664	accuracy: 80.5159%
# Best model updated and saved at "best_model.pt"
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.027415	cls_loss: 0.026577	k_loss: 0.055871	k: 0.236370	lat_loss: 0.601790
# Train -> [ 2560/ 5504 (47%)]	loss: 0.007599	cls_loss: 0.006817	k_loss: 0.056148	k: 0.236956	lat_loss: 0.545355
# Train -> [ 5120/ 5504 (93%)]	loss: 0.008823	cls_loss: 0.008091	k_loss: 0.056518	k: 0.237736	lat_loss: 0.494234
# Validation (source) -> cls_loss: 0.052555	accuracy: 98.5533%
# Validation (target) -> cls_loss: 0.618953	accuracy: 79.8024%
# Best model updated and saved at "best_model.pt"
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.003736	cls_loss: 0.002995	k_loss: 0.056540	k: 0.237781	lat_loss: 0.503321
# Train -> [ 2560/ 5504 (47%)]	loss: 0.016800	cls_loss: 0.015939	k_loss: 0.056746	k: 0.238215	lat_loss: 0.622305
# Train -> [ 5120/ 5504 (93%)]	loss: 0.019360	cls_loss: 0.018461	k_loss: 0.056693	k: 0.238102	lat_loss: 0.660603
# Validation (source) -> cls_loss: 0.042824	accuracy: 98.8000%
# Validation (target) -> cls_loss: 0.778912	accuracy: 76.6740%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.016179	cls_loss: 0.015279	k_loss: 0.056722	k: 0.238164	lat_loss: 0.661514
# Train -> [ 2560/ 5504 (47%)]	loss: 0.037781	cls_loss: 0.036968	k_loss: 0.056806	k: 0.238341	lat_loss: 0.574370
# Train -> [ 5120/ 5504 (93%)]	loss: 0.011154	cls_loss: 0.010456	k_loss: 0.057086	k: 0.238927	lat_loss: 0.459303
# Validation (source) -> cls_loss: 0.062104	accuracy: 98.3200%
# Validation (target) -> cls_loss: 0.763128	accuracy: 77.2228%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.117624	cls_loss: 0.116851	k_loss: 0.057132	k: 0.239023	lat_loss: 0.533461
# Train -> [ 2560/ 5504 (47%)]	loss: 0.006815	cls_loss: 0.006018	k_loss: 0.057536	k: 0.239866	lat_loss: 0.557725
# Train -> [ 5120/ 5504 (93%)]	loss: 0.016161	cls_loss: 0.015398	k_loss: 0.057456	k: 0.239699	lat_loss: 0.523801
# Validation (source) -> cls_loss: 0.048520	accuracy: 98.7000%
# Validation (target) -> cls_loss: 0.727833	accuracy: 77.9363%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.009763	cls_loss: 0.008984	k_loss: 0.057439	k: 0.239664	lat_loss: 0.539228
# Train -> [ 2560/ 5504 (47%)]	loss: 0.006813	cls_loss: 0.006005	k_loss: 0.057464	k: 0.239717	lat_loss: 0.567574
# Train -> [ 5120/ 5504 (93%)]	loss: 0.014085	cls_loss: 0.013345	k_loss: 0.057703	k: 0.240214	lat_loss: 0.499973
# Validation (source) -> cls_loss: 0.047312	accuracy: 98.6133%
# Validation (target) -> cls_loss: 0.579321	accuracy: 79.6378%
# Best model updated and saved at "best_model.pt"
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.030016	cls_loss: 0.029286	k_loss: 0.057744	k: 0.240299	lat_loss: 0.489722
# Train -> [ 2560/ 5504 (47%)]	loss: 0.011536	cls_loss: 0.010636	k_loss: 0.058133	k: 0.241108	lat_loss: 0.658686
# Train -> [ 5120/ 5504 (93%)]	loss: 0.065438	cls_loss: 0.064738	k_loss: 0.058717	k: 0.242315	lat_loss: 0.458289
# Validation (source) -> cls_loss: 0.050752	accuracy: 98.6200%
# Validation (target) -> cls_loss: 0.496833	accuracy: 83.6443%
# Best model updated and saved at "best_model.pt"
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.052960	cls_loss: 0.052214	k_loss: 0.058734	k: 0.242352	lat_loss: 0.504424
# Train -> [ 2560/ 5504 (47%)]	loss: 0.035714	cls_loss: 0.034988	k_loss: 0.059052	k: 0.243007	lat_loss: 0.483039
# Train -> [ 5120/ 5504 (93%)]	loss: 0.018747	cls_loss: 0.018041	k_loss: 0.059312	k: 0.243540	lat_loss: 0.462628
# Validation (source) -> cls_loss: 0.043353	accuracy: 98.7200%
# Validation (target) -> cls_loss: 0.737662	accuracy: 78.0461%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.020909	cls_loss: 0.020174	k_loss: 0.059312	k: 0.243541	lat_loss: 0.491820
# Train -> [ 2560/ 5504 (47%)]	loss: 0.004486	cls_loss: 0.003760	k_loss: 0.059460	k: 0.243843	lat_loss: 0.482696
# Train -> [ 5120/ 5504 (93%)]	loss: 0.078730	cls_loss: 0.077961	k_loss: 0.059726	k: 0.244389	lat_loss: 0.523948
# Validation (source) -> cls_loss: 0.043597	accuracy: 98.7667%
# Validation (target) -> cls_loss: 0.625749	accuracy: 81.0648%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.015372	cls_loss: 0.014618	k_loss: 0.059729	k: 0.244394	lat_loss: 0.509736
# Train -> [ 2560/ 5504 (47%)]	loss: 0.009291	cls_loss: 0.008605	k_loss: 0.059933	k: 0.244812	lat_loss: 0.441702
# Train -> [ 5120/ 5504 (93%)]	loss: 0.005905	cls_loss: 0.005173	k_loss: 0.059972	k: 0.244891	lat_loss: 0.487405
# Validation (source) -> cls_loss: 0.045886	accuracy: 98.7200%
# Validation (target) -> cls_loss: 0.780745	accuracy: 77.1131%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.006379	cls_loss: 0.005674	k_loss: 0.060002	k: 0.244953	lat_loss: 0.459952
# Train -> [ 2560/ 5504 (47%)]	loss: 0.009860	cls_loss: 0.009142	k_loss: 0.060623	k: 0.246218	lat_loss: 0.472378
# Train -> [ 5120/ 5504 (93%)]	loss: 0.013399	cls_loss: 0.012734	k_loss: 0.060821	k: 0.246620	lat_loss: 0.418442
# Validation (source) -> cls_loss: 0.048022	accuracy: 98.5667%
# Validation (target) -> cls_loss: 0.696688	accuracy: 78.7047%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.017055	cls_loss: 0.016400	k_loss: 0.060825	k: 0.246627	lat_loss: 0.408766
# Train -> [ 2560/ 5504 (47%)]	loss: 0.013435	cls_loss: 0.012764	k_loss: 0.061103	k: 0.247191	lat_loss: 0.424248
# Train -> [ 5120/ 5504 (93%)]	loss: 0.005447	cls_loss: 0.004727	k_loss: 0.061518	k: 0.248029	lat_loss: 0.472113
# Validation (source) -> cls_loss: 0.045178	accuracy: 98.7800%
# Validation (target) -> cls_loss: 0.558233	accuracy: 83.1504%
# Test (source) -> cls_loss: 0.037751	accuracy: 98.9600%
# Test (target) -> cls_loss: 0.650079	accuracy: 78.8739%
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyModel                                  [128, 10]                 --
# ├─FeatureExtractor: 1-1                  [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                   --                        --
# │    │    └─Sequential: 3-1              [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2              [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3              [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                  [128, 576]                667,010
# ├─ClassRegressor: 1-3                    [128, 10]                 --
# │    └─ModuleList: 2-2                   --                        --
# │    │    └─Sequential: 3-4              [128, 128]                73,856
# │    │    └─Sequential: 3-5              [128, 64]                 8,256
# │    └─Linear: 2-3                       [128, 10]                 650
# ==========================================================================================
# Total params: 773,068
# Trainable params: 773,068
# Non-trainable params: 0
# Total mult-adds (M): 259.07
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 22.69
# Params size (MB): 0.42
# Estimated Total Size (MB): 23.51
# ==========================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.306142	cls_loss: 2.305428	k_loss: 0.499678	k: 0.706879	lat_loss: 0.007050
# Train -> [ 2560/ 5504 (47%)]	loss: 0.975707	cls_loss: 0.974993	k_loss: 0.495628	k: 0.704008	lat_loss: 0.009947
# Train -> [ 5120/ 5504 (93%)]	loss: 0.291672	cls_loss: 0.290946	k_loss: 0.495105	k: 0.703637	lat_loss: 0.022023
# Validation (source) -> cls_loss: 0.389889	accuracy: 88.1267%
# Validation (target) -> cls_loss: 0.961803	accuracy: 69.3194%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.419749	cls_loss: 0.419026	k_loss: 0.495082	k: 0.703621	lat_loss: 0.019904
# Train -> [ 2560/ 5504 (47%)]	loss: 0.280581	cls_loss: 0.279860	k_loss: 0.494390	k: 0.703129	lat_loss: 0.018424
# Train -> [ 5120/ 5504 (93%)]	loss: 0.181365	cls_loss: 0.180642	k_loss: 0.494814	k: 0.703430	lat_loss: 0.019668
# Validation (source) -> cls_loss: 0.200277	accuracy: 93.9333%
# Validation (target) -> cls_loss: 0.995872	accuracy: 69.7585%
# Epoch 3 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.125786	cls_loss: 0.125062	k_loss: 0.494951	k: 0.703527	lat_loss: 0.020341
# Train -> [ 2560/ 5504 (47%)]	loss: 0.198681	cls_loss: 0.197957	k_loss: 0.496012	k: 0.704281	lat_loss: 0.019968
# Train -> [ 5120/ 5504 (93%)]	loss: 0.198334	cls_loss: 0.197607	k_loss: 0.497339	k: 0.705223	lat_loss: 0.021848
# Validation (source) -> cls_loss: 0.166886	accuracy: 94.6533%
# Validation (target) -> cls_loss: 0.947698	accuracy: 67.1789%
# Best model updated and saved at "best_model.pt"
# Epoch 4 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.212187	cls_loss: 0.211458	k_loss: 0.497456	k: 0.705306	lat_loss: 0.022945
# Train -> [ 2560/ 5504 (47%)]	loss: 0.122080	cls_loss: 0.121351	k_loss: 0.498992	k: 0.706394	lat_loss: 0.021770
# Train -> [ 5120/ 5504 (93%)]	loss: 0.082508	cls_loss: 0.081780	k_loss: 0.499743	k: 0.706925	lat_loss: 0.021264
# Validation (source) -> cls_loss: 0.121511	accuracy: 96.1000%
# Validation (target) -> cls_loss: 1.075105	accuracy: 66.0263%
# Epoch 5 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.127288	cls_loss: 0.126559	k_loss: 0.499890	k: 0.707029	lat_loss: 0.021767
# Train -> [ 2560/ 5504 (47%)]	loss: 0.148867	cls_loss: 0.148139	k_loss: 0.501021	k: 0.707828	lat_loss: 0.019502
# Train -> [ 5120/ 5504 (93%)]	loss: 0.018892	cls_loss: 0.018161	k_loss: 0.502023	k: 0.708536	lat_loss: 0.022626
# Validation (source) -> cls_loss: 0.102567	accuracy: 96.7733%
# Validation (target) -> cls_loss: 1.227198	accuracy: 66.6850%
# Epoch 6 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.074403	cls_loss: 0.073671	k_loss: 0.502221	k: 0.708676	lat_loss: 0.023754
# Train -> [ 2560/ 5504 (47%)]	loss: 0.103750	cls_loss: 0.103018	k_loss: 0.503633	k: 0.709671	lat_loss: 0.022776
# Train -> [ 5120/ 5504 (93%)]	loss: 0.081466	cls_loss: 0.080733	k_loss: 0.503846	k: 0.709821	lat_loss: 0.022818
# Validation (source) -> cls_loss: 0.089576	accuracy: 97.2333%
# Validation (target) -> cls_loss: 1.261876	accuracy: 67.5631%
# Epoch 7 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.049932	cls_loss: 0.049199	k_loss: 0.504093	k: 0.709995	lat_loss: 0.022130
# Train -> [ 2560/ 5504 (47%)]	loss: 0.086751	cls_loss: 0.086019	k_loss: 0.505101	k: 0.710705	lat_loss: 0.020876
# Train -> [ 5120/ 5504 (93%)]	loss: 0.103452	cls_loss: 0.102720	k_loss: 0.504548	k: 0.710316	lat_loss: 0.020901
# Validation (source) -> cls_loss: 0.079819	accuracy: 97.6067%
# Validation (target) -> cls_loss: 0.834490	accuracy: 75.3568%
# Best model updated and saved at "best_model.pt"
# Epoch 8 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.057363	cls_loss: 0.056632	k_loss: 0.504249	k: 0.710105	lat_loss: 0.020142
# Train -> [ 2560/ 5504 (47%)]	loss: 0.035675	cls_loss: 0.034944	k_loss: 0.503808	k: 0.709794	lat_loss: 0.021155
# Train -> [ 5120/ 5504 (93%)]	loss: 0.102947	cls_loss: 0.102214	k_loss: 0.504542	k: 0.710311	lat_loss: 0.023279
# Validation (source) -> cls_loss: 0.076954	accuracy: 97.5533%
# Validation (target) -> cls_loss: 0.739486	accuracy: 77.5521%
# Best model updated and saved at "best_model.pt"
# Epoch 9 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.055892	cls_loss: 0.055157	k_loss: 0.504580	k: 0.710338	lat_loss: 0.024815
# Train -> [ 2560/ 5504 (47%)]	loss: 0.097643	cls_loss: 0.096907	k_loss: 0.506207	k: 0.711482	lat_loss: 0.024238
# Train -> [ 5120/ 5504 (93%)]	loss: 0.086091	cls_loss: 0.085354	k_loss: 0.508029	k: 0.712762	lat_loss: 0.024308
# Validation (source) -> cls_loss: 0.076754	accuracy: 97.7200%
# Validation (target) -> cls_loss: 0.862197	accuracy: 74.2042%
# Epoch 10 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.035949	cls_loss: 0.035215	k_loss: 0.508005	k: 0.712745	lat_loss: 0.021295
# Train -> [ 2560/ 5504 (47%)]	loss: 0.018170	cls_loss: 0.017435	k_loss: 0.508659	k: 0.713203	lat_loss: 0.022418
# Train -> [ 5120/ 5504 (93%)]	loss: 0.035524	cls_loss: 0.034786	k_loss: 0.511079	k: 0.714898	lat_loss: 0.022301
# Validation (source) -> cls_loss: 0.064930	accuracy: 97.9400%
# Validation (target) -> cls_loss: 0.847968	accuracy: 76.2349%
# Epoch 11 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.045575	cls_loss: 0.044840	k_loss: 0.511356	k: 0.715092	lat_loss: 0.020805
# Train -> [ 2560/ 5504 (47%)]	loss: 0.060252	cls_loss: 0.059511	k_loss: 0.512642	k: 0.715990	lat_loss: 0.025093
# Train -> [ 5120/ 5504 (93%)]	loss: 0.029100	cls_loss: 0.028361	k_loss: 0.513003	k: 0.716242	lat_loss: 0.022693
# Validation (source) -> cls_loss: 0.066841	accuracy: 97.8933%
# Validation (target) -> cls_loss: 1.137631	accuracy: 69.5390%
# Epoch 12 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.030601	cls_loss: 0.029863	k_loss: 0.512919	k: 0.716184	lat_loss: 0.021810
# Train -> [ 2560/ 5504 (47%)]	loss: 0.047870	cls_loss: 0.047132	k_loss: 0.512536	k: 0.715916	lat_loss: 0.022505
# Train -> [ 5120/ 5504 (93%)]	loss: 0.045366	cls_loss: 0.044626	k_loss: 0.512890	k: 0.716163	lat_loss: 0.023825
# Validation (source) -> cls_loss: 0.062801	accuracy: 98.0933%
# Validation (target) -> cls_loss: 1.110184	accuracy: 70.8562%
# Epoch 13 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.040153	cls_loss: 0.039412	k_loss: 0.512976	k: 0.716223	lat_loss: 0.024354
# Train -> [ 2560/ 5504 (47%)]	loss: 0.102449	cls_loss: 0.101708	k_loss: 0.512215	k: 0.715692	lat_loss: 0.024794
# Train -> [ 5120/ 5504 (93%)]	loss: 0.053835	cls_loss: 0.053094	k_loss: 0.511394	k: 0.715118	lat_loss: 0.025335
# Validation (source) -> cls_loss: 0.072841	accuracy: 97.7067%
# Validation (target) -> cls_loss: 1.398083	accuracy: 64.8738%
# Epoch 14 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.073129	cls_loss: 0.072389	k_loss: 0.511401	k: 0.715123	lat_loss: 0.024531
# Train -> [ 2560/ 5504 (47%)]	loss: 0.028428	cls_loss: 0.027690	k_loss: 0.511797	k: 0.715400	lat_loss: 0.022580
# Train -> [ 5120/ 5504 (93%)]	loss: 0.022493	cls_loss: 0.021754	k_loss: 0.513288	k: 0.716442	lat_loss: 0.023488
# Validation (source) -> cls_loss: 0.065440	accuracy: 97.9867%
# Validation (target) -> cls_loss: 0.940120	accuracy: 72.1186%
# Epoch 15 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.045260	cls_loss: 0.044520	k_loss: 0.513351	k: 0.716485	lat_loss: 0.023908
# Train -> [ 2560/ 5504 (47%)]	loss: 0.032839	cls_loss: 0.032098	k_loss: 0.513775	k: 0.716781	lat_loss: 0.023610
# Train -> [ 5120/ 5504 (93%)]	loss: 0.030528	cls_loss: 0.029788	k_loss: 0.515427	k: 0.717932	lat_loss: 0.022441
# Validation (source) -> cls_loss: 0.065700	accuracy: 97.9800%
# Validation (target) -> cls_loss: 1.000883	accuracy: 71.7892%
# Epoch 16 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.012515	cls_loss: 0.011775	k_loss: 0.515488	k: 0.717975	lat_loss: 0.022191
# Train -> [ 2560/ 5504 (47%)]	loss: 0.050266	cls_loss: 0.049525	k_loss: 0.516882	k: 0.718945	lat_loss: 0.021934
# Train -> [ 5120/ 5504 (93%)]	loss: 0.029164	cls_loss: 0.028424	k_loss: 0.517736	k: 0.719539	lat_loss: 0.021320
# Validation (source) -> cls_loss: 0.054598	accuracy: 98.4600%
# Validation (target) -> cls_loss: 0.829235	accuracy: 76.8935%
# Epoch 17 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.021513	cls_loss: 0.020770	k_loss: 0.517665	k: 0.719490	lat_loss: 0.023325
# Train -> [ 2560/ 5504 (47%)]	loss: 0.031462	cls_loss: 0.030721	k_loss: 0.519880	k: 0.721027	lat_loss: 0.020396
# Train -> [ 5120/ 5504 (93%)]	loss: 0.026629	cls_loss: 0.025885	k_loss: 0.520746	k: 0.721627	lat_loss: 0.021983
# Validation (source) -> cls_loss: 0.068088	accuracy: 97.9600%
# Validation (target) -> cls_loss: 0.625871	accuracy: 76.5093%
# Best model updated and saved at "best_model.pt"
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.030491	cls_loss: 0.029747	k_loss: 0.520829	k: 0.721685	lat_loss: 0.021765
# Train -> [ 2560/ 5504 (47%)]	loss: 0.088742	cls_loss: 0.088000	k_loss: 0.520193	k: 0.721244	lat_loss: 0.020743
# Train -> [ 5120/ 5504 (93%)]	loss: 0.074035	cls_loss: 0.073290	k_loss: 0.520752	k: 0.721632	lat_loss: 0.023958
# Validation (source) -> cls_loss: 0.052469	accuracy: 98.4133%
# Validation (target) -> cls_loss: 0.820289	accuracy: 78.5401%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.050667	cls_loss: 0.049923	k_loss: 0.520703	k: 0.721597	lat_loss: 0.021784
# Train -> [ 2560/ 5504 (47%)]	loss: 0.100122	cls_loss: 0.099381	k_loss: 0.520814	k: 0.721675	lat_loss: 0.019329
# Train -> [ 5120/ 5504 (93%)]	loss: 0.024056	cls_loss: 0.023311	k_loss: 0.522097	k: 0.722563	lat_loss: 0.022166
# Validation (source) -> cls_loss: 0.050900	accuracy: 98.4867%
# Validation (target) -> cls_loss: 0.994174	accuracy: 74.6981%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.074902	cls_loss: 0.074158	k_loss: 0.522249	k: 0.722668	lat_loss: 0.020973
# Train -> [ 2560/ 5504 (47%)]	loss: 0.053566	cls_loss: 0.052824	k_loss: 0.522541	k: 0.722870	lat_loss: 0.019797
# Train -> [ 5120/ 5504 (93%)]	loss: 0.056679	cls_loss: 0.055935	k_loss: 0.522301	k: 0.722704	lat_loss: 0.021440
# Validation (source) -> cls_loss: 0.063516	accuracy: 98.1200%
# Validation (target) -> cls_loss: 1.036065	accuracy: 71.3502%
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.038528	cls_loss: 0.037784	k_loss: 0.522328	k: 0.722723	lat_loss: 0.021632
# Train -> [ 2560/ 5504 (47%)]	loss: 0.056610	cls_loss: 0.055865	k_loss: 0.522523	k: 0.722858	lat_loss: 0.022197
# Train -> [ 5120/ 5504 (93%)]	loss: 0.017933	cls_loss: 0.017189	k_loss: 0.524474	k: 0.724206	lat_loss: 0.020536
# Validation (source) -> cls_loss: 0.052497	accuracy: 98.3933%
# Validation (target) -> cls_loss: 0.858811	accuracy: 76.0703%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.021433	cls_loss: 0.020689	k_loss: 0.524650	k: 0.724327	lat_loss: 0.018989
# Train -> [ 2560/ 5504 (47%)]	loss: 0.039030	cls_loss: 0.038283	k_loss: 0.523776	k: 0.723723	lat_loss: 0.022499
# Train -> [ 5120/ 5504 (93%)]	loss: 0.027493	cls_loss: 0.026749	k_loss: 0.523506	k: 0.723537	lat_loss: 0.021133
# Validation (source) -> cls_loss: 0.060147	accuracy: 98.1533%
# Validation (target) -> cls_loss: 0.595093	accuracy: 81.1745%
# Best model updated and saved at "best_model.pt"
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.033898	cls_loss: 0.033153	k_loss: 0.523351	k: 0.723430	lat_loss: 0.021620
# Train -> [ 2560/ 5504 (47%)]	loss: 0.030873	cls_loss: 0.030128	k_loss: 0.523668	k: 0.723649	lat_loss: 0.021053
# Train -> [ 5120/ 5504 (93%)]	loss: 0.038809	cls_loss: 0.038063	k_loss: 0.525143	k: 0.724668	lat_loss: 0.021826
# Validation (source) -> cls_loss: 0.047445	accuracy: 98.6267%
# Validation (target) -> cls_loss: 0.804395	accuracy: 77.1679%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.031292	cls_loss: 0.030545	k_loss: 0.525407	k: 0.724850	lat_loss: 0.022722
# Train -> [ 2560/ 5504 (47%)]	loss: 0.040984	cls_loss: 0.040237	k_loss: 0.526546	k: 0.725635	lat_loss: 0.020984
# Train -> [ 5120/ 5504 (93%)]	loss: 0.002960	cls_loss: 0.002213	k_loss: 0.526857	k: 0.725849	lat_loss: 0.021245
# Validation (source) -> cls_loss: 0.046813	accuracy: 98.5600%
# Validation (target) -> cls_loss: 0.934431	accuracy: 75.3019%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.042569	cls_loss: 0.041821	k_loss: 0.526658	k: 0.725712	lat_loss: 0.021891
# Train -> [ 2560/ 5504 (47%)]	loss: 0.012519	cls_loss: 0.011771	k_loss: 0.526479	k: 0.725588	lat_loss: 0.022843
# Train -> [ 5120/ 5504 (93%)]	loss: 0.022866	cls_loss: 0.022118	k_loss: 0.527552	k: 0.726328	lat_loss: 0.020730
# Validation (source) -> cls_loss: 0.047895	accuracy: 98.6000%
# Validation (target) -> cls_loss: 0.535910	accuracy: 83.2053%
# Best model updated and saved at "best_model.pt"
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.022792	cls_loss: 0.022045	k_loss: 0.527571	k: 0.726341	lat_loss: 0.020998
# Train -> [ 2560/ 5504 (47%)]	loss: 0.008263	cls_loss: 0.007517	k_loss: 0.528341	k: 0.726871	lat_loss: 0.019043
# Train -> [ 5120/ 5504 (93%)]	loss: 0.039505	cls_loss: 0.038756	k_loss: 0.527958	k: 0.726607	lat_loss: 0.022116
# Validation (source) -> cls_loss: 0.046785	accuracy: 98.6333%
# Validation (target) -> cls_loss: 0.775166	accuracy: 80.1317%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.001962	cls_loss: 0.001213	k_loss: 0.528124	k: 0.726721	lat_loss: 0.021892
# Train -> [ 2560/ 5504 (47%)]	loss: 0.026767	cls_loss: 0.026015	k_loss: 0.529904	k: 0.727945	lat_loss: 0.023774
# Train -> [ 5120/ 5504 (93%)]	loss: 0.044883	cls_loss: 0.044132	k_loss: 0.529833	k: 0.727896	lat_loss: 0.022800
# Validation (source) -> cls_loss: 0.048405	accuracy: 98.5933%
# Validation (target) -> cls_loss: 0.677886	accuracy: 79.9122%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.013419	cls_loss: 0.012667	k_loss: 0.529727	k: 0.727823	lat_loss: 0.023335
# Train -> [ 2560/ 5504 (47%)]	loss: 0.026937	cls_loss: 0.026187	k_loss: 0.529329	k: 0.727550	lat_loss: 0.022178
# Train -> [ 5120/ 5504 (93%)]	loss: 0.046443	cls_loss: 0.045692	k_loss: 0.529457	k: 0.727638	lat_loss: 0.023775
# Validation (source) -> cls_loss: 0.044991	accuracy: 98.6267%
# Validation (target) -> cls_loss: 0.767397	accuracy: 79.0889%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.024860	cls_loss: 0.024111	k_loss: 0.529438	k: 0.727625	lat_loss: 0.021571
# Train -> [ 2560/ 5504 (47%)]	loss: 0.037483	cls_loss: 0.036736	k_loss: 0.529159	k: 0.727433	lat_loss: 0.019793
# Train -> [ 5120/ 5504 (93%)]	loss: 0.007688	cls_loss: 0.006939	k_loss: 0.529146	k: 0.727424	lat_loss: 0.022041
# Validation (source) -> cls_loss: 0.054301	accuracy: 98.3000%
# Validation (target) -> cls_loss: 0.615241	accuracy: 81.8332%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.035678	cls_loss: 0.034928	k_loss: 0.529219	k: 0.727474	lat_loss: 0.021852
# Train -> [ 2560/ 5504 (47%)]	loss: 0.031255	cls_loss: 0.030502	k_loss: 0.529326	k: 0.727548	lat_loss: 0.025245
# Train -> [ 5120/ 5504 (93%)]	loss: 0.091399	cls_loss: 0.090649	k_loss: 0.528757	k: 0.727157	lat_loss: 0.023115
# Validation (source) -> cls_loss: 0.046309	accuracy: 98.6600%
# Validation (target) -> cls_loss: 0.503151	accuracy: 84.1383%
# Best model updated and saved at "best_model.pt"
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.087694	cls_loss: 0.086944	k_loss: 0.528762	k: 0.727160	lat_loss: 0.023496
# Train -> [ 2560/ 5504 (47%)]	loss: 0.046107	cls_loss: 0.045353	k_loss: 0.530560	k: 0.728395	lat_loss: 0.025142
# Train -> [ 5120/ 5504 (93%)]	loss: 0.006923	cls_loss: 0.006171	k_loss: 0.531694	k: 0.729174	lat_loss: 0.022865
# Validation (source) -> cls_loss: 0.045547	accuracy: 98.6000%
# Validation (target) -> cls_loss: 0.974638	accuracy: 72.9418%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.012879	cls_loss: 0.012127	k_loss: 0.531962	k: 0.729357	lat_loss: 0.022751
# Train -> [ 2560/ 5504 (47%)]	loss: 0.004857	cls_loss: 0.004104	k_loss: 0.533222	k: 0.730221	lat_loss: 0.022520
# Train -> [ 5120/ 5504 (93%)]	loss: 0.012379	cls_loss: 0.011624	k_loss: 0.534005	k: 0.730757	lat_loss: 0.023625
# Validation (source) -> cls_loss: 0.052217	accuracy: 98.4933%
# Validation (target) -> cls_loss: 0.833194	accuracy: 76.5093%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.006747	cls_loss: 0.005994	k_loss: 0.534034	k: 0.730776	lat_loss: 0.022531
# Train -> [ 2560/ 5504 (47%)]	loss: 0.012158	cls_loss: 0.011404	k_loss: 0.533900	k: 0.730685	lat_loss: 0.023689
# Train -> [ 5120/ 5504 (93%)]	loss: 0.008776	cls_loss: 0.008023	k_loss: 0.534807	k: 0.731305	lat_loss: 0.021448
# Validation (source) -> cls_loss: 0.042265	accuracy: 98.7467%
# Validation (target) -> cls_loss: 0.958945	accuracy: 71.6246%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.026989	cls_loss: 0.026235	k_loss: 0.534946	k: 0.731400	lat_loss: 0.022251
# Train -> [ 2560/ 5504 (47%)]	loss: 0.030974	cls_loss: 0.030218	k_loss: 0.535645	k: 0.731877	lat_loss: 0.023836
# Train -> [ 5120/ 5504 (93%)]	loss: 0.004395	cls_loss: 0.003641	k_loss: 0.534994	k: 0.731433	lat_loss: 0.022460
# Validation (source) -> cls_loss: 0.040448	accuracy: 98.7933%
# Validation (target) -> cls_loss: 0.764749	accuracy: 74.7530%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.003045	cls_loss: 0.002292	k_loss: 0.534898	k: 0.731367	lat_loss: 0.022176
# Train -> [ 2560/ 5504 (47%)]	loss: 0.002899	cls_loss: 0.002143	k_loss: 0.534556	k: 0.731133	lat_loss: 0.024932
# Train -> [ 5120/ 5504 (93%)]	loss: 0.002350	cls_loss: 0.001596	k_loss: 0.534354	k: 0.730995	lat_loss: 0.023485
# Validation (source) -> cls_loss: 0.048011	accuracy: 98.7733%
# Validation (target) -> cls_loss: 0.776434	accuracy: 80.4610%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.003863	cls_loss: 0.003108	k_loss: 0.534336	k: 0.730983	lat_loss: 0.024089
# Train -> [ 2560/ 5504 (47%)]	loss: 0.013120	cls_loss: 0.012366	k_loss: 0.534206	k: 0.730894	lat_loss: 0.023299
# Train -> [ 5120/ 5504 (93%)]	loss: 0.024926	cls_loss: 0.024172	k_loss: 0.534653	k: 0.731200	lat_loss: 0.023362
# Validation (source) -> cls_loss: 0.045155	accuracy: 98.6933%
# Validation (target) -> cls_loss: 0.966620	accuracy: 76.1251%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.015073	cls_loss: 0.014318	k_loss: 0.534657	k: 0.731202	lat_loss: 0.023863
# Train -> [ 2560/ 5504 (47%)]	loss: 0.058522	cls_loss: 0.057767	k_loss: 0.534486	k: 0.731085	lat_loss: 0.024002
# Train -> [ 5120/ 5504 (93%)]	loss: 0.009492	cls_loss: 0.008739	k_loss: 0.534576	k: 0.731147	lat_loss: 0.021987
# Validation (source) -> cls_loss: 0.053163	accuracy: 98.5067%
# Validation (target) -> cls_loss: 0.704177	accuracy: 81.9978%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.017150	cls_loss: 0.016397	k_loss: 0.534529	k: 0.731115	lat_loss: 0.022795
# Train -> [ 2560/ 5504 (47%)]	loss: 0.064565	cls_loss: 0.063810	k_loss: 0.533319	k: 0.730287	lat_loss: 0.024625
# Train -> [ 5120/ 5504 (93%)]	loss: 0.072403	cls_loss: 0.071651	k_loss: 0.532311	k: 0.729596	lat_loss: 0.021767
# Validation (source) -> cls_loss: 0.047107	accuracy: 98.6400%
# Validation (target) -> cls_loss: 0.576945	accuracy: 81.4490%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.029766	cls_loss: 0.029015	k_loss: 0.532398	k: 0.729656	lat_loss: 0.021717
# Train -> [ 2560/ 5504 (47%)]	loss: 0.011909	cls_loss: 0.011160	k_loss: 0.532483	k: 0.729714	lat_loss: 0.018914
# Train -> [ 5120/ 5504 (93%)]	loss: 0.002720	cls_loss: 0.001968	k_loss: 0.532775	k: 0.729915	lat_loss: 0.022022
# Validation (source) -> cls_loss: 0.039001	accuracy: 98.8667%
# Validation (target) -> cls_loss: 0.891476	accuracy: 75.8507%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.019300	cls_loss: 0.018548	k_loss: 0.532903	k: 0.730002	lat_loss: 0.021350
# Train -> [ 2560/ 5504 (47%)]	loss: 0.044973	cls_loss: 0.044220	k_loss: 0.534168	k: 0.730868	lat_loss: 0.022005
# Train -> [ 5120/ 5504 (93%)]	loss: 0.002701	cls_loss: 0.001946	k_loss: 0.536784	k: 0.732656	lat_loss: 0.022472
# Validation (source) -> cls_loss: 0.047675	accuracy: 98.6800%
# Validation (target) -> cls_loss: 1.010152	accuracy: 77.3326%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.002613	cls_loss: 0.001855	k_loss: 0.537006	k: 0.732807	lat_loss: 0.024475
# Train -> [ 2560/ 5504 (47%)]	loss: 0.038368	cls_loss: 0.037611	k_loss: 0.537946	k: 0.733448	lat_loss: 0.024286
# Train -> [ 5120/ 5504 (93%)]	loss: 0.019282	cls_loss: 0.018527	k_loss: 0.537571	k: 0.733192	lat_loss: 0.021656
# Validation (source) -> cls_loss: 0.042579	accuracy: 98.7267%
# Validation (target) -> cls_loss: 0.780820	accuracy: 79.4731%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.027197	cls_loss: 0.026442	k_loss: 0.537520	k: 0.733157	lat_loss: 0.020968
# Train -> [ 2560/ 5504 (47%)]	loss: 0.008795	cls_loss: 0.008043	k_loss: 0.537319	k: 0.733020	lat_loss: 0.019560
# ...
# Validation (source) -> cls_loss: 0.093169	accuracy: 97.4067%
# Validation (target) -> cls_loss: 1.092710	accuracy: 68.0022%
# Epoch 18 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.103909	cls_loss: 0.102463	k_loss: 0.005281	k: 0.072670	lat_loss: 1.373549
# Train -> [ 2560/ 5504 (47%)]	loss: 0.049557	cls_loss: 0.048176	k_loss: 0.005311	k: 0.072874	lat_loss: 1.308504
# Train -> [ 5120/ 5504 (93%)]	loss: 0.054448	cls_loss: 0.052975	k_loss: 0.005301	k: 0.072806	lat_loss: 1.399971
# Validation (source) -> cls_loss: 0.093362	accuracy: 97.3933%
# Validation (target) -> cls_loss: 1.137740	accuracy: 68.6608%
# Epoch 19 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.126127	cls_loss: 0.124671	k_loss: 0.005301	k: 0.072806	lat_loss: 1.383383
# Train -> [ 2560/ 5504 (47%)]	loss: 0.087584	cls_loss: 0.086206	k_loss: 0.005324	k: 0.072966	lat_loss: 1.305316
# Train -> [ 5120/ 5504 (93%)]	loss: 0.122739	cls_loss: 0.121571	k_loss: 0.005381	k: 0.073357	lat_loss: 1.094734
# Validation (source) -> cls_loss: 0.095885	accuracy: 97.3533%
# Validation (target) -> cls_loss: 0.863682	accuracy: 68.1668%
# Epoch 20 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.066747	cls_loss: 0.065574	k_loss: 0.005383	k: 0.073372	lat_loss: 1.099286
# Train -> [ 2560/ 5504 (47%)]	loss: 0.134804	cls_loss: 0.133360	k_loss: 0.005405	k: 0.073521	lat_loss: 1.369756
# Train -> [ 5120/ 5504 (93%)]	loss: 0.037156	cls_loss: 0.035848	k_loss: 0.005437	k: 0.073733	lat_loss: 1.234128
# Validation (source) -> cls_loss: 0.081950	accuracy: 97.6400%
# Validation (target) -> cls_loss: 0.705702	accuracy: 77.2777%
# Best model updated and saved at "best_model.pt"
# Epoch 21 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.025915	cls_loss: 0.024436	k_loss: 0.005439	k: 0.073751	lat_loss: 1.404779
# Train -> [ 2560/ 5504 (47%)]	loss: 0.054289	cls_loss: 0.052860	k_loss: 0.005445	k: 0.073789	lat_loss: 1.354914
# Train -> [ 5120/ 5504 (93%)]	loss: 0.113394	cls_loss: 0.111915	k_loss: 0.005509	k: 0.074220	lat_loss: 1.404835
# Validation (source) -> cls_loss: 0.081759	accuracy: 97.7400%
# Validation (target) -> cls_loss: 0.969202	accuracy: 68.2217%
# Epoch 22 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.058822	cls_loss: 0.057560	k_loss: 0.005515	k: 0.074263	lat_loss: 1.187850
# Train -> [ 2560/ 5504 (47%)]	loss: 0.068908	cls_loss: 0.067470	k_loss: 0.005559	k: 0.074556	lat_loss: 1.364154
# Train -> [ 5120/ 5504 (93%)]	loss: 0.138383	cls_loss: 0.137036	k_loss: 0.005605	k: 0.074869	lat_loss: 1.272115
# Validation (source) -> cls_loss: 0.073468	accuracy: 97.9533%
# Validation (target) -> cls_loss: 1.075721	accuracy: 70.9111%
# Epoch 23 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.040907	cls_loss: 0.039533	k_loss: 0.005610	k: 0.074897	lat_loss: 1.298745
# Train -> [ 2560/ 5504 (47%)]	loss: 0.066552	cls_loss: 0.065317	k_loss: 0.005664	k: 0.075257	lat_loss: 1.160183
# Train -> [ 5120/ 5504 (93%)]	loss: 0.073973	cls_loss: 0.072711	k_loss: 0.005727	k: 0.075678	lat_loss: 1.185790
# Validation (source) -> cls_loss: 0.086692	accuracy: 97.7000%
# Validation (target) -> cls_loss: 0.812986	accuracy: 76.5642%
# Epoch 24 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.063060	cls_loss: 0.061780	k_loss: 0.005732	k: 0.075708	lat_loss: 1.204200
# Train -> [ 2560/ 5504 (47%)]	loss: 0.039425	cls_loss: 0.037991	k_loss: 0.005789	k: 0.076085	lat_loss: 1.358434
# Train -> [ 5120/ 5504 (93%)]	loss: 0.022054	cls_loss: 0.020950	k_loss: 0.005844	k: 0.076446	lat_loss: 1.027329
# Validation (source) -> cls_loss: 0.087819	accuracy: 97.6200%
# Validation (target) -> cls_loss: 0.831779	accuracy: 73.2162%
# Epoch 25 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.077901	cls_loss: 0.076942	k_loss: 0.005848	k: 0.076474	lat_loss: 0.882398
# Train -> [ 2560/ 5504 (47%)]	loss: 0.024871	cls_loss: 0.023513	k_loss: 0.005921	k: 0.076948	lat_loss: 1.280896
# Train -> [ 5120/ 5504 (93%)]	loss: 0.065282	cls_loss: 0.063970	k_loss: 0.006024	k: 0.077616	lat_loss: 1.233837
# Validation (source) -> cls_loss: 0.077651	accuracy: 97.9067%
# Validation (target) -> cls_loss: 0.970477	accuracy: 73.2162%
# Epoch 26 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.060473	cls_loss: 0.059108	k_loss: 0.006029	k: 0.077645	lat_loss: 1.288011
# Train -> [ 2560/ 5504 (47%)]	loss: 0.077100	cls_loss: 0.076015	k_loss: 0.006070	k: 0.077911	lat_loss: 1.007083
# Train -> [ 5120/ 5504 (93%)]	loss: 0.065769	cls_loss: 0.064391	k_loss: 0.006105	k: 0.078138	lat_loss: 1.299634
# Validation (source) -> cls_loss: 0.075516	accuracy: 98.0267%
# Validation (target) -> cls_loss: 1.156964	accuracy: 69.8683%
# Epoch 27 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.032296	cls_loss: 0.030874	k_loss: 0.006108	k: 0.078151	lat_loss: 1.344082
# Train -> [ 2560/ 5504 (47%)]	loss: 0.100051	cls_loss: 0.098702	k_loss: 0.006175	k: 0.078578	lat_loss: 1.270415
# Train -> [ 5120/ 5504 (93%)]	loss: 0.025693	cls_loss: 0.024153	k_loss: 0.006229	k: 0.078925	lat_loss: 1.460804
# Validation (source) -> cls_loss: 0.076787	accuracy: 97.8800%
# Validation (target) -> cls_loss: 0.956768	accuracy: 72.3930%
# Epoch 28 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.022480	cls_loss: 0.020904	k_loss: 0.006240	k: 0.078996	lat_loss: 1.496909
# Train -> [ 2560/ 5504 (47%)]	loss: 0.022656	cls_loss: 0.021255	k_loss: 0.006296	k: 0.079347	lat_loss: 1.322174
# Train -> [ 5120/ 5504 (93%)]	loss: 0.028665	cls_loss: 0.027088	k_loss: 0.006395	k: 0.079970	lat_loss: 1.496895
# Validation (source) -> cls_loss: 0.073850	accuracy: 97.9667%
# Validation (target) -> cls_loss: 1.178997	accuracy: 69.4292%
# Epoch 29 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.058515	cls_loss: 0.057032	k_loss: 0.006404	k: 0.080026	lat_loss: 1.402848
# Train -> [ 2560/ 5504 (47%)]	loss: 0.047324	cls_loss: 0.046192	k_loss: 0.006434	k: 0.080212	lat_loss: 1.051309
# Train -> [ 5120/ 5504 (93%)]	loss: 0.027433	cls_loss: 0.026098	k_loss: 0.006433	k: 0.080204	lat_loss: 1.254393
# Validation (source) -> cls_loss: 0.075899	accuracy: 98.0000%
# Validation (target) -> cls_loss: 0.996947	accuracy: 71.7892%
# Epoch 30 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.068282	cls_loss: 0.066933	k_loss: 0.006434	k: 0.080214	lat_loss: 1.268978
# Train -> [ 2560/ 5504 (47%)]	loss: 0.064901	cls_loss: 0.063646	k_loss: 0.006460	k: 0.080373	lat_loss: 1.174797
# Train -> [ 5120/ 5504 (93%)]	loss: 0.055670	cls_loss: 0.054411	k_loss: 0.006486	k: 0.080533	lat_loss: 1.178256
# Validation (source) -> cls_loss: 0.078245	accuracy: 97.8733%
# Validation (target) -> cls_loss: 0.822220	accuracy: 74.5335%
# Epoch 31 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.024985	cls_loss: 0.023678	k_loss: 0.006485	k: 0.080532	lat_loss: 1.227097
# Train -> [ 2560/ 5504 (47%)]	loss: 0.062350	cls_loss: 0.061092	k_loss: 0.006522	k: 0.080757	lat_loss: 1.177806
# Train -> [ 5120/ 5504 (93%)]	loss: 0.031079	cls_loss: 0.029772	k_loss: 0.006584	k: 0.081139	lat_loss: 1.226059
# Validation (source) -> cls_loss: 0.072536	accuracy: 97.9733%
# Validation (target) -> cls_loss: 1.076371	accuracy: 68.1668%
# Epoch 32 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.068980	cls_loss: 0.067679	k_loss: 0.006591	k: 0.081186	lat_loss: 1.219560
# Train -> [ 2560/ 5504 (47%)]	loss: 0.044862	cls_loss: 0.043661	k_loss: 0.006637	k: 0.081466	lat_loss: 1.120072
# Train -> [ 5120/ 5504 (93%)]	loss: 0.021663	cls_loss: 0.020069	k_loss: 0.006661	k: 0.081616	lat_loss: 1.512748
# Validation (source) -> cls_loss: 0.075330	accuracy: 98.0200%
# Validation (target) -> cls_loss: 0.987580	accuracy: 71.2953%
# Epoch 33 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.112868	cls_loss: 0.111362	k_loss: 0.006665	k: 0.081641	lat_loss: 1.424730
# Train -> [ 2560/ 5504 (47%)]	loss: 0.023006	cls_loss: 0.021655	k_loss: 0.006671	k: 0.081676	lat_loss: 1.269512
# Train -> [ 5120/ 5504 (93%)]	loss: 0.104723	cls_loss: 0.103542	k_loss: 0.006692	k: 0.081803	lat_loss: 1.099184
# Validation (source) -> cls_loss: 0.079026	accuracy: 97.7533%
# Validation (target) -> cls_loss: 0.831734	accuracy: 75.0823%
# Epoch 34 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.031658	cls_loss: 0.030305	k_loss: 0.006695	k: 0.081821	lat_loss: 1.271136
# Train -> [ 2560/ 5504 (47%)]	loss: 0.023421	cls_loss: 0.022096	k_loss: 0.006714	k: 0.081937	lat_loss: 1.242751
# Train -> [ 5120/ 5504 (93%)]	loss: 0.062369	cls_loss: 0.060961	k_loss: 0.006745	k: 0.082126	lat_loss: 1.325376
# Validation (source) -> cls_loss: 0.071362	accuracy: 98.1400%
# Validation (target) -> cls_loss: 0.784081	accuracy: 76.0154%
# Epoch 35 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.052309	cls_loss: 0.050949	k_loss: 0.006747	k: 0.082140	lat_loss: 1.278418
# Train -> [ 2560/ 5504 (47%)]	loss: 0.015727	cls_loss: 0.014346	k_loss: 0.006764	k: 0.082244	lat_loss: 1.298894
# Train -> [ 5120/ 5504 (93%)]	loss: 0.033523	cls_loss: 0.032088	k_loss: 0.006787	k: 0.082386	lat_loss: 1.352604
# Validation (source) -> cls_loss: 0.070738	accuracy: 98.0933%
# Validation (target) -> cls_loss: 0.965387	accuracy: 69.0999%
# Epoch 36 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.029663	cls_loss: 0.028291	k_loss: 0.006792	k: 0.082414	lat_loss: 1.289507
# Train -> [ 2560/ 5504 (47%)]	loss: 0.019681	cls_loss: 0.018498	k_loss: 0.006836	k: 0.082682	lat_loss: 1.099986
# Train -> [ 5120/ 5504 (93%)]	loss: 0.015274	cls_loss: 0.013654	k_loss: 0.006864	k: 0.082851	lat_loss: 1.537179
# Validation (source) -> cls_loss: 0.073668	accuracy: 98.1133%
# Validation (target) -> cls_loss: 0.926226	accuracy: 73.1065%
# Epoch 37 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.054491	cls_loss: 0.052967	k_loss: 0.006866	k: 0.082859	lat_loss: 1.440834
# Train -> [ 2560/ 5504 (47%)]	loss: 0.041689	cls_loss: 0.040402	k_loss: 0.006858	k: 0.082815	lat_loss: 1.203769
# Train -> [ 5120/ 5504 (93%)]	loss: 0.016680	cls_loss: 0.015299	k_loss: 0.006871	k: 0.082894	lat_loss: 1.298801
# Validation (source) -> cls_loss: 0.064592	accuracy: 98.3133%
# Validation (target) -> cls_loss: 0.884169	accuracy: 73.3260%
# Epoch 38 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.114721	cls_loss: 0.113391	k_loss: 0.006874	k: 0.082909	lat_loss: 1.247565
# Train -> [ 2560/ 5504 (47%)]	loss: 0.075246	cls_loss: 0.073862	k_loss: 0.006893	k: 0.083023	lat_loss: 1.300631
# Train -> [ 5120/ 5504 (93%)]	loss: 0.009822	cls_loss: 0.008426	k_loss: 0.006921	k: 0.083190	lat_loss: 1.312493
# Validation (source) -> cls_loss: 0.072162	accuracy: 98.0400%
# Validation (target) -> cls_loss: 1.008893	accuracy: 71.4599%
# Epoch 39 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.024897	cls_loss: 0.023491	k_loss: 0.006927	k: 0.083229	lat_loss: 1.322639
# Train -> [ 2560/ 5504 (47%)]	loss: 0.030068	cls_loss: 0.028927	k_loss: 0.006959	k: 0.083423	lat_loss: 1.058434
# Train -> [ 5120/ 5504 (93%)]	loss: 0.028446	cls_loss: 0.027101	k_loss: 0.006973	k: 0.083504	lat_loss: 1.261111
# Validation (source) -> cls_loss: 0.071277	accuracy: 97.9933%
# Validation (target) -> cls_loss: 0.782849	accuracy: 74.4786%
# Epoch 40 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.021132	cls_loss: 0.019972	k_loss: 0.006977	k: 0.083529	lat_loss: 1.076651
# Train -> [ 2560/ 5504 (47%)]	loss: 0.108651	cls_loss: 0.107460	k_loss: 0.007035	k: 0.083873	lat_loss: 1.107529
# Train -> [ 5120/ 5504 (93%)]	loss: 0.008198	cls_loss: 0.006922	k_loss: 0.007065	k: 0.084052	lat_loss: 1.192265
# Validation (source) -> cls_loss: 0.064259	accuracy: 98.1333%
# Validation (target) -> cls_loss: 0.857573	accuracy: 73.1614%
# Epoch 41 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.041957	cls_loss: 0.040750	k_loss: 0.007067	k: 0.084066	lat_loss: 1.123268
# Train -> [ 2560/ 5504 (47%)]	loss: 0.023106	cls_loss: 0.021958	k_loss: 0.007143	k: 0.084517	lat_loss: 1.063459
# Train -> [ 5120/ 5504 (93%)]	loss: 0.134229	cls_loss: 0.133025	k_loss: 0.007184	k: 0.084758	lat_loss: 1.119164
# Validation (source) -> cls_loss: 0.068129	accuracy: 98.1067%
# Validation (target) -> cls_loss: 0.773244	accuracy: 77.5521%
# Epoch 42 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.059025	cls_loss: 0.057796	k_loss: 0.007189	k: 0.084785	lat_loss: 1.144128
# Train -> [ 2560/ 5504 (47%)]	loss: 0.010041	cls_loss: 0.008974	k_loss: 0.007239	k: 0.085082	lat_loss: 0.982185
# Train -> [ 5120/ 5504 (93%)]	loss: 0.012199	cls_loss: 0.010960	k_loss: 0.007318	k: 0.085548	lat_loss: 1.153444
# Validation (source) -> cls_loss: 0.068842	accuracy: 98.0867%
# Validation (target) -> cls_loss: 1.058542	accuracy: 69.0999%
# Epoch 43 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.038002	cls_loss: 0.036747	k_loss: 0.007337	k: 0.085655	lat_loss: 1.168941
# Train -> [ 2560/ 5504 (47%)]	loss: 0.085384	cls_loss: 0.084223	k_loss: 0.007486	k: 0.086522	lat_loss: 1.075061
# Train -> [ 5120/ 5504 (93%)]	loss: 0.025602	cls_loss: 0.024531	k_loss: 0.007561	k: 0.086955	lat_loss: 0.984182
# Validation (source) -> cls_loss: 0.061590	accuracy: 98.2733%
# Validation (target) -> cls_loss: 0.879953	accuracy: 70.3622%
# Epoch 44 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.092970	cls_loss: 0.091885	k_loss: 0.007561	k: 0.086957	lat_loss: 0.998049
# Train -> [ 2560/ 5504 (47%)]	loss: 0.049584	cls_loss: 0.048431	k_loss: 0.007567	k: 0.086990	lat_loss: 1.065565
# Train -> [ 5120/ 5504 (93%)]	loss: 0.027403	cls_loss: 0.026481	k_loss: 0.007590	k: 0.087121	lat_loss: 0.834929
# Validation (source) -> cls_loss: 0.059241	accuracy: 98.3400%
# Validation (target) -> cls_loss: 0.742765	accuracy: 77.0033%
# Epoch 45 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.093990	cls_loss: 0.092951	k_loss: 0.007595	k: 0.087149	lat_loss: 0.951923
# Train -> [ 2560/ 5504 (47%)]	loss: 0.027682	cls_loss: 0.026456	k_loss: 0.007669	k: 0.087573	lat_loss: 1.138492
# Train -> [ 5120/ 5504 (93%)]	loss: 0.025061	cls_loss: 0.024040	k_loss: 0.007766	k: 0.088125	lat_loss: 0.932845
# Validation (source) -> cls_loss: 0.066180	accuracy: 98.0000%
# Validation (target) -> cls_loss: 0.842966	accuracy: 74.1493%
# Epoch 46 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.052407	cls_loss: 0.051443	k_loss: 0.007770	k: 0.088149	lat_loss: 0.876485
# Train -> [ 2560/ 5504 (47%)]	loss: 0.036042	cls_loss: 0.034829	k_loss: 0.007793	k: 0.088276	lat_loss: 1.124452
# Train -> [ 5120/ 5504 (93%)]	loss: 0.035136	cls_loss: 0.034120	k_loss: 0.007814	k: 0.088399	lat_loss: 0.927489
# Validation (source) -> cls_loss: 0.063631	accuracy: 98.0933%
# Validation (target) -> cls_loss: 0.927334	accuracy: 69.4841%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.102482	cls_loss: 0.101408	k_loss: 0.007811	k: 0.088379	lat_loss: 0.986178
# Train -> [ 2560/ 5504 (47%)]	loss: 0.085027	cls_loss: 0.083688	k_loss: 0.007828	k: 0.088476	lat_loss: 1.250801
# Train -> [ 5120/ 5504 (93%)]	loss: 0.008094	cls_loss: 0.006827	k_loss: 0.007903	k: 0.088901	lat_loss: 1.178398
# Validation (source) -> cls_loss: 0.059399	accuracy: 98.1667%
# Validation (target) -> cls_loss: 0.891534	accuracy: 72.9418%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.029537	cls_loss: 0.028412	k_loss: 0.007906	k: 0.088916	lat_loss: 1.035736
# Train -> [ 2560/ 5504 (47%)]	loss: 0.022592	cls_loss: 0.021310	k_loss: 0.007902	k: 0.088891	lat_loss: 1.192362
# Train -> [ 5120/ 5504 (93%)]	loss: 0.058163	cls_loss: 0.057194	k_loss: 0.007908	k: 0.088926	lat_loss: 0.879416
# Validation (source) -> cls_loss: 0.058734	accuracy: 98.2267%
# Validation (target) -> cls_loss: 0.889332	accuracy: 71.3502%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.043001	cls_loss: 0.042086	k_loss: 0.007909	k: 0.088935	lat_loss: 0.826142
# Train -> [ 2560/ 5504 (47%)]	loss: 0.027833	cls_loss: 0.026583	k_loss: 0.007985	k: 0.089361	lat_loss: 1.161233
# Train -> [ 5120/ 5504 (93%)]	loss: 0.035796	cls_loss: 0.034591	k_loss: 0.008018	k: 0.089545	lat_loss: 1.114600
# Validation (source) -> cls_loss: 0.056834	accuracy: 98.4000%
# Validation (target) -> cls_loss: 0.902313	accuracy: 73.7651%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.019689	cls_loss: 0.018536	k_loss: 0.008020	k: 0.089552	lat_loss: 1.063451
# Train -> [ 2560/ 5504 (47%)]	loss: 0.050285	cls_loss: 0.049254	k_loss: 0.008043	k: 0.089682	lat_loss: 0.941388
# Train -> [ 5120/ 5504 (93%)]	loss: 0.064127	cls_loss: 0.063046	k_loss: 0.008080	k: 0.089889	lat_loss: 0.991753
# Validation (source) -> cls_loss: 0.059520	accuracy: 98.3600%
# Validation (target) -> cls_loss: 0.964317	accuracy: 72.4479%
# Test (source) -> cls_loss: 0.075846	accuracy: 98.0000%
# Test (target) -> cls_loss: 0.806456	accuracy: 74.1405%

# %%
np.save('all_loss_train.npy', all_loss_train)
np.save('all_loss_val.npy', all_loss_val)
np.save('all_loss_test.npy', all_loss_test)

plot_losses(
    list(np.mean(all_loss_train, axis=0).T),
    loss_labels_train,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training'
)
plot_losses(
    list(np.mean(all_loss_val, axis=0).T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation'
)
print(np.mean(all_loss_test, axis=0))
# Out:
# [0.04541721 0.98694    0.69423149 0.79143   ]
