# %%
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchinfo

torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Create dataset

# %%
def create_dataloader(dataset, transform=None, val_split=0.25, batch_size=64, num_workers=2):
    train_set = dataset('./data', train=True,  download=True, transform=transform)
    test_set  = dataset('./data', train=False, download=True, transform=transform)
    
    train_set, val_set = torch.utils.data.random_split(train_set, [1-val_split, val_split])
    
    train = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    val   = torch.utils.data.DataLoader(val_set,   batch_size=batch_size, shuffle=True,  num_workers=num_workers)
    test  = torch.utils.data.DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return (train, val, test)

# %% [markdown]
# # Create model

# %% [markdown]
# ## CNN

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, input_shape: Tuple[int], cnn_out_features: List[int]):
        super().__init__()
        
        self.cnn_layers = nn.ModuleList()
        shape = list(input_shape)
        prev_nf = input_shape[0]
        
        for curr_nf in cnn_out_features:
            self.cnn_layers.append(nn.Sequential(
                nn.Conv2d(prev_nf, curr_nf, kernel_size=3, padding='same'),
                nn.MaxPool2d(2)
            ))
            prev_nf = curr_nf
            
            shape[0] = curr_nf
            shape[1] = int(shape[1] / 2)
            shape[2] = int(shape[2] / 2)
        
        self.input_shape = input_shape
        self.output_shape = (shape[0], shape[1], shape[2])
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.cnn_layers:
            x = layer(x)
        return x

# %%
class ClassRegressor(nn.Module):
    def __init__(self, input_shape: Tuple[int], output_shape: int, fnn_out_features: List[int]):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.fnn_layers = nn.ModuleList()
        prev_nf = in_features
        
        for curr_nf in fnn_out_features:
            self.fnn_layers.append(nn.Sequential(
                nn.Linear(prev_nf, curr_nf),
                nn.ReLU()
            ))
            prev_nf = curr_nf
        
        self.op_layer = nn.Linear(prev_nf, output_shape)
        
        self.in_features = in_features
        self.out_features = output_shape
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        for layer in self.fnn_layers:
            x = layer(x)
        x = self.op_layer(x)
        return x

# %% [markdown]
# ## K-Regressor

# %%
class KRegressor(nn.Module):
    def __init__(self, input_shape: int, hidden_size: int):
        super().__init__()
        
        if isinstance(input_shape, tuple):
            in_features = 1
            for x in input_shape:
                in_features *= x
        else:
            in_features = input_shape
        
        self.projection = nn.Linear(in_features, hidden_size)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=hidden_size,
                nhead=1
            ),
            num_layers=1
        )
        self.output_layer = nn.Sequential(
            nn.Linear(hidden_size, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        z = self.transformer(x)[0, :]
        k = self.output_layer(z)
        return k

# %% [markdown]
# ## Dimensionality reducer

# %%
class DimensionReducer(nn.Module):
    def __init__(
        self,
        in_features: int,
        hidden_size: int,
        beta: float = 5.0,
        esp:  float = 1e-8
    ):
        super().__init__()
        
        self.beta = beta
        self.esp = esp
        self.k_regressor = KRegressor(in_features, hidden_size)
    
    def forward(self, xs: torch.Tensor) -> torch.Tensor:
        kd = min(xs.shape[0], xs.shape[1])
        ks = self.k_regressor(xs)
        
        xs = xs - torch.mean(xs, dim=0)
        # xs = xs + self.esp
        us, ss, vhs = torch.linalg.svd(xs, full_matrices=False)
        
        i = torch.arange(kd, device=xs.device)
        ws = torch.sigmoid(-self.beta*(i - ks*kd))
        
        ss1 = torch.diag(ss * ws)
        xs = torch.mm(torch.mm(us, ss1), vhs)
        
        return (xs, ks)

# %%
class MyModel(nn.Module):
    def __init__(
        self,
        input_shape:      Tuple[int],
        output_shape:     int,
        cnn_out_features: List[int],
        fnn_out_features: List[int]
    ):
        super().__init__()
        self.feature_extractor = FeatureExtractor(input_shape, cnn_out_features)
        self.class_regressor   = ClassRegressor(self.feature_extractor.output_shape, output_shape, fnn_out_features)
        self.dimension_reducer = DimensionReducer(self.feature_extractor.output_shape, hidden_size=128)
    
    def forward(self, x):
        x = self.feature_extractor(x)
        x = torch.flatten(x, start_dim=1)
        x, k = self.dimension_reducer(x)
        x = self.class_regressor(x)
        return (x, k)

# %% [markdown]
# # Plotting

# %%
def plot_losses(
    losses: List[np.ndarray],
    labels: List[str] = None,
    ylabel: str = '',
    xlabel: str = '',
    title:  str = ''
):
    if labels is None:
        labels = [''] * len(losses)
    for loss, label in zip(losses, labels):
        plt.plot(loss, label=label)
    plt.legend()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Hyperparameters & dataset creation

# %%
lr_c = 1e-3
batch_size = 128
model_save_path = 'best_model.pt'

num_epochs = 50
checkpoint = 20

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

train_s, val_s, test_s = create_dataloader(
    torchvision.datasets.MNIST,
    transform=transform,
    batch_size=batch_size
)
train_t, val_t, test_t = create_dataloader(
    torchvision.datasets.USPS,
    transform=transforms.Compose([transform, transforms.Resize((28, 28))]),
    batch_size=batch_size
)

# %% [markdown]
# # Training & evaluation

# %%
def evaluate(model_c, dataloader, cls_loss_fn, k=None, mode=None):
    model_c.eval()
    cls_losses = []
    accuracy   = 0
    
    with torch.no_grad():
        for batch_idx, (x, y_true) in enumerate(dataloader):
            x = x.to(device)
            y_true = y_true.to(device)
            
            y_pred, _ = model_c(x)
            loss = cls_loss_fn(y_pred, y_true)
            
            cls_losses += [loss.item()]
            y_pred1 = torch.max(y_pred, dim=1)[1]
            accuracy += torch.sum(y_pred1 == y_true).item()
    
    cls_loss = np.mean(cls_losses)
    accuracy /= len(dataloader.dataset)
    
    if mode is not None:
        print('{} -> cls_loss: {:.6f}\taccuracy: {:.4f}%'.format(
            mode,
            cls_loss,
            accuracy * 100
        ))
    return (cls_loss, accuracy)

# %%
def train_step(xs, xt, ys_true, alpha, gamma):
    N = xs.shape[0]
    
    ys_pred, ks = classifier(xs)
    
    cls_loss = cls_loss_fn(ys_pred, ys_true)
    k_loss = ks**2
    
    # alignment to target
    kd = min(xs.shape[0], xs.shape[1])
    
    xt = classifier.feature_extractor(xt)
    xt = torch.flatten(xt, start_dim=1)
    
    xt = xt - torch.mean(xt, dim=0)
    # xs = xs + self.esp
    ut, st, vht = torch.linalg.svd(xt, full_matrices=False)

    i = torch.arange(kd, device=xs.device)
    beta = classifier.dimension_reducer.beta
    wt = torch.sigmoid(-beta*(i - ks*kd))
    wt = 1 - wt

    st1 = torch.diag(st * wt)
    xt = torch.mm(torch.mm(ut, st1), vht)
    
    yt_pred = classifier.class_regressor(xt)
    yt_true = torch.zeros(N, classifier.class_regressor.out_features, device=device)
    
    lat_loss = F.mse_loss(yt_pred, yt_true)
    
    loss = cls_loss + alpha*ks + gamma*lat_loss
    
    optimizer_c.zero_grad()
    loss.backward()
    optimizer_c.step()
    
    return (
        loss.item(),
        cls_loss.item(),
        k_loss.item(),
        ks.item(),
        lat_loss.item()
    )

# %% [markdown]
# # Main

# %%
def main():
    global classifier, dimension_reducer
    global cls_loss_fn
    global optimizer_c
    global loss_labels_train, loss_labels_val
    
    classifier = MyModel(
        input_shape=(1, 28, 28),
        output_shape=10,
        cnn_out_features=[16, 32, 64],
        fnn_out_features=[128, 64],
    ).to(device)
    
    dimension_reducer = DimensionReducer(
        classifier.class_regressor.in_features,
        hidden_size=128
    ).to(device)
    
    print(torchinfo.summary(classifier, input_size=(batch_size, 1, 28, 28)))
    
    cls_loss_fn = nn.CrossEntropyLoss()
    optimizer_c = torch.optim.Adam(classifier.parameters(), lr=lr_c)
    
    all_loss = np.zeros((num_epochs, 5))
    loss_labels_train = ['loss', 'cls_loss', 'k_loss', 'k', 'lat_loss']

    all_loss_val = np.zeros((num_epochs, 4))
    all_loss_test = np.zeros((1, 4))
    loss_labels_val = ['cls_loss_s', 'accuracy_s', 'cls_loss_t', 'accuracy_t']
    
    best_val_loss = float('inf')
    best_k = 1
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1} --------')

        classifier.train()

        len_dataloader = min(len(train_s), len(train_t))
        iter_s = iter(train_s)
        iter_t = iter(train_t)

        avg_loss = np.zeros(all_loss.shape[1])

        for batch_idx in range(len_dataloader):
            p = float(batch_idx + epoch*len_dataloader) / (num_epochs*len_dataloader)
            # alpha = 2 / (1 + np.exp(-10 * p)) - 1
            alpha = 1e-2
            gamma = 1e-3
            
            # if epoch > 30:    # start label alignment to target
            #     for param in classifier.feature_extractor.parameters():
            #         param.requires_grad = False
            #     for param in classifier.dimension_reducer.parameters():
            #         param.requires_grad = False
            #     gamma = 10
            # else:
            #     gamma = 0

            data_s = next(iter_s)
            data_t = next(iter_t)

            xs, ys_true = data_s
            xt, yt_true = data_t
            if xs.shape[0] != xt.shape[0]:
                continue

            xs = xs.to(device)
            xt = xt.to(device)
            ys_true = ys_true.to(device)
            yt_true = yt_true.to(device)

            losses = train_step(xs, xt, ys_true, alpha, gamma)
            avg_loss += losses

            if checkpoint is not None and batch_idx % checkpoint == 0:
                print('Train -> [{:>5}/{:>5} ({:.0f}%)]'.format(
                        batch_idx * batch_size,
                        len_dataloader * batch_size,
                        batch_idx / len_dataloader * 100
                    ),
                    end='\t'
                )
                for loss, label in zip(losses, loss_labels_train):
                    print(f'{label}: {loss:.6f}', end='\t')
                print('')

        avg_loss = avg_loss / len_dataloader
        all_loss[epoch] = losses

        val_losses_s = evaluate(classifier, val_s, cls_loss_fn, mode='Validation (source)')
        val_losses_t = evaluate(classifier, val_t, cls_loss_fn, mode='Validation (target)')

        all_loss_val[epoch] = val_losses_s + val_losses_t

        val_loss = val_losses_t[0]

        if val_loss < best_val_loss:
            torch.save(classifier.state_dict(), model_save_path)
            best_k = avg_loss[-1]
            best_val_loss = val_loss
            print(f'Best model updated and saved at "{model_save_path}"')
    
    classifier.load_state_dict(torch.load(model_save_path))
    test_loss_s = evaluate(classifier, test_s, cls_loss_fn, mode='Test (source)')
    test_loss_t = evaluate(classifier, test_t, cls_loss_fn, mode='Test (target)')
    
    all_loss_test = test_loss_s + test_loss_t
    
    return (all_loss, all_loss_val, all_loss_test)

# %%
all_loss_train = []
all_loss_val   = []
all_loss_test  = []
for i in range(5):
    loss_train, loss_val, loss_test = main()
    all_loss_train.append(loss_train)
    all_loss_val.append(loss_val)
    all_loss_test.append(loss_test)

all_loss_train = np.array(all_loss_train)
all_loss_val   = np.array(all_loss_val)
all_loss_test  = np.array(all_loss_test)
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# MyModel                                                 [128, 10]                 --
# ├─FeatureExtractor: 1-1                                 [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                                  --                        --
# │    │    └─Sequential: 3-1                             [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2                             [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3                             [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                                 [128, 576]                --
# │    └─KRegressor: 2-2                                  [1]                       --
# │    │    └─Linear: 3-4                                 [128, 128]                73,856
# │    │    └─TransformerEncoder: 3-5                     [128, 128]                593,024
# │    │    └─Sequential: 3-6                             [1]                       129
# ├─ClassRegressor: 1-3                                   [128, 10]                 --
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─Sequential: 3-7                             [128, 128]                73,856
# │    │    └─Sequential: 3-8                             [128, 64]                 8,256
# │    └─Linear: 2-4                                      [128, 10]                 650
# =========================================================================================================
# Total params: 773,067
# Trainable params: 773,067
# Non-trainable params: 0
# Total mult-adds (M): 335.97
# =========================================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 25.31
# Params size (MB): 2.83
# Estimated Total Size (MB): 28.54
# =========================================================================================================
# Epoch 1 --------
# Train -> [    0/ 5504 (0%)]	loss: 2.310488	cls_loss: 2.305570	k_loss: 0.241595	k: 0.491523	lat_loss: 0.002843
# Train -> [ 2560/ 5504 (47%)]	loss: 1.704758	cls_loss: 1.702511	k_loss: 0.048739	k: 0.220768	lat_loss: 0.039034
# Train -> [ 5120/ 5504 (93%)]	loss: 0.530647	cls_loss: 0.527197	k_loss: 0.110217	k: 0.331989	lat_loss: 0.130349
# Validation (source) -> cls_loss: 0.462030	accuracy: 87.1000%
# Validation (target) -> cls_loss: 1.128169	accuracy: 63.9407%
# Best model updated and saved at "best_model.pt"
# Epoch 2 --------
# Train -> [    0/ 5504 (0%)]	loss: 0
--------
# Train -> [    0/ 5504 (0%)]	loss: 0.021840	cls_loss: 0.015345	k_loss: 0.417872	k: 0.646430	lat_loss: 0.030418
# Train -> [ 2560/ 5504 (47%)]	loss: 0.074965	cls_loss: 0.068647	k_loss: 0.395103	k: 0.628572	lat_loss: 0.031576
# Train -> [ 5120/ 5504 (93%)]	loss: 0.009903	cls_loss: 0.004399	k_loss: 0.295688	k: 0.543772	lat_loss: 0.066144
# Validation (source) -> cls_loss: 0.042532	accuracy: 98.8600%
# Validation (target) -> cls_loss: 0.802720	accuracy: 76.6740%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.031556	cls_loss: 0.026281	k_loss: 0.269294	k: 0.518936	lat_loss: 0.085485
# Train -> [ 2560/ 5504 (47%)]	loss: 0.056525	cls_loss: 0.051158	k_loss: 0.279849	k: 0.529008	lat_loss: 0.076953
# Train -> [ 5120/ 5504 (93%)]	loss: 0.020126	cls_loss: 0.014117	k_loss: 0.355830	k: 0.596515	lat_loss: 0.043650
# Validation (source) -> cls_loss: 0.045142	accuracy: 98.8200%
# Validation (target) -> cls_loss: 1.039469	accuracy: 75.1372%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.043691	cls_loss: 0.037338	k_loss: 0.399710	k: 0.632227	lat_loss: 0.030549
# Train -> [ 2560/ 5504 (47%)]	loss: 0.078498	cls_loss: 0.071650	k_loss: 0.466427	k: 0.682954	lat_loss: 0.018426
# Train -> [ 5120/ 5504 (93%)]	loss: 0.015449	cls_loss: 0.008523	k_loss: 0.477314	k: 0.690879	lat_loss: 0.017734
# Validation (source) -> cls_loss: 0.040212	accuracy: 98.8933%
# Validation (target) -> cls_loss: 0.570039	accuracy: 82.0527%
# Test (source) -> cls_loss: 0.034516	accuracy: 98.9700%
# Test (target) -> cls_loss: 0.681724	accuracy: 79.2725%
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# MyModel                                                 [128, 10]                 --
# ├─FeatureExtractor: 1-1                                 [128, 64, 3, 3]           --
# │    └─ModuleList: 2-1                                  --                        --
# │    │    └─Sequential: 3-1                             [128, 16, 14, 14]         160
# │    │    └─Sequential: 3-2                             [128, 32, 7, 7]           4,640
# │    │    └─Sequential: 3-3                             [128, 64, 3, 3]           18,496
# ├─DimensionReducer: 1-2                                 [128, 576]                --
# │    └─KRegressor: 2-2                                  [1]                       --
# │    │    └─Linear: 3-4                                 [128, 128]                73,856
# │    │    └─TransformerEncoder: 3-5                     [128, 128]                593,024
# │    │    └─Sequential: 3-6                             [1]                       129
# ├─ClassRegressor: 1-3                                   [128, 10]                 --
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─Sequential: 3-7                             [128, 128]                73,856
# │    │    └─Sequential: 3-8                             [128, 64]                 8,256
# │    └─Linear: 2-4                                      [128, 10]                 650
# =========================================================================================================
# Total params: 773,067
# Trainable params: 773,067
# Non-trainable params: 0
# Total mult-adds (M): 335.97
# =========================================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 25.31
# Params size (MB): 2.83
# Estimated Total Size (MB): 28.54
# =========================================================================================================
# Epoch 1 --------
--------
# Train -> [    0/ 5504 (0%)]	loss: 0.011010	cls_loss: 0.005124	k_loss: 0.338038	k: 0.581410	lat_loss: 0.072166
# Train -> [ 2560/ 5504 (47%)]	loss: 0.025563	cls_loss: 0.019773	k_loss: 0.326699	k: 0.571576	lat_loss: 0.074304
# Train -> [ 5120/ 5504 (93%)]	loss: 0.028260	cls_loss: 0.022786	k_loss: 0.289597	k: 0.538142	lat_loss: 0.092411
# Validation (source) -> cls_loss: 0.050530	accuracy: 98.6200%
# Validation (target) -> cls_loss: 0.598672	accuracy: 83.5346%
# Epoch 47 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.031213	cls_loss: 0.025938	k_loss: 0.266045	k: 0.515795	lat_loss: 0.117403
# Train -> [ 2560/ 5504 (47%)]	loss: 0.006438	cls_loss: 0.000635	k_loss: 0.328961	k: 0.573551	lat_loss: 0.067560
# Train -> [ 5120/ 5504 (93%)]	loss: 0.017401	cls_loss: 0.011377	k_loss: 0.356436	k: 0.597023	lat_loss: 0.053452
# Validation (source) -> cls_loss: 0.062143	accuracy: 98.1267%
# Validation (target) -> cls_loss: 0.733562	accuracy: 76.6740%
# Epoch 48 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.034975	cls_loss: 0.028878	k_loss: 0.366446	k: 0.605348	lat_loss: 0.043688
# Train -> [ 2560/ 5504 (47%)]	loss: 0.020340	cls_loss: 0.013775	k_loss: 0.426855	k: 0.653341	lat_loss: 0.031181
# Train -> [ 5120/ 5504 (93%)]	loss: 0.031960	cls_loss: 0.025101	k_loss: 0.466805	k: 0.683231	lat_loss: 0.027558
# Validation (source) -> cls_loss: 0.045449	accuracy: 98.6533%
# Validation (target) -> cls_loss: 0.504945	accuracy: 84.2481%
# Epoch 49 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.041016	cls_loss: 0.033940	k_loss: 0.497260	k: 0.705166	lat_loss: 0.023983
# Train -> [ 2560/ 5504 (47%)]	loss: 0.012616	cls_loss: 0.005033	k_loss: 0.571997	k: 0.756305	lat_loss: 0.020515
# Train -> [ 5120/ 5504 (93%)]	loss: 0.033381	cls_loss: 0.026166	k_loss: 0.517059	k: 0.719068	lat_loss: 0.024196
# Validation (source) -> cls_loss: 0.043889	accuracy: 98.7533%
# Validation (target) -> cls_loss: 0.627422	accuracy: 82.2722%
# Epoch 50 --------
# Train -> [    0/ 5504 (0%)]	loss: 0.022049	cls_loss: 0.014929	k_loss: 0.503343	k: 0.709467	lat_loss: 0.025538
# Train -> [ 2560/ 5504 (47%)]	loss: 0.007023	cls_loss: 0.000358	k_loss: 0.439228	k: 0.662743	lat_loss: 0.038151
# Train -> [ 5120/ 5504 (93%)]	loss: 0.006716	cls_loss: 0.000323	k_loss: 0.402827	k: 0.634687	lat_loss: 0.045806
# Validation (source) -> cls_loss: 0.042216	accuracy: 98.8333%
# Validation (target) -> cls_loss: 0.624606	accuracy: 81.8332%
# Test (source) -> cls_loss: 0.040612	accuracy: 98.7400%
# Test (target) -> cls_loss: 0.656000	accuracy: 81.2656%

# %%
np.save('all_loss_train.npy', all_loss_train)
np.save('all_loss_val.npy', all_loss_val)
np.save('all_loss_test.npy', all_loss_test)

plot_losses(
    list(np.mean(all_loss_train, axis=0).T),
    loss_labels_train,
    ylabel='Loss',
    xlabel='Epoch',
    title='Training'
)
plot_losses(
    list(np.mean(all_loss_val, axis=0).T),
    loss_labels_val,
    ylabel='Loss',
    xlabel='Epoch',
    title='Validation'
)
print(np.mean(all_loss_test, axis=0))
# Out:
# [0.04043164 0.98778    0.61448395 0.8163428 ]
